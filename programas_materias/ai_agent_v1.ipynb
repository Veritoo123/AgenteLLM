# %% [markdown]
# # Librerías y dependencias

# %%
# %%capture
# !apt-get update
# !apt-get install pandoc # para usar markdown
# !apt-get install texlive-xetex # Toma un buen tiempo la instalación
# !pip install markdown2 # para usar markdown
# !pip install pypandoc # para usar markdown
# !pip install fitz
# !pip install --upgrade pymupdf
# !pip install python-docx

# %%
import os
import json
import fitz  # PyMuPDF para leer PDFs
import markdown
import pypandoc
import google.generativeai as genai
from docx import Document

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Agente

# %%
genai.configure(api_key="AIzaSyAooWfS3xzumCHk4xw4lMjl2yGdcoj3sog")
model = genai.GenerativeModel('gemini-2.0-flash-001')

# %%
initial_prompt = """
Eres un desarrollador experto de contenido educativo con amplia experiencia en la creación de materiales de cursos universitarios. Posees un profundo conocimiento en principios pedagógicos, diseño curricular y redacción académica. Tu tarea es ayudar a desarrollar un agente inteligente basado en modelos de lenguaje (LLM) que, a partir de un plan de estudios (syllabus), genere materiales educativos integrales que cumplan con altos estándares académicos.

Contexto y Objetivos
El agente debe:

Analizar y Comprender el Syllabus:

Extraer los componentes esenciales (objetivos, competencias, temáticas, metodologías, evaluaciones, etc.).
Identificar puntos clave para la generación de contenido pedagógico.
Generar Materiales Educativos:

Elaborar módulos detallados para cada tema o área, definiendo objetivos, contenidos, actividades y evaluaciones.
Crear notas de clase comprensivas que expliquen en profundidad cada módulo, incluyendo ejemplos, explicaciones teóricas,Problemas de práctica con soluciones y preguntas para discusión.
Mantener un alto rigor académico, asegurando la confiabilidad de la información y la integración de buenas prácticas pedagógicas.
Formato de Salida Específico:

Toda la salida generada debe estructurarse en formato JSON.
La estructura JSON debe incluir secciones claras para módulos y notas de clase.
Ejemplo de formato JSON:

{
  "course_title": "Título del Curso",
  "modules": [
    {
      "module_title": "Título del Módulo 1",
      "objectives": ["Objetivo 1", "Objetivo 2"],
      "module_num": "1",
      "content_outline": "Resumen de contenidos",
      "class_notes": {
        "class_num": "1",
        "introduction": "Introducción detallada del tema",
        "theory": "Desarrollo teórico con explicaciones y ejemplos",
        "challenges": "Problemas  y actividades prácticas para el estudiante con las respectivas soluciones, también preguntas para discusión"
      }
    },
    {
      "module_title": "Título del Módulo 2",
      "objectives": ["Objetivo A", "Objetivo B"],
      "content_outline": "Resumen de contenidos",
      "class_notes": {
        "introduction": "Introducción al tema",
        "theory": "Explicaciones teóricas y casos de estudio",
        "challenges": "Ejercicios y retos para aplicar lo aprendido con las respectivas soluciones"
      }
    }
  ]
}


SYLLABUS:
"""

# %% [markdown]
# ### Funciones para la extracción de texto

# %%
def extract_text_from_pdf(pdf_path):
    """ Extrae texto de un archivo PDF. """
    doc = fitz.open(pdf_path)
    return "\n".join([page.get_text() for page in doc])

def extract_text_from_txt(txt_path):
    """ Extrae texto de un archivo TXT. """
    with open(txt_path, "r", encoding="utf-8") as file:
        return file.read()

def extract_text_from_docx(docx_path):
    """ Extrae texto de un archivo DOCX. """
    doc = Document(docx_path)
    return "\n".join([para.text for para in doc.paragraphs])

def extract_text_from_file(file_path):
    """ Detecta el tipo de archivo y extrae el texto. """
    if file_path.endswith(".pdf"):
        return extract_text_from_pdf(file_path)
    elif file_path.endswith(".txt"):
        return extract_text_from_txt(file_path)
    elif file_path.endswith(".docx"):
        return extract_text_from_docx(file_path)
    else:
        raise ValueError("Formato de archivo no soportado")

def convert_to_pdf(content, output_name):
    """ Convierte texto en formato markdown a PDF. """
    html = markdown.markdown(content)
    extra_args = [
        '--pdf-engine=xelatex',
        '-V', 'mainfont=Latin Modern Roman',
        '-V', 'geometry:margin=1in',
        '-V', 'linkcolor=blue',
        '-V', 'toc'
    ]

    path = f"/content/drive/MyDrive/Trabajo4/output/{output_name}"
    pypandoc.convert_text(html, 'pdf', format='html', outputfile=path, extra_args=extra_args)

def get_json(response):
    respuesta = response.text

    # Find the start and end of the JSON object
    start = respuesta.find('{')
    end = respuesta.rfind('}') + 1  # +1 to include the closing brace

    # Extract the JSON string
    json_string = respuesta[start:end]

    # Try to parse the JSON
    try:
        data_json = json.loads(json_string)
        return data_json
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        print(f"Problematic JSON string: {json_string}")
        return None

# %% [markdown]
# ### Funciones para generar el contenido

# %%
def crear_material_clase_i(model, i, data_json):
    # Extraer solo la información del módulo actual
    modulo_info = data_json["modules"][i]

    module_num = modulo_info.get("module_num", i + 1)

    prompt = f"""Eres un desarrollador experto de contenido educativo con amplia experiencia en la creación de materiales de cursos universitarios.
    Posees un profundo conocimiento en principios pedagógicos, diseño curricular y redacción académica.
    Tu tarea es ayudar a desarrollar materiales educativos integrales a partir de un plan de estudios (syllabus), asegurando altos estándares académicos.

    ### Contexto y Objetivos
    - **Analizar y comprender el syllabus**:
      - Extraer los componentes esenciales (objetivos, competencias, temáticas, metodologías, evaluaciones, etc.).
      - Identificar puntos clave para la generación de contenido pedagógico.
    - **Generar materiales educativos**:
      - Analizar detalladamente cada módulo, definiendo objetivos, contenidos, actividades y evaluaciones con sus respectivas soluciones.
      - Crear notas de clase comprensivas que expliquen en profundidad cada módulo, con ejemplos, explicaciones teóricas, problemas práticos con soluciones y preguntas de discusión.
      - Mantener un alto rigor académico y coherencia con módulos previos.

    ### Plan de estudios - Módulo {module_num}
    {modulo_info}

    ### Instrucciones
    - Genera **únicamente** el material detallado del **módulo {module_num}**.
    - **No copies ni reformules información de módulos anteriores.**
    - Si un tema se repite en distintos módulos, **explica las diferencias y profundiza en los aspectos específicos de este módulo**.
    - Asegúrate de seguir el esquema de clases indicado en el syllabus.
    - Verifica el orden y la coherencia de los temas con las demás clases.
    - Usa exclusivamente la información del syllabus como base.

    **Revisa antes de entregar la respuesta. No incluyas el historial en la respuesta, solo el nuevo contenido.**
    """

    # Generar contenido con el modelo
    material = model.generate_content(prompt)

    # Imprimir la salida para verificar si es repetida
    print(f"Material generado para el módulo {module_num}:\n", material.text)

    # Generar resumen del material
    resumen = model.generate_content("Resume el siguiente texto sin perder información clave:\n" + material.text)

    # Convertir a PDF
    output_name = "material_modulo_{}.pdf".format(module_num)
    convert_to_pdf(material.text, output_name)

    return material, resumen

def crear_materiales(model, data_json):
    history = ""  # Ya no es necesario usarlo en la generación

    for i in range(len(data_json["modules"])):
        _, resumen = crear_material_clase_i(model, i, data_json)  # Pasamos data_json como dict

        # Si aún quieres acumular el resumen, puedes hacerlo sin que afecte la generación de contenido
        if resumen and resumen.text.strip():
            history += "\n" + resumen.text.strip()

    return history

def crear_material_clase(model, modulo_info, modulo_num, clase_num, total_clases, semanas_curso, clases_semana, previous_classes_summaries=""):
    """
    Genera el material para una clase específica con prompts optimizados
    """
    # Prompt base con información esencial
    prompt_base = f"""Eres un desarrollador experto de contenido educativo.

    ### Contexto del Curso
    - Duración: {semanas_curso} semanas, {clases_semana} clases por semana
    - Módulo actual ({modulo_num}) dividido en {total_clases} clases
    - Esta es la clase {clase_num} de {total_clases} para este módulo

    ### Instrucciones
    Genera el material detallado para la clase {clase_num} del módulo {modulo_num}, incluyendo:
    1. Título de la clase
    2. Objetivos específicos
    3. Contenido teórico detallado
    4. Ejemplos o casos de estudio
    5. Actividades prácticas con sus respectivas soluciones
    6. Materiales complementarios"""

    # Extraer solo la información esencial del módulo
    modulo_info_simplificado = {
        "title": modulo_info.get("title", ""),
        "description": modulo_info.get("description", ""),
        "topics": modulo_info.get("topics", [])
    }

    # Primer paso: obtener estructura general de la clase
    primer_prompt = f"""{prompt_base}

    ### Información del módulo
    {json.dumps(modulo_info_simplificado, indent=2)}

    Primero, proporciona solo un esquema detallado con los temas principales
    que deberías cubrir en esta clase específica."""

    esquema = model.generate_content(primer_prompt)

    # Solo enviar resúmenes relevantes para mantener contexto
    resumenes_relevantes = ""
    if previous_classes_summaries:
        # Extraer solo los últimos resúmenes si hay muchos
        resumenes_split = previous_classes_summaries.split("Resumen de la clase")
        if len(resumenes_split) > 3:  # Si hay más de 3 resúmenes
            resumenes_relevantes = "Resumen de la clase".join(resumenes_split[-3:])
        else:
            resumenes_relevantes = previous_classes_summaries

    # Segundo paso: generar el contenido completo basado en el esquema
    segundo_prompt = f"""{prompt_base}

    ### Información del módulo
    {json.dumps(modulo_info_simplificado, indent=2)}

    ### Esquema aprobado
    {esquema.text}

    ### Contexto de clases anteriores
    {resumenes_relevantes}

    Desarrolla ahora el contenido completo siguiendo este esquema,
    asegurando continuidad con las clases anteriores."""

    material = model.generate_content(segundo_prompt)

    # Generar resumen de la clase para mantener coherencia (prompt corto)
    resumen_prompt = "Resume en 150 palabras los puntos clave tratados en la siguiente clase:\n" + material.text[:2000]  # Limitamos a los primeros 2000 caracteres para el resumen
    resumen = model.generate_content(resumen_prompt)

    # Convertir a HTML y PDF
    output_name = f"material_modulo_{modulo_num}_clase_{clase_num}.pdf"
    convert_to_pdf(material.text, output_name)

    return material, resumen.text

def crear_materiales_modulo(model, modulo_info, modulo_idx, semanas_curso, clases_semana):
    """
    Genera los materiales para todas las clases de un módulo
    """
    # Calcular el número de clases para este módulo
    total_modulos = len(data_json["modules"])
    total_clases_curso = semanas_curso * clases_semana

    # Distribuir clases de manera proporcional entre módulos
    clases_por_modulo = max(1, round(total_clases_curso / total_modulos))

    # Asegurar que los módulos más importantes tengan al menos 2 clases si es posible
    if modulo_idx < (total_clases_curso % total_modulos):
        clases_por_modulo += 1

    # Limitamos a máximo 6 clases por módulo como solicitado
    clases_por_modulo = min(clases_por_modulo, 6)

    print(f"Generando {clases_por_modulo} clases para el módulo {modulo_idx+1}")

    # Para mantener coherencia entre clases
    previous_classes_summaries = ""

    # Generar cada clase del módulo
    for clase_num in range(1, clases_por_modulo + 1):
        print(f"Generando clase {clase_num} de {clases_por_modulo} del módulo {modulo_idx+1}...")

        material, resumen = crear_material_clase(
            model,
            modulo_info,
            modulo_idx + 1,
            clase_num,
            clases_por_modulo,
            semanas_curso,
            clases_semana,
            previous_classes_summaries
        )

        # Agregar resumen de esta clase para las siguientes
        previous_classes_summaries += f"\n\nResumen de la clase {clase_num}:\n{resumen}"

    return previous_classes_summaries

def crear_todos_materiales(model, data_json, semanas_curso=16, clases_semana=2):
    """
    Genera los materiales para todos los módulos del curso
    """
    all_summaries = ""

    for i, modulo in enumerate(data_json["modules"]):
        print(f"\n--- GENERANDO MÓDULO {i+1} ---")
        modulo_summaries = crear_materiales_modulo(
            model,
            modulo,
            i,
            semanas_curso,
            clases_semana
        )
        all_summaries += f"\n\n--- RESUMEN MÓDULO {i+1} ---\n{modulo_summaries}"

        # Guardar resúmenes después de cada módulo en caso de error
        with open(f"resumen_modulo_{i+1}.txt", "w", encoding="utf-8") as f:
            f.write(modulo_summaries)

    # Documento final con todos los resúmenes
    with open("resumen_curso_completo.txt", "w", encoding="utf-8") as f:
        f.write(all_summaries)

    return all_summaries

# %% [markdown]
# # Ejecución principal

# %%
# Obtener información
path = "/content/drive/MyDrive/Trabajo4/programas_materias/Evaluación humana/Programa Calidad de Software.docx"
document_text = extract_text_from_file(path)

# %%
# Obtener respuesta
prompt = f"{initial_prompt}\n{document_text}"
response = model.generate_content(prompt)

# %%
# Convertir respuesta a pdf
convert_to_pdf(response.text, "materiales_curso.pdf")

# %%
# Obtener data_json
data_json = get_json(response)

# %%
data_json
# Out:
# {'course_title': 'Calidad del Software',
#  'course_description': 'Este curso proporciona una comprensión completa de los conceptos, procesos y prácticas necesarias para garantizar la calidad en el desarrollo de software.  Se utilizarán dos libros de texto principales: Software Quality Assurance de Claude Y. Laporte y Introduction to Software Quality de Gerard O’Regan.',
#  'modules': [{'module_title': 'Introducción a la Calidad del Software',
#    'module_num': '1',
#    'objectives': ['Comprender la importancia de la calidad del software.',
#     'Definir la calidad del software desde diferentes perspectivas.',
#     'Identificar los factores que influyen en la calidad del software.',
#     'Presentar el alcance del curso y los objetivos generales.'],
#    'content_outline': 'Definiciones de calidad del software, impacto de la calidad en el desarrollo, factores que influyen en la calidad, introducción a las métricas de calidad, visión general del curso.',
#    'class_notes': {'class_num': '1',
#     'introduction': 'La calidad del software es esencial para el éxito de cualquier proyecto de software.  Impacta la satisfacción del cliente, los costos de desarrollo y mantenimiento, y la reputación de la empresa. Esta clase introduce los conceptos fundamentales de la calidad del software y su importancia en el ciclo de vida del desarrollo.',
#     'theory': "La calidad del software se define como el grado en que un producto de software cumple con los requisitos especificados y las necesidades implícitas del usuario. Factores clave incluyen: Funcionalidad, Fiabilidad, Usabilidad, Eficiencia, Mantenibilidad, Portabilidad.  Claude Y. Laporte define la calidad del software como (según su libro Software Quality Assurance) el grado en que un producto de software cumple con los requisitos especificados y las necesidades implícitas del usuario.  Gerard O'Regan (Introduction to Software Quality) destaca la importancia de la gestión de la calidad en todo el ciclo de vida del desarrollo de software.  El estándar ISO/IEC 25010 proporciona un modelo de calidad del producto que define características de calidad y subcaracterísticas.",
#     'challenges': [{'question': '¿Por qué es importante invertir en la calidad del software al inicio de un proyecto?',
#       'solution': 'Invertir en calidad al inicio reduce costos a largo plazo, previene defectos costosos de corregir, y mejora la satisfacción del cliente. Permite una mejor planificación y diseño, minimizando errores desde la concepción del proyecto.',
#       'type': 'practice_problem'},
#      {'question': 'Discute las diferentes perspectivas de calidad del software (desde el punto de vista del desarrollador, del cliente y del gerente del proyecto).',
#       'type': 'discussion_question'}]}},
#   {'module_title': 'Fundamentos de la Calidad',
#    'module_num': '2',
#    'objectives': ['Entender los principios básicos de la gestión de la calidad.',
#     'Conocer las diferentes filosofías de calidad (Deming, Juran, Crosby).',
#     'Aplicar los conceptos de mejora continua a la calidad del software.',
#     'Analizar el ciclo de vida de la calidad del software'],
#    'content_outline': 'Principios de gestión de la calidad, filosofías de Deming, Juran y Crosby, mejora continua (PDCA), ciclo de vida de la calidad del software, costes de la calidad.',
#    'class_notes': {'class_num': '2',
#     'introduction': 'Esta clase profundiza en los fundamentos teóricos de la calidad, explorando las filosofías de los gurús de la calidad y su aplicación al desarrollo de software. Se analiza el ciclo de vida de la calidad y la importancia de la mejora continua.',
#     'theory': "W. Edwards Deming enfatizó la importancia de la mejora continua y el control estadístico de procesos (SPC). Joseph M. Juran se centró en la gestión de la calidad a través de la planificación, el control y la mejora. Philip Crosby promovió el concepto de 'cero defectos' y la importancia de la prevención.  El ciclo de vida de la calidad del software incluye: Planificación, Aseguramiento de la Calidad (QA), Control de Calidad (QC), Mejora.  Laporte y O'Regan cubren estos fundamentos en detalle, proporcionando una base sólida para la gestión de la calidad del software.",
#     'challenges': [{'question': 'Explica cómo aplicar el ciclo PDCA (Plan, Do, Check, Act) a la mejora de la calidad del software.',
#       'solution': 'Plan: Identificar áreas de mejora y definir objetivos. Do: Implementar cambios o soluciones. Check: Evaluar los resultados y medir el impacto. Act: Estandarizar las mejoras o realizar ajustes adicionales. Por ejemplo, Plan: reducir el número de defectos en el código, Do: implementar revisiones de código más rigurosas, Check: medir la cantidad de defectos encontrados después de las revisiones, Act: si hay una disminución significativa, formalizar el proceso de revisión de código.',
#       'type': 'practice_problem'},
#      {'question': 'Compara y contrasta las filosofías de calidad de Deming, Juran y Crosby. ¿Cuál crees que es más aplicable al desarrollo de software moderno?',
#       'type': 'discussion_question'}]}},
#   {'module_title': 'Requisitos de Calidad del Software',
#    'module_num': '3',
#    'objectives': ['Identificar y documentar requisitos de calidad del software.',
#     'Comprender la relación entre requisitos funcionales y no funcionales.',
#     'Utilizar diferentes técnicas para la elicitation de requisitos de calidad.',
#     'Priorizar los requisitos de calidad en función de su impacto.'],
#    'content_outline': 'Definición de requisitos de calidad, requisitos funcionales vs. no funcionales, técnicas de elicitation, priorización de requisitos, atributos de calidad ISO/IEC 25010.',
#    'class_notes': {'class_num': '3',
#     'introduction': 'Los requisitos de calidad son cruciales para asegurar que el software cumpla con las expectativas del usuario. Esta clase se centra en la identificación, documentación y priorización de los requisitos de calidad, incluyendo la diferenciación entre requisitos funcionales y no funcionales.',
#     'theory': "Los requisitos funcionales describen lo que el software debe hacer. Los requisitos no funcionales describen cómo debe hacerlo, incluyendo atributos de calidad como: Rendimiento, Seguridad, Usabilidad, Fiabilidad, Mantenibilidad, Portabilidad. Técnicas de Elicitation: Entrevistas, Sesiones de Lluvia de Ideas, Prototipos, Casos de Uso. Priorización de Requisitos: Método MoSCoW (Must have, Should have, Could have, Won't have).  El estándar ISO/IEC 25010 define atributos de calidad clave que deben considerarse al especificar los requisitos de calidad del software.  Tanto Laporte como O'Regan proporcionan ejemplos prácticos y metodologías para la elicitation y especificación de requisitos de calidad.",
#     'challenges': [{'question': 'Da ejemplos de requisitos funcionales y no funcionales para una aplicación bancaria online.',
#       'solution': 'Funcionales: Permitir al usuario ver el saldo de su cuenta. No funcionales: La aplicación debe responder en menos de 2 segundos. Funcionales: Permitir la transferencia de fondos entre cuentas. No funcionales: La aplicación debe ser segura y proteger la información del usuario.',
#       'type': 'practice_problem'},
#      {'question': '¿Cómo se puede priorizar los requisitos de calidad en un proyecto de software con recursos limitados?',
#       'type': 'discussion_question'}]}}]}

# %%
# Obtener material
history_materiales = ""
history_materiales = crear_materiales(model,data_json)
# Out:
# Material generado para el módulo 1:
#  ## Módulo 1: Introducción a la Calidad del Software
#
# **Objetivos del Módulo:**
#
# *   Comprender la importancia de la calidad del software.
# *   Definir la calidad del software desde diferentes perspectivas.
# *   Identificar los factores que influyen en la calidad del software.
# *   Presentar el alcance del curso y los objetivos generales.
#
# **Contenido del Módulo:**
#
# *   Definiciones de calidad del software.
# *   Impacto de la calidad en el desarrollo.
# *   Factores que influyen en la calidad.
# *   Introducción a las métricas de calidad.
# *   Visión general del curso.
#
# **Clase 1**
#
# **Título:** Fundamentos de la Calidad del Software
#
# **Introducción:**
#
# La calidad del software es esencial para el éxito de cualquier proyecto de software. Impacta la satisfacción del cliente, los costos de desarrollo y mantenimiento, y la reputación de la empresa. Esta clase introduce los conceptos fundamentales de la calidad del software y su importancia en el ciclo de vida del desarrollo. Exploraremos diferentes definiciones, su impacto y los factores que contribuyen a ella.
#
# **Teoría:**
#
# La calidad del software se define como el grado en que un producto de software cumple con los requisitos especificados y las necesidades implícitas del usuario.  Esta definición, aparentemente simple, encierra una complejidad considerable. No se trata simplemente de que el software "funcione", sino de que funcione *bien* en el contexto para el que fue diseñado. Implica satisfacer necesidades explícitas (requisitos documentados) y necesidades implícitas (expectativas del usuario no siempre articuladas).
#
# Factores clave que definen la calidad del software incluyen:
#
# *   **Funcionalidad:** El grado en que el software realiza las funciones deseadas. Esto incluye la corrección, integridad, seguridad y adecuación de las funciones.
# *   **Fiabilidad:** La capacidad del software para mantener un nivel de rendimiento especificado bajo condiciones establecidas durante un período de tiempo determinado. Se relaciona con la madurez, tolerancia a fallos, recuperabilidad y disponibilidad del sistema.
# *   **Usabilidad:** Facilidad con la que los usuarios pueden aprender a usar, operar y ser atraídos por el software.  Implica la comprensibilidad, facilidad de aprendizaje, operabilidad, atractivo y conformidad con los estándares de usabilidad.
# *   **Eficiencia:**  El rendimiento del software en términos de recursos utilizados (tiempo de procesamiento, memoria, ancho de banda de red).  Incluye el comportamiento temporal, la utilización de recursos y la capacidad.
# *   **Mantenibilidad:** La facilidad con la que el software puede ser modificado, corregido o adaptado a nuevos requisitos. Abarca la analizabilidad, modificabilidad, estabilidad y capacidad de prueba.
# *   **Portabilidad:** La capacidad del software para ser transferido de un entorno a otro (hardware, sistema operativo, etc.). Se relaciona con la adaptabilidad, facilidad de instalación, coexistencia y capacidad de reemplazo.
#
# Claude Y. Laporte define la calidad del software como (según su libro Software Quality Assurance) el grado en que un producto de software cumple con los requisitos especificados y las necesidades implícitas del usuario.  Gerard O'Regan (Introduction to Software Quality) destaca la importancia de la gestión de la calidad en todo el ciclo de vida del desarrollo de software.  El estándar ISO/IEC 25010 proporciona un modelo de calidad del producto que define características de calidad y subcaracterísticas. Este estándar ofrece un marco de referencia para evaluar la calidad desde diferentes perspectivas y en diferentes etapas del ciclo de vida del software.
#
# **Problemas Prácticos y Preguntas de Discusión:**
#
# 1.  **Pregunta:** ¿Por qué es importante invertir en la calidad del software al inicio de un proyecto?
#     **Solución:** Invertir en calidad al inicio reduce costos a largo plazo, previene defectos costosos de corregir, y mejora la satisfacción del cliente. Permite una mejor planificación y diseño, minimizando errores desde la concepción del proyecto. El costo de corregir un defecto aumenta exponencialmente a medida que avanza el ciclo de vida del desarrollo. Identificar y corregir un error en la fase de requerimientos es mucho más barato que hacerlo en la fase de pruebas o, peor aún, en producción. Además, un software de baja calidad puede dañar la reputación de la empresa y generar pérdida de clientes.
#
# 2.  **Pregunta:** Discute las diferentes perspectivas de calidad del software (desde el punto de vista del desarrollador, del cliente y del gerente del proyecto).
#     **Discusión:**
#     *   **Desarrollador:**  Podría enfocarse en la calidad del código, la adherencia a las mejores prácticas de programación, la eficiencia del algoritmo y la facilidad de mantenimiento.  Para el desarrollador, la calidad puede significar un código limpio, bien documentado y que cumpla con las especificaciones técnicas.
#     *   **Cliente:** Se preocupará por la funcionalidad, la usabilidad, la fiabilidad y el rendimiento.  El cliente busca un software que resuelva sus problemas de manera efectiva, sea fácil de usar y no presente fallos frecuentes.  La satisfacción del cliente es el principal indicador de calidad desde esta perspectiva.
#     *   **Gerente del Proyecto:** Se centrará en la gestión de riesgos, el cumplimiento del presupuesto y el cronograma, y la satisfacción del cliente.  Para el gerente, la calidad implica entregar un producto que cumpla con los requisitos dentro de las restricciones de tiempo y costo, minimizando riesgos y asegurando la satisfacción del cliente.  La gestión de la calidad es un aspecto clave para el éxito del proyecto.
#
# Material generado para el módulo 2:
#  ## Módulo 2: Fundamentos de la Calidad
#
# **Objetivos:**
#
# *   Entender los principios básicos de la gestión de la calidad.
# *   Conocer las diferentes filosofías de calidad (Deming, Juran, Crosby).
# *   Aplicar los conceptos de mejora continua a la calidad del software.
# *   Analizar el ciclo de vida de la calidad del software.
#
# **Contenidos:**
#
# *   Principios de gestión de la calidad.
# *   Filosofías de Deming, Juran y Crosby.
# *   Mejora continua (PDCA).
# *   Ciclo de vida de la calidad del software.
# *   Costes de la calidad.
#
# ---
#
# **Clase 2: Fundamentos Teóricos de la Calidad y su Aplicación al Software**
#
# **Introducción:**
#
# Esta clase profundiza en los fundamentos teóricos de la calidad, explorando las filosofías de los gurús de la calidad y su aplicación al desarrollo de software. Se analiza el ciclo de vida de la calidad y la importancia de la mejora continua.
#
# **Teoría:**
#
# Los principios de gestión de la calidad se centran en la satisfacción del cliente, la mejora continua y la prevención de defectos.  A continuación, se exploran las filosofías de tres figuras clave en el desarrollo de la gestión de la calidad.
#
# *   **W. Edwards Deming:** Enfatizó la importancia de la mejora continua y el control estadístico de procesos (SPC). Deming propuso los 14 puntos para la gestión, un conjunto de principios para transformar las prácticas de gestión y mejorar la calidad y la productividad.  Su filosofía se centra en reducir la variación en los procesos a través de la aplicación de métodos estadísticos y la mejora continua basada en datos. El ciclo PDCA (Plan-Do-Check-Act) es fundamental en su enfoque.
#
# *   **Joseph M. Juran:** Se centró en la gestión de la calidad a través de la planificación, el control y la mejora, la "Trilogía de Juran". Juran identificó tres procesos gerenciales clave: la planificación de la calidad, el control de la calidad y el mejoramiento de la calidad. La planificación implica establecer los objetivos de calidad y los procesos para alcanzarlos. El control involucra la evaluación del desempeño real, la comparación con los objetivos y la toma de medidas correctivas. El mejoramiento se enfoca en la búsqueda de formas de mejorar la calidad de forma continua. A diferencia de Deming, Juran se centró más en la gestión y menos en el control estadístico de procesos, haciendo énfasis en la participación de la dirección en la mejora de la calidad.
#
# *   **Philip Crosby:** Promovió el concepto de "cero defectos" y la importancia de la prevención. Crosby definía la calidad como conformidad con los requisitos, enfatizando que la calidad se logra cuando los productos y servicios cumplen con las especificaciones. Su enfoque se basa en la prevención de errores en lugar de la detección y corrección.  A diferencia de Deming y Juran, Crosby no estaba de acuerdo con la aceptación de un "nivel aceptable de calidad". Para Crosby, el objetivo era cero defectos y la prevención era la clave.
#
# El **ciclo de vida de la calidad del software** incluye las siguientes etapas:
#
# 1.  **Planificación:** Definición de los estándares de calidad, métricas y procesos a seguir.
# 2.  **Aseguramiento de la Calidad (QA):** Actividades proactivas para prevenir defectos, como revisiones de código, pruebas unitarias y análisis estático.
# 3.  **Control de Calidad (QC):** Actividades reactivas para detectar defectos, como pruebas de integración, pruebas de sistema y pruebas de aceptación.
# 4.  **Mejora:** Análisis de los defectos encontrados y la implementación de acciones correctivas y preventivas para evitar que se repitan.  Esta etapa puede incluir la modificación de procesos, la capacitación del personal y la adopción de nuevas tecnologías.
#
# Laporte y O'Regan cubren estos fundamentos en detalle, proporcionando una base sólida para la gestión de la calidad del software.
#
# **Desafíos:**
#
# *   **Problema Práctico:** Explica cómo aplicar el ciclo PDCA (Plan, Do, Check, Act) a la mejora de la calidad del software.
#
#     *   **Solución:**
#         *   **Plan:** Identificar áreas de mejora y definir objetivos.  Por ejemplo, reducir el número de defectos críticos encontrados en las pruebas de aceptación del usuario (UAT). Definir métricas para medir el éxito (e.g., número de defectos críticos, tiempo de resolución de defectos).
#         *   **Do:** Implementar cambios o soluciones. Por ejemplo, implementar revisiones de código más rigurosas, mejorar los casos de prueba de UAT, o proporcionar capacitación adicional a los desarrolladores en áreas donde se están encontrando defectos con frecuencia.
#         *   **Check:** Evaluar los resultados y medir el impacto. Por ejemplo, medir la cantidad de defectos críticos encontrados después de las revisiones de código o los cambios en los casos de prueba de UAT. Comparar los resultados con las métricas definidas en la fase de Planificación.
#         *   **Act:** Estandarizar las mejoras o realizar ajustes adicionales. Si hay una disminución significativa en el número de defectos, formalizar el proceso de revisión de código o los cambios en las pruebas de UAT.  Si los resultados no son satisfactorios, identificar las causas raíz y ajustar el plan.  Este paso asegura la institucionalización de las mejoras y el aprendizaje continuo.
#
# *   **Pregunta de Discusión:** Compara y contrasta las filosofías de calidad de Deming, Juran y Crosby. ¿Cuál crees que es más aplicable al desarrollo de software moderno? Justifica tu respuesta. Considera aspectos como la agilidad, la velocidad de entrega y la complejidad de los proyectos de software actuales.
#
# Material generado para el módulo 3:
#  ## Módulo 3: Requisitos de Calidad del Software
#
# **Objetivos del Módulo:**
#
# *   Identificar y documentar requisitos de calidad del software.
# *   Comprender la relación entre requisitos funcionales y no funcionales.
# *   Utilizar diferentes técnicas para la elicitation de requisitos de calidad.
# *   Priorizar los requisitos de calidad en función de su impacto.
#
# **Contenido del Módulo:**
#
# *   Definición de requisitos de calidad.
# *   Requisitos funcionales vs. no funcionales.
# *   Técnicas de elicitation.
# *   Priorización de requisitos.
# *   Atributos de calidad ISO/IEC 25010.
#
# ---
#
# ### Clase 3: Requisitos de Calidad del Software
#
# **Introducción:**
#
# Los requisitos de calidad son cruciales para asegurar que el software cumpla con las expectativas del usuario. Esta clase se centra en la identificación, documentación y priorización de los requisitos de calidad, incluyendo la diferenciación entre requisitos funcionales y no funcionales. Una clara comprensión de estos requisitos es fundamental para el éxito de cualquier proyecto de software.
#
# **Teoría:**
#
# **Requisitos Funcionales vs. No Funcionales:**
#
# Es vital comprender la diferencia fundamental entre los requisitos funcionales y no funcionales, ya que ambos son indispensables para la construcción de un software exitoso.
#
# *   **Requisitos Funcionales:** Describen *lo que* el software debe hacer.  Estos requisitos se centran en las funcionalidades específicas que el sistema debe proporcionar al usuario.  Ejemplos incluyen la capacidad de un usuario de iniciar sesión, realizar una búsqueda, generar un informe, etc.  La documentación de los requisitos funcionales a menudo se presenta en forma de casos de uso o historias de usuario.
#
# *   **Requisitos No Funcionales:** Describen *cómo* el software debe hacerlo.  Estos requisitos imponen restricciones sobre el diseño y la implementación del sistema y se refieren a atributos de calidad. Incluyen:
#
#     *   **Rendimiento:** Tiempo de respuesta, throughput (tasa de procesamiento), uso de recursos (CPU, memoria).  Ejemplo: "El sistema debe poder procesar 1000 transacciones por segundo".
#     *   **Seguridad:** Confidencialidad, integridad, disponibilidad, autenticación, autorización.  Ejemplo: "Solo los usuarios autorizados deben poder acceder a los datos de la base de datos".
#     *   **Usabilidad:** Facilidad de uso, facilidad de aprendizaje, accesibilidad.  Ejemplo: "El sistema debe ser intuitivo y fácil de usar para usuarios sin experiencia técnica".
#     *   **Fiabilidad:** Disponibilidad, tiempo medio entre fallos (MTBF), tolerancia a fallos. Ejemplo: "El sistema debe estar disponible el 99.99% del tiempo".
#     *   **Mantenibilidad:** Facilidad de modificación, facilidad de corrección de errores, facilidad de adaptación a nuevos requisitos.  Ejemplo: "El código debe estar bien documentado y modular para facilitar las modificaciones futuras".
#     *   **Portabilidad:** Facilidad de adaptación a diferentes plataformas (sistemas operativos, navegadores, dispositivos). Ejemplo: "El sistema debe poder ejecutarse en Windows, Linux y macOS".
#
# **Técnicas de Elicitation:**
#
# La elicitation de requisitos es el proceso de descubrir, recopilar, documentar y validar las necesidades del usuario y las partes interesadas para un sistema de software. Elegir la técnica correcta depende del proyecto y sus stakeholders.
#
# *   **Entrevistas:** Conversaciones estructuradas o no estructuradas con las partes interesadas para comprender sus necesidades y expectativas. Permiten obtener información detallada y aclarar dudas.
# *   **Sesiones de Lluvia de Ideas:** Reuniones en las que las partes interesadas generan ideas libremente para identificar posibles requisitos. Fomentan la creatividad y la colaboración.
# *   **Prototipos:** Creación de versiones preliminares del software para que las partes interesadas puedan interactuar con él y proporcionar feedback.  Permiten visualizar el sistema y detectar problemas de usabilidad o funcionalidad.
# *   **Casos de Uso:** Descripciones detalladas de cómo los usuarios interactúan con el sistema para lograr un objetivo específico.  Ayudan a comprender los requisitos funcionales desde la perspectiva del usuario.
#
# **Priorización de Requisitos:**
#
# La priorización es fundamental debido a las limitaciones de tiempo, presupuesto y recursos.
#
# *   **Método MoSCoW (Must have, Should have, Could have, Won't have):** Una técnica sencilla y popular para clasificar los requisitos en función de su importancia.
#
#     *   **Must have (Debe tener):** Requisitos críticos para el éxito del proyecto; el sistema no puede funcionar sin ellos.
#     *   **Should have (Debería tener):** Requisitos importantes, pero el sistema puede funcionar sin ellos (aunque con algunas limitaciones).
#     *   **Could have (Podría tener):** Requisitos deseables, pero no esenciales; su implementación depende de los recursos disponibles.
#     *   **Won't have (No tendrá):** Requisitos que no se implementarán en esta versión del sistema, pero podrían considerarse en futuras versiones.
#
# **Atributos de Calidad ISO/IEC 25010:**
#
# El estándar ISO/IEC 25010 proporciona un modelo de calidad del producto de software que define una serie de atributos de calidad clave. Este estándar  ayuda a asegurar una definición completa y consistente de los requisitos de calidad:
#
# *   **Calidad en Uso:**  Mide la medida en que un producto utilizado por usuarios específicos logra objetivos específicos con efectividad, eficiencia, satisfacción y ausencia de riesgo en un contexto de uso específico.
# *   **Calidad del Producto:**  Divide la calidad del producto en 8 características:
#     *   **Adecuación funcional:** El grado en que el producto satisface las necesidades declaradas e implícitas cuando se utiliza en condiciones específicas.
#     *   **Eficiencia de desempeño:** El rendimiento relativo a la cantidad de recursos utilizados en condiciones declaradas.
#     *   **Compatibilidad:** El grado en que un producto puede intercambiar información con otros productos.
#     *   **Usabilidad:** El grado en que un producto puede ser utilizado por usuarios específicos para lograr objetivos específicos con eficacia, eficiencia y satisfacción en un contexto de uso específico.
#     *   **Fiabilidad:** El grado en que un producto desempeña funciones especificadas bajo condiciones especificadas durante un período de tiempo específico.
#     *   **Seguridad:**  El grado en que un producto protege la información y los datos de modo que personas o sistemas no autorizados no puedan leerla ni modificarla, y sin negar el acceso a las personas o sistemas autorizados.
#     *   **Mantenibilidad:** El grado en que un producto puede ser modificado. Las modificaciones pueden incluir correcciones, mejoras o adaptación del software a entornos, requisitos y especificaciones de funciones cambiantes.
#     *   **Portabilidad:** El grado en que un producto puede ser transferido de un entorno a otro.
#
# **Desafíos:**
#
# *   Es importante destacar que tanto Laporte como O'Regan proporcionan ejemplos prácticos y metodologías para la elicitation y especificación de requisitos de calidad.
#
# **Preguntas y Problemas:**
#
# *   **Ejemplo Práctico:**
#
#     *   **Pregunta:** Da ejemplos de requisitos funcionales y no funcionales para una aplicación bancaria online.
#     *   **Solución:**
#         *   Funcionales: Permitir al usuario ver el saldo de su cuenta. No funcionales: La aplicación debe responder en menos de 2 segundos.
#         *   Funcionales: Permitir la transferencia de fondos entre cuentas. No funcionales: La aplicación debe ser segura y proteger la información del usuario.
#
# *   **Pregunta de Discusión:** ¿Cómo se puede priorizar los requisitos de calidad en un proyecto de software con recursos limitados?

# %%
semanas_curso = 16
clases_semana = 2

history = crear_todos_materiales(model, data_json, semanas_curso, clases_semana)
# Out:
# --- GENERANDO MÓDULO 1 ---
# Generando 6 clases para el módulo 1
# Generando clase 1 de 6 del módulo 1...
# Generando clase 2 de 6 del módulo 1...
# Generando clase 3 de 6 del módulo 1...
# [WARNING] Missing character: There is no π (U+03C0) (U+03C0) in font Latin Modern Roman 10 Regular
#
# WARNING:pypandoc:Missing character: There is no π (U+03C0) (U+03C0) in font Latin Modern Roman 10 Regular
# Generando clase 4 de 6 del módulo 1...
# Generando clase 5 de 6 del módulo 1...
# Generando clase 6 de 6 del módulo 1...
#
# --- GENERANDO MÓDULO 2 ---
# Generando 6 clases para el módulo 2
# Generando clase 1 de 6 del módulo 2...
# Generando clase 2 de 6 del módulo 2...
# Generando clase 3 de 6 del módulo 2...
# Generando clase 4 de 6 del módulo 2...
# Generando clase 5 de 6 del módulo 2...
# Generando clase 6 de 6 del módulo 2...
#
# --- GENERANDO MÓDULO 3 ---
# Generando 6 clases para el módulo 3
# Generando clase 1 de 6 del módulo 3...
# Generando clase 2 de 6 del módulo 3...
# Generando clase 3 de 6 del módulo 3...
# Generando clase 4 de 6 del módulo 3...
# Generando clase 5 de 6 del módulo 3...
# Generando clase 6 de 6 del módulo 3...

# %% [markdown]
# # Marco de evaluación

# %%
# !pip install textstat
# Out:
# Requirement already satisfied: textstat in /usr/local/lib/python3.11/dist-packages (0.7.5)
# Requirement already satisfied: pyphen in /usr/local/lib/python3.11/dist-packages (from textstat) (0.17.2)
# Requirement already satisfied: cmudict in /usr/local/lib/python3.11/dist-packages (from textstat) (1.0.32)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from textstat) (75.1.0)
# Requirement already satisfied: importlib-metadata>=5 in /usr/local/lib/python3.11/dist-packages (from cmudict->textstat) (8.6.1)
# Requirement already satisfied: importlib-resources>=5 in /usr/local/lib/python3.11/dist-packages (from cmudict->textstat) (6.5.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=5->cmudict->textstat) (3.21.0)

# %% [markdown]
# ## Evaluación Automatizada

# %% [markdown]
# ### Métricas de relevancia de contenido

# %% [markdown]
# Usando TF-IDF se evalúa la similitud entre el contenido generado y los temas del programa del curso usando la similitud del coseno. Se espera un resultado entre 50 y 80 para ser considerado aceptable y mayor a 80 para ser considerado excelente:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def evaluar_relevancia(contenido_generado, data_json):

    temas_programa = " ".join([
        mod["content_outline"] + " " + " ".join(mod["objectives"])
        for mod in data_json["modules"]
    ])

    vectorizer = TfidfVectorizer()
    tfidf_matriz = vectorizer.fit_transform([contenido_generado, temas_programa])
    score = cosine_similarity(tfidf_matriz[0], tfidf_matriz[1])[0][0]

    return score

# %% [markdown]
# ### Verificación de consistencia

# %% [markdown]
# Para verificar la consistencia se hace uso del resultado obtenido en la evaluación de relevancia de manera que se pueda saber si la información que se generó es coherente para cada una de las clases y módulos. Así, si un módulo repite mucha información que ya estaba en el anterior, se considera redundante y por ende inconsistente:

# %%
def evaluar_consistencia(modulos_generados):

    inconsistencias = []

    for i in range(len(modulos_generados) - 1):
        similitud = evaluar_relevancia(modulos_generados[i]["class_notes"]["theory"], {"modules": [modulos_generados[i+1]]})
        if similitud > 0.85:
            inconsistencias.append(f"Inconsistencia detectada entre Módulo {modulos_generados[i]['module_num']} y {modulos_generados[i+1]['module_num']}")

    return inconsistencias if inconsistencias else "Todos los módulos son consistentes"

# %% [markdown]
# ### Puntuaciones de legibilidad

# %% [markdown]
# Se mide qué tan comprensible es el texto obtenido calculando el Índice de Flesh-Kincaid, el cual se basa en la longitud de las oraciones y el número promedio de sílabas por palabra. De acuerdo con este índice, mientras más cortas sean las frases y las palabras, el texto es más fácil de entender. Debido a que estamos trabajando con clases universitarias, se espera un índice entre 30 y 70 dependiendo del curso:

# %%
import textstat

def evaluar_legibilidad(texto):

    indice = textstat.flesch_reading_ease(texto)

    return indice

# %% [markdown]
# ### Análisis del uso de terminología específica del dominio

# %% [markdown]
# Se evalúa el uso apropiado de la terminología por medio de una comparación con un diccionario de términos obtenido del programa del curso. De esta manera, se cuentan cuántas de estas palabras claves usadas en el programa aparencen en el contenido generado. El resultado esperado es un valor entre 50 y 80 para ser considerado aceptable y mayor a 80 para ser considerado excelente:

# %%
def evaluar_terminologia(contenido_generado, data_json):

    terminos_clave = set()

    for mod in data_json["modules"]:
        terminos_clave.update(mod["objectives"])
        terminos_clave.update(mod["content_outline"].split())
    terminos_usados = [termino for termino in terminos_clave if termino.lower() in contenido_generado.lower()]

    return len(terminos_usados) / len(terminos_clave) if terminos_clave else 0

# %% [markdown]
# ### **Interpretación de resultados**

# %%
def evaluar_material_generado(data_json):

    resultados = []

    inconsistencias = evaluar_consistencia(data_json["modules"])

    for mod in data_json["modules"]:

        theory_content = mod["class_notes"].get("theory", "")
        retos = mod["class_notes"].get("challenges", [])
        pregunta = " ".join([ch.get("question", "") for ch in retos])
        solucion = " ".join([ch.get("solution", "") for ch in retos if "solution" in ch])

        contenido = theory_content + " " + pregunta + " " + solucion

        relevancia = evaluar_relevancia(contenido, data_json)
        legibilidad = evaluar_legibilidad(contenido)
        terminologia = evaluar_terminologia(contenido, data_json)

        resultados.append({
            "module_num": mod["module_num"],
            "Relevancia": relevancia,
            "Legibilidad": legibilidad,
            "Uso de Terminología": terminologia
        })

    return {
        "resultados": resultados,
        "inconsistencias": inconsistencias
    }

evaluacion = evaluar_material_generado(data_json)

# %%
evaluacion
# Out:
# {'resultados': [{'module_num': '1',
#    'Relevancia': 0.6928527232957675,
#    'Legibilidad': 25.49,
#    'Uso de Terminología': 0.2833333333333333},
#   {'module_num': '2',
#    'Relevancia': 0.7306844324934806,
#    'Legibilidad': 38.52,
#    'Uso de Terminología': 0.35},
#   {'module_num': '3',
#    'Relevancia': 0.6711319046865591,
#    'Legibilidad': 23.73,
#    'Uso de Terminología': 0.2833333333333333}],
#  'inconsistencias': 'Todos los módulos son consistentes'}

# %% [markdown]
# ## Evaluación Humana
