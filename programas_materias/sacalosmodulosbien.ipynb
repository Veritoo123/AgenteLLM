# %% [markdown]
# Ejemplo invocación Gemini
# En este notebook se muestra cómo trabajar con la API de Google Gemini.
#
# Universidad Nacional de Colombia
#
# Departamento de Ciencias de la Computación y de la Decisión
#
# Profesor Juan David Ospina
#
# Introducción a Redes Neuronales y Algoritmos Bioinspirados
#
# Semestre 2024-02
#
# Fecha: 26 de febrero de 2025

# %%
# %%capture
# !apt-get update
# !apt-get install pandoc # para usar markdown
# !apt-get install texlive-xetex # Toma un buen tiempo la instalación
# !pip install markdown2 # para usar markdown
# !pip install pypandoc # para usar markdown

# %%
# !pip install fitz
# Out:
# Collecting fitz
#   Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl.metadata (816 bytes)
# Collecting configobj (from fitz)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting configparser (from fitz)
#   Downloading configparser-7.1.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: httplib2 in /usr/local/lib/python3.11/dist-packages (from fitz) (0.22.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (from fitz) (5.3.2)
# Collecting nipype (from fitz)
#   Downloading nipype-1.9.2-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fitz) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from fitz) (2.2.2)
# Collecting pyxnat (from fitz)
#   Downloading pyxnat-1.6.3-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from fitz) (1.13.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2->fitz) (3.2.1)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel->fitz) (6.5.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from nibabel->fitz) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel->fitz) (4.12.2)
# Requirement already satisfied: click>=6.6.0 in /usr/local/lib/python3.11/dist-packages (from nipype->fitz) (8.1.8)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.11/dist-packages (from nipype->fitz) (3.4.2)
# Collecting prov>=1.5.2 (from nipype->fitz)
#   Downloading prov-2.0.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pydot>=1.2.3 in /usr/local/lib/python3.11/dist-packages (from nipype->fitz) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.2 in /usr/local/lib/python3.11/dist-packages (from nipype->fitz) (2.8.2)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting simplejson>=3.8.0 (from nipype->fitz)
#   Downloading simplejson-3.20.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting traits>=6.2 (from nipype->fitz)
#   Downloading traits-7.0.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: filelock>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from nipype->fitz) (3.17.0)
# Collecting acres (from nipype->fitz)
#   Downloading acres-0.3.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting etelemetry>=0.3.1 (from nipype->fitz)
#   Downloading etelemetry-0.3.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting looseversion!=1.2 (from nipype->fitz)
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting puremagic (from nipype->fitz)
#   Downloading puremagic-1.28-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->fitz) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->fitz) (2025.1)
# Requirement already satisfied: lxml>=4.3 in /usr/local/lib/python3.11/dist-packages (from pyxnat->fitz) (5.3.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from pyxnat->fitz) (2.32.3)
# Requirement already satisfied: pathlib>=1.0 in /usr/local/lib/python3.11/dist-packages (from pyxnat->fitz) (1.0.1)
# Collecting ci-info>=0.2 (from etelemetry>=0.3.1->nipype->fitz)
#   Downloading ci_info-0.3.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-6.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.2->nipype->fitz) (1.17.0)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=5.0.0->nipype->fitz)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->pyxnat->fitz) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->pyxnat->fitz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->pyxnat->fitz) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->pyxnat->fitz) (2025.1.31)
# Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl (20 kB)
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Downloading configparser-7.1.0-py3-none-any.whl (17 kB)
# Downloading nipype-1.9.2-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 60.2 MB/s eta 0:00:00
# Downloading pyxnat-1.6.3-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 kB 9.9 MB/s eta 0:00:00
# Downloading etelemetry-0.3.1-py3-none-any.whl (6.4 kB)
# Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Downloading prov-2.0.1-py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 35.0 MB/s eta 0:00:00
# Downloading rdflib-6.3.2-py3-none-any.whl (528 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.1/528.1 kB 41.2 MB/s eta 0:00:00
# Downloading simplejson-3.20.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 14.6 MB/s eta 0:00:00
# Downloading traits-7.0.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 110.1 MB/s eta 0:00:00
# Downloading acres-0.3.0-py3-none-any.whl (10 kB)
# Downloading puremagic-1.28-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.9 MB/s eta 0:00:00
# Downloading ci_info-0.3.0-py3-none-any.whl (7.8 kB)
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: puremagic, looseversion, traits, simplejson, isodate, configparser, configobj, ci-info, acres, rdflib, pyxnat, etelemetry, prov, nipype, fitz
# Successfully installed acres-0.3.0 ci-info-0.3.0 configobj-5.0.9 configparser-7.1.0 etelemetry-0.3.1 fitz-0.0.1.dev2 isodate-0.6.1 looseversion-1.3.0 nipype-1.9.2 prov-2.0.1 puremagic-1.28 pyxnat-1.6.3 rdflib-6.3.2 simplejson-3.20.1 traits-7.0.2

# %%
# !pip install --upgrade pymupdf
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.25.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.25.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 115.1 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.25.3

# %%
import os
from google.colab import userdata
from markdown2 import markdown
import pypandoc

#os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

import google.generativeai as genai

# %%
import fitz  # PyMuPDF para leer PDFs
import google.generativeai as genai

# Configura la API de Gemini (sustituye con tu clave)
genai.configure(api_key="AIzaSyAooWfS3xzumCHk4xw4lMjl2yGdcoj3sog")
model = genai.GenerativeModel('gemini-2.0-flash-001')

initial_prompt = """
Eres un desarrollador experto de contenido educativo con amplia experiencia en la creación de materiales de cursos universitarios. Posees un profundo conocimiento en principios pedagógicos, diseño curricular y redacción académica. Tu tarea es ayudar a desarrollar un agente inteligente basado en modelos de lenguaje (LLM) que, a partir de un plan de estudios (syllabus), genere materiales educativos integrales que cumplan con altos estándares académicos.

Contexto y Objetivos
El agente debe:

Analizar y Comprender el Syllabus:

Extraer los componentes esenciales (objetivos, competencias, temáticas, metodologías, evaluaciones, etc.).
Identificar puntos clave para la generación de contenido pedagógico.
Generar Materiales Educativos:

Elaborar módulos detallados para cada tema o área, definiendo objetivos, contenidos, actividades y evaluaciones.
Crear notas de clase comprensivas que expliquen en profundidad cada módulo, incluyendo ejemplos, explicaciones teóricas y prácticos retos para el estudiante.
Mantener un alto rigor académico, asegurando la confiabilidad de la información y la integración de buenas prácticas pedagógicas.
Formato de Salida Específico:

Toda la salida generada debe estructurarse en formato JSON.
La estructura JSON debe incluir secciones claras para módulos y notas de clase.
Ejemplo de formato JSON:

{
  "course_title": "Título del Curso",
  "modules": [
    {
      "module_title": "Título del Módulo 1",
      "objectives": ["Objetivo 1", "Objetivo 2"],
      "module_num": "1",
      "content_outline": "Resumen de contenidos",
      "class_notes": {
        "class_num": "1",
        "introduction": "Introducción detallada del tema",
        "theory": "Desarrollo teórico con explicaciones y ejemplos",
        "challenges": "Retos y actividades prácticas para el estudiante"
      }
    },
    {
      "module_title": "Título del Módulo 2",
      "objectives": ["Objetivo A", "Objetivo B"],
      "content_outline": "Resumen de contenidos",
      "class_notes": {
        "introduction": "Introducción al tema",
        "theory": "Explicaciones teóricas y casos de estudio",
        "challenges": "Ejercicios y retos para aplicar lo aprendido"
      }
    }
  ]
}


SYLLABUS:
"""

# Función para extraer texto de un PDF
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = "\n".join([page.get_text() for page in doc])  # Extrae el texto de todas las páginas
    return text


# Cargar el PDF y extraer el texto
pdf_path = "/content/1503714_Desarrollo_Económico - firmado.pdf"  # Cambia por tu archivo
document_text = extract_text_from_pdf(pdf_path)

# %%
prompt = f"{initial_prompt}\n{document_text}"



response = model.generate_content(prompt)

# %%
# Convertir el texto en un PDF

# Resultado del promt
text = response.text

# Archivo intermedio html
html = markdown(text)

# Convierte el archivo html en PDF
extra_args = ['--pdf-engine=xelatex',
              '-V', 'mainfont=Latin Modern Roman'
             ]
pypandoc.convert_text(html, 'pdf', format='html', outputfile='materiales_curso.pdf', extra_args=extra_args)
# Revisar el resultado en la carpeta de archivos de Colab.
# Out:
# ''

# %%
import json

respuesta = response.text

# Find the start and end of the JSON object
start = respuesta.find('{')
end = respuesta.rfind('}') + 1  # +1 to include the closing brace

# Extract the JSON string
json_string = respuesta[start:end]

# Try to parse the JSON
try:
    data_json = json.loads(json_string)
    print(data_json)  # Or do something else with the data
except json.JSONDecodeError as e:
    print(f"Error decoding JSON: {e}")
    print(f"Problematic JSON string: {json_string}")
# Out:
# {'course_title': 'Desarrollo Económico', 'course_code': '1503714', 'academic_unit': 'Facultad de Ciencias Económicas', 'credits': 3, 'validity': '2022-1 y 2022-2', 'professor': 'Maria Isabel Restrepo E.', 'professor_email': 'isabel.restrepo@udea.edu.co', 'modules': [{'module_num': '1', 'module_title': 'Principios del desarrollo económico', 'objectives': ['Distinguir las principales teorías del desarrollo económico en un contexto histórico.', 'Identificar los principales retos al desarrollo económico de los países.', 'Sustentar opiniones sobre los retos, las políticas y las estrategias del desarrollo.'], 'content_outline': 'Introducción al desarrollo económico, Modelos clásicos y neoclásicos de crecimiento y desarrollo económico, Modelos contemporáneos de desarrollo económico, Determinantes fundamentales', 'class_notes': {'class_num': '1', 'introduction': 'Este módulo introduce los conceptos fundamentales del desarrollo económico, explorando su evolución histórica y las diferentes escuelas de pensamiento. Se analizarán los factores que determinan el crecimiento económico a largo plazo.', 'theory': 'Se revisarán modelos clásicos como el de Adam Smith y David Ricardo, analizando sus contribuciones y limitaciones. Posteriormente, se estudiarán modelos neoclásicos como el de Solow-Swan, prestando especial atención al papel del capital físico y humano. Finalmente, se abordarán modelos contemporáneos como los de crecimiento endógeno, que incorporan la innovación y el progreso tecnológico como motores del desarrollo.  Ejemplos de determinantes fundamentales a analizar son geografía, instituciones y cultura, examinando cómo influyen en el desempeño económico de los países.', 'challenges': 'Investigar y presentar un breve ensayo sobre la evolución de una teoría específica del desarrollo económico (por ejemplo, la teoría de la dependencia o la teoría de la modernización).  Comparar y contrastar los supuestos y predicciones de los modelos clásicos y neoclásicos de crecimiento.  Analizar un caso de estudio de un país que haya experimentado un rápido crecimiento económico, identificando los factores clave que contribuyeron a su éxito.'}}, {'module_num': '2', 'module_title': 'La perspectiva doméstica del desarrollo económico', 'objectives': ['Identificar los principales retos al desarrollo económico de los países.'], 'content_outline': 'Pobreza, desigualdad y desarrollo económico, Crecimiento de la población, Capital humano: educación y salud, Urbanización y migración rural – urbana, Transformación agrícola y desarrollo rural, Medio ambiente y desarrollo', 'class_notes': {'class_num': '1', 'introduction': 'Este módulo se enfoca en los desafíos internos que enfrentan los países en desarrollo.  Se analizarán temas como la pobreza, la desigualdad, el crecimiento poblacional, la inversión en capital humano, la urbanización y la sostenibilidad ambiental.', 'theory': 'Se examinará la relación entre pobreza y desigualdad, explorando sus causas y consecuencias en el desarrollo económico.  Se analizará el impacto del crecimiento poblacional en los recursos y el medio ambiente.  Se estudiará la importancia de la educación y la salud como determinantes del capital humano y su contribución al crecimiento.  Se analizarán los desafíos de la urbanización y la migración rural-urbana, así como la necesidad de promover un desarrollo rural sostenible.  Finalmente, se abordará la relación entre medio ambiente y desarrollo, explorando estrategias para lograr un crecimiento sostenible.', 'challenges': 'Analizar las políticas gubernamentales destinadas a reducir la pobreza y la desigualdad en un país específico. Investigar el impacto de la inversión en educación y salud en el crecimiento económico de un país en desarrollo.  Evaluar las políticas de desarrollo rural implementadas en una región específica y sus efectos en la reducción de la pobreza y el crecimiento económico.  Desarrollar un plan de acción para promover el desarrollo sostenible en una comunidad loca ...

# %%
import markdown
import pypandoc

def crear_material_clase_i(model, i, data_json):
    # Extraer solo la información del módulo actual
    modulo_info = data_json["modules"][i]

    prompt = """Eres un desarrollador experto de contenido educativo con amplia experiencia en la creación de materiales de cursos universitarios.
    Posees un profundo conocimiento en principios pedagógicos, diseño curricular y redacción académica.
    Tu tarea es ayudar a desarrollar materiales educativos integrales a partir de un plan de estudios (syllabus), asegurando altos estándares académicos.

    ### Contexto y Objetivos
    - **Analizar y comprender el syllabus**:
      - Extraer los componentes esenciales (objetivos, competencias, temáticas, metodologías, evaluaciones, etc.).
      - Identificar puntos clave para la generación de contenido pedagógico.
    - **Generar materiales educativos**:
      - Analizar detalladamente cada módulo, definiendo objetivos, contenidos, actividades y evaluaciones.
      - Crear notas de clase comprensivas que expliquen en profundidad cada módulo, con ejemplos, explicaciones teóricas y retos prácticos.
      - Mantener un alto rigor académico y coherencia con módulos previos.

    ### Plan de estudios - Módulo {i}
    {modulo_info}

    ### Instrucciones
    - Genera **únicamente** el material detallado del **módulo {i}**.
    - **No copies ni reformules información de módulos anteriores.**
    - Si un tema se repite en distintos módulos, **explica las diferencias y profundiza en los aspectos específicos de este módulo**.
    - Asegúrate de seguir el esquema de clases indicado en el syllabus.
    - Verifica el orden y la coherencia de los temas con las demás clases.

    **Revisa antes de entregar la respuesta. No incluyas el historial en la respuesta, solo el nuevo contenido.**
    """.format(i=i, modulo_info=modulo_info)

    # Generar contenido con el modelo
    material = model.generate_content(prompt)

    # Imprimir la salida para verificar si es repetida
    print(f"Material generado para el módulo {i}:\n", material.text)

    # Generar resumen del material
    resumen = model.generate_content("Resume el siguiente texto sin perder información clave:\n" + material.text)

    # Convertir a HTML
    html = markdown.markdown(material.text)

    # Convertir a PDF
    output_name = "material_modulo_{}.pdf".format(i)
    extra_args = ['--pdf-engine=xelatex', '-V', 'mainfont=Latin Modern Roman']
    pypandoc.convert_text(html, 'pdf', format='html', outputfile=output_name, extra_args=extra_args)

    return material, resumen

# %%
import json

def crear_materiales(model, data_json):
    history = ""  # Ya no es necesario usarlo en la generación

    for i in range(len(data_json["modules"])):
        _, resumen = crear_material_clase_i(model, i, data_json)  # Pasamos data_json como dict

        # Si aún quieres acumular el resumen, puedes hacerlo sin que afecte la generación de contenido
        if resumen and resumen.text.strip():
            history += "\n" + resumen.text.strip()

    return history

# %%
history = ""
history = crear_materiales(model,data_json)
# Out:
# Material generado para el módulo 0:
#  ## Módulo 1: Principios del Desarrollo Económico
#
# **Objetivos del Módulo:**
#
# *   Distinguir las principales teorías del desarrollo económico en un contexto histórico.
# *   Identificar los principales retos al desarrollo económico de los países.
# *   Sustentar opiniones sobre los retos, las políticas y las estrategias del desarrollo.
#
# **Contenido del Módulo:**
#
# *   Introducción al desarrollo económico.
# *   Modelos clásicos y neoclásicos de crecimiento y desarrollo económico.
# *   Modelos contemporáneos de desarrollo económico.
# *   Determinantes fundamentales del desarrollo económico.
#
# ---
#
# **Clase 1: Introducción al Desarrollo Económico y Modelos Clásicos y Neoclásicos**
#
# **Introducción:**
#
# Esta clase introduce el campo del desarrollo económico, diferenciándolo del simple crecimiento económico. El desarrollo económico abarca mejoras en el bienestar general de la población, incluyendo el acceso a la salud, la educación, la reducción de la pobreza y la desigualdad, además del aumento del ingreso per cápita. Examinaremos la evolución histórica del pensamiento sobre el desarrollo, desde las perspectivas clásicas hasta las teorías más modernas. El objetivo es proporcionar una base sólida para comprender los debates y las políticas actuales en el ámbito del desarrollo.
#
# **Teoría:**
#
# **A. Desarrollo Económico vs. Crecimiento Económico:** Es crucial distinguir entre crecimiento y desarrollo. El crecimiento económico se refiere al aumento en la producción de bienes y servicios de una economía, generalmente medido por el Producto Interno Bruto (PIB). El desarrollo económico, por otro lado, implica un cambio estructural en la economía, mejorando la calidad de vida de sus habitantes. Incluye aspectos como la reducción de la pobreza, la mejora de la salud y la educación, la igualdad de género y la sostenibilidad ambiental. Un país puede experimentar crecimiento económico sin necesariamente lograr un desarrollo económico significativo. Por ejemplo, un país rico en recursos naturales puede experimentar un crecimiento del PIB debido a la exportación de estos recursos, pero si los beneficios no se distribuyen equitativamente y no se invierten en capital humano y social, el desarrollo económico puede ser limitado.
#
# **B. Modelos Clásicos de Crecimiento y Desarrollo:**
#
# *   **Adam Smith y la "Riqueza de las Naciones":** Smith argumentó que la división del trabajo, la especialización y el libre mercado son fundamentales para el crecimiento económico. La "mano invisible" del mercado asigna eficientemente los recursos, promoviendo la innovación y la acumulación de capital. Smith enfatizó la importancia de las instituciones que protegen los derechos de propiedad y fomentan la competencia.
# *   **David Ricardo y la Ventaja Comparativa:** Ricardo desarrolló la teoría de la ventaja comparativa, demostrando que los países se benefician del comercio internacional incluso si son menos eficientes que otros en la producción de todos los bienes. Lo importante es especializarse en la producción de bienes en los que tienen una ventaja comparativa, es decir, donde el costo de oportunidad de producir esos bienes es menor. Esta teoría sigue siendo un pilar fundamental del comercio internacional.
# *   **Thomas Malthus y la Población:** Malthus argumentó que la población tiende a crecer a un ritmo más rápido que la producción de alimentos, lo que lleva a la escasez y la pobreza. Si bien su predicción sobre la hambruna generalizada no se ha cumplido debido a los avances tecnológicos en la agricultura, su preocupación por la sostenibilidad de los recursos naturales sigue siendo relevante en el contexto del cambio climático y el crecimiento demográfico actual.
#
# **C. Modelos Neoclásicos de Crecimiento:**
#
# *   **Modelo de Solow-Swan:** Este modelo es un pilar en la teoría del crecimiento. Asume que el crecimiento económico a largo plazo está determinado por el progreso tecnológico exógeno (fuera del modelo). El modelo predice que los países convergerán hacia un estado estacionario donde el crecimiento del ingreso per cápita es cero, a menos que haya progreso tecnológico continuo. El modelo destaca la importancia de la acumulación de capital físico y humano, pero el progreso tecnológico es el principal impulsor del crecimiento a largo plazo. Una limitación del modelo de Solow-Swan es que no explica de dónde viene el progreso tecnológico.
#     *   **Elementos clave del modelo de Solow-Swan:**
#         *   **Función de Producción:**  Y = A * K<sup>α</sup> * L<sup>1-α</sup>, donde Y es la producción, A es la productividad total de los factores (tecnología), K es el capital, L es el trabajo y α es la participación del capital en la producción.
#         *   **Acumulación de Capital:** La tasa de cambio del capital (ΔK) depende de la inversión (sY) y la depreciación (δK), donde s es la tasa de ahorro y δ es la tasa de depreciación. ΔK = sY - δK.
#         *   **Crecimiento de la Población:**  La población (y la fuerza laboral) crece a una tasa constante 'n'.
#     *   **Implicaciones:** El modelo predice convergencia condicional: países con tasas de ahorro más altas o tasas de crecimiento poblacional más bajas tendrán niveles de ingreso per cápita más altos en el estado estacionario.
#
# **D. Limitaciones de los Modelos Clásicos y Neoclásicos:**
#
# *   Los modelos clásicos a menudo no incorporan el papel de la tecnología y el capital humano en el crecimiento.
# *   El modelo de Solow-Swan considera el progreso tecnológico como exógeno, lo cual no explica las fuentes de la innovación y el cambio tecnológico.
# *   Estos modelos a menudo asumen mercados perfectos y no consideran las imperfecciones del mercado, la desigualdad, las instituciones o la geografía, factores que pueden tener un impacto significativo en el desarrollo.
#
# **Retos:**
#
# 1.  **Ensayo sobre la evolución de una teoría del desarrollo económico:** Investiga y presenta un breve ensayo (500-750 palabras) sobre la evolución de una teoría específica del desarrollo económico.  Puedes elegir, por ejemplo, la teoría de la dependencia, la teoría de la modernización, o la teoría de los polos de crecimiento. En tu ensayo, describe los orígenes de la teoría, sus principales proponentes, sus argumentos centrales, las críticas que ha recibido y su relevancia actual.
# 2.  **Comparación de Modelos Clásicos y Neoclásicos:** Elabora una tabla comparativa que contraste los supuestos, las variables clave, las predicciones y las limitaciones de los modelos clásicos (Smith, Ricardo, Malthus) y el modelo neoclásico de Solow-Swan.
# 3.  **Caso de Estudio de Crecimiento Económico:** Selecciona un país que haya experimentado un rápido crecimiento económico en las últimas décadas (por ejemplo, Corea del Sur, Singapur, China). Investiga y analiza los factores clave que contribuyeron a su éxito. Identifica las políticas económicas, las inversiones en capital humano y la tecnología que jugaron un papel crucial.
#
# ---
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 7 Regular/
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 7 Regular/
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 7 Regular/
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 7 Regular/
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
#
# WARNING:pypandoc:Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# Material generado para el módulo 1:
#  ## Módulo 2: La perspectiva doméstica del desarrollo económico
#
# **Objetivo General:** Identificar los principales retos al desarrollo económico de los países.
#
# **Contenido:** Pobreza, desigualdad y desarrollo económico, Crecimiento de la población, Capital humano: educación y salud, Urbanización y migración rural – urbana, Transformación agrícola y desarrollo rural, Medio ambiente y desarrollo.
#
# ### Clase 1: Introducción a los Desafíos Internos del Desarrollo Económico
#
# **Introducción:**
#
# Este módulo se enfoca en los desafíos internos que enfrentan los países en desarrollo. Se analizarán temas como la pobreza, la desigualdad, el crecimiento poblacional, la inversión en capital humano, la urbanización y la sostenibilidad ambiental. Comprender estos desafíos es crucial para diseñar políticas y estrategias efectivas que impulsen el desarrollo económico sostenible y equitativo. A diferencia de los factores externos, los desafíos internos están más directamente sujetos a las políticas y acciones del propio país.
#
# **Teoría:**
#
# *   **Pobreza, Desigualdad y Desarrollo Económico:**
#
#     *   La **pobreza** se define como la carencia de recursos básicos para satisfacer las necesidades fundamentales, incluyendo alimentación, vivienda, salud y educación. Se mide comúnmente a través de líneas de pobreza, tanto absolutas (basadas en un nivel mínimo de ingresos) como relativas (en relación con la distribución del ingreso en una sociedad).
#     *   La **desigualdad** se refiere a la distribución asimétrica de ingresos, riqueza y oportunidades dentro de una sociedad. Se mide con herramientas como el coeficiente de Gini (que varía de 0, perfecta igualdad, a 1, perfecta desigualdad) y las curvas de Lorenz.
#     *   **Relación entre Pobreza y Desigualdad:** La desigualdad extrema puede exacerbar la pobreza, limitando el acceso a oportunidades para los más vulnerables. A su vez, la pobreza generalizada puede perpetuar la desigualdad al impedir la movilidad social y el desarrollo del capital humano. Un círculo vicioso se genera donde la desigualdad impide la reducción de la pobreza y viceversa.
#     *   **Causas de la Pobreza y la Desigualdad:** Entre las causas se encuentran la falta de acceso a educación de calidad, la discriminación (por género, etnia, etc.), la corrupción, la inestabilidad política, la falta de oportunidades de empleo decente, la concentración de la propiedad de la tierra y la ausencia de políticas redistributivas efectivas.
#     *   **Consecuencias de la Pobreza y la Desigualdad:** Impactan negativamente el crecimiento económico (limitando la demanda interna y la inversión), generan inestabilidad social y política, aumentan la criminalidad, afectan la salud y el bienestar de la población, y reducen la productividad laboral.
#
# *   **Crecimiento de la Población:**
#
#     *   El crecimiento poblacional en los países en desarrollo puede ejercer presión sobre los recursos naturales, la infraestructura y los servicios públicos.  Un crecimiento demográfico rápido puede superar la capacidad del gobierno para proveer educación, salud y vivienda adecuadas.
#     *   **Transición Demográfica:** Es importante comprender la etapa de la transición demográfica en la que se encuentra un país. Muchos países en desarrollo aún experimentan altas tasas de natalidad y mortalidad, mientras que otros están en etapas más avanzadas con tasas de natalidad en declive.
#     *   **Implicaciones para el Desarrollo:** Un crecimiento poblacional no controlado puede agravar la pobreza, aumentar la presión sobre la tierra y los recursos hídricos, generar desempleo y subempleo, y contribuir a la degradación ambiental.  Sin embargo, un crecimiento poblacional adecuado, combinado con políticas apropiadas, puede impulsar la innovación y el crecimiento económico a largo plazo.
#
# *   **Capital Humano: Educación y Salud:**
#
#     *   El **capital humano** se refiere al conjunto de habilidades, conocimientos y salud que posee la población y que contribuye a la productividad económica.
#     *   **Educación:** Es fundamental para el desarrollo económico. Mejora la productividad laboral, fomenta la innovación, promueve la movilidad social y contribuye a la formación de ciudadanos informados y comprometidos. Invertir en educación, especialmente en la educación básica y técnica, es crucial para aumentar el capital humano.
#     *   **Salud:** Una población sana es más productiva y contribuye al crecimiento económico. El acceso a servicios de salud de calidad, la nutrición adecuada y la prevención de enfermedades son esenciales para mejorar el capital humano.
#     *   **Relación entre Educación y Salud:** La educación y la salud están interrelacionadas. Una mejor educación puede llevar a mejores decisiones de salud, mientras que una buena salud puede mejorar el rendimiento educativo. La inversión en ambos aspectos es esencial para un desarrollo humano integral.
#
# *   **Urbanización y Migración Rural – Urbana:**
#
#     *   La **urbanización** es el proceso de crecimiento de las ciudades y el aumento de la proporción de la población que vive en áreas urbanas. La **migración rural-urbana** es un factor clave de este proceso, impulsada por la búsqueda de mejores oportunidades económicas y sociales en las ciudades.
#     *   **Desafíos de la Urbanización:** El rápido crecimiento urbano en los países en desarrollo puede generar problemas como la falta de vivienda adecuada, la congestión del tráfico, la contaminación, la escasez de servicios públicos y la marginalidad social.
#     *   **Oportunidades de la Urbanización:** La urbanización también puede generar oportunidades para el desarrollo económico, como la concentración de la actividad económica, la innovación y la creación de empleo.
#     *   **Políticas para una Urbanización Sostenible:** Es fundamental implementar políticas de planificación urbana que promuevan el desarrollo ordenado de las ciudades, la provisión de servicios públicos adecuados, la creación de empleo y la inclusión social.
#
# *   **Transformación Agrícola y Desarrollo Rural:**
#
#     *   La **transformación agrícola** se refiere al proceso de modernización de la agricultura, que implica el uso de tecnologías más eficientes, la diversificación de los cultivos, la mejora de la gestión de los recursos y la integración de los agricultores en los mercados.
#     *   **Desarrollo Rural:** Se enfoca en mejorar las condiciones de vida de la población rural, a través de la creación de empleo, el acceso a servicios básicos, la mejora de la infraestructura y la promoción de actividades económicas diversificadas.
#     *   **Importancia del Sector Agrícola:** La agricultura sigue siendo un sector importante en muchos países en desarrollo, proporcionando empleo, alimentos e ingresos a una parte significativa de la población. La transformación agrícola y el desarrollo rural son esenciales para reducir la pobreza, mejorar la seguridad alimentaria y promover el crecimiento económico inclusivo.
#
# *   **Medio Ambiente y Desarrollo:**
#
#     *   El **desarrollo sostenible** implica satisfacer las necesidades del presente sin comprometer la capacidad de las generaciones futuras para satisfacer sus propias necesidades.
#     *   **Relación entre Medio Ambiente y Desarrollo:** La degradación ambiental puede socavar el desarrollo económico al reducir la productividad de la tierra, disminuir la disponibilidad de agua, aumentar la vulnerabilidad a los desastres naturales y afectar la salud de la población.
#     *   **Desafíos Ambientales:** Los países en desarrollo enfrentan desafíos ambientales como la deforestación, la erosión del suelo, la contaminación del agua y del aire, la pérdida de biodiversidad y el cambio climático.
#     *   **Estrategias para un Desarrollo Sostenible:** Es fundamental adoptar políticas que promuevan la gestión sostenible de los recursos naturales, la eficiencia energética, la adopción de tecnologías limpias, la conservación de la biodiversidad y la mitigación del cambio climático.
#
# **Desafíos:**
#
# 1.  **Analizar las políticas gubernamentales destinadas a reducir la pobreza y la desigualdad en un país específico.** Seleccionar un país en desarrollo y analizar en detalle las políticas implementadas para reducir la pobreza y la desigualdad. Identificar los programas más efectivos, sus limitaciones y áreas de mejora. Considerar el impacto de la política fiscal (impuestos y gasto público) en la distribución del ingreso.
#
# 2.  **Investigar el impacto de la inversión en educación y salud en el crecimiento económico de un país en desarrollo.** Realizar una investigación empírica sobre el impacto de la inversión en educación y salud en el crecimiento económico de un país específico. Utilizar datos estadísticos para analizar la correlación entre estas variables y el crecimiento del PIB. Analizar la calidad de la educación y los servicios de salud, y su impacto en la productividad laboral.
#
# 3.  **Evaluar las políticas de desarrollo rural implementadas en una región específica y sus efectos en la reducción de la pobreza y el crecimiento económico.** Estudiar las políticas de desarrollo rural implementadas en una región específica (ej. un estado o provincia) y evaluar su impacto en la reducción de la pobreza y el crecimiento económico. Analizar los programas de apoyo a la agricultura, la mejora de la infraestructura rural, la diversificación económica y el acceso a servicios básicos.
#
# 4.  **Desarrollar un plan de acción para promover el desarrollo sostenible en una comunidad local, teniendo en cuenta los desafíos ambientales y sociales.** Diseñar un plan de acción para promover el desarrollo sostenible en una comunidad local (ej. un pueblo o barrio). Identificar los principales desafíos ambientales y sociales que enfrenta la comunidad. Proponer soluciones innovadoras y participativas que involucren a todos los actores locales (gobierno, empresas, sociedad civil). Incluir medidas para la conservación de los recursos naturales, la promoción de energías renovables, la gestión de residuos, la creación de empleo verde y la mejora de la calidad de vida.
#
# Material generado para el módulo 2:
#  ## Módulo 3: La perspectiva internacional del desarrollo económico
#
# **Objetivos:**
#
# *   Identificar los principales retos al desarrollo económico de los países en el contexto internacional.
# *   Sustentar opiniones informadas sobre los retos, las políticas y las estrategias del desarrollo en relación con el comercio, las finanzas y la inversión internacional.
#
# **Contenido:**
#
# *   Comercio internacional
# *   Balanza de pagos
# *   Deuda y crisis financieras
# *   Financiamiento e inversión extranjera
# *   Política fiscal y financiera para el desarrollo
#
# **Clase 1:**
#
# **Introducción:**
#
# Este módulo analiza el papel crucial del comercio internacional, las finanzas y la inversión extranjera en el proceso de desarrollo económico. Se explorarán los desafíos y oportunidades que presenta la globalización para los países en desarrollo, prestando especial atención a cómo estos factores externos interactúan con las dinámicas internas de cada nación. A diferencia de los módulos anteriores, este se centra en las **interacciones** entre las economías nacionales y el sistema económico global.
#
# **Teoría:**
#
# 1.  **Comercio Internacional y Crecimiento Económico:**
#
#     *   **Teorías del comercio internacional:** Se examinarán las teorías clásicas (ventaja comparativa de Ricardo, modelo Heckscher-Ohlin) y las teorías modernas (economías de escala, competencia imperfecta, cadenas globales de valor). Se analizará cómo estas teorías explican los patrones de comercio entre países desarrollados y en desarrollo, y cómo las políticas comerciales (aranceles, cuotas, acuerdos comerciales) pueden afectar el crecimiento económico. Se hará énfasis en las limitaciones de las teorías tradicionales para explicar el comercio entre países en desarrollo, y la importancia de considerar factores como la especialización productiva, la diversificación exportadora, y la mejora de la competitividad.
#
#     *   **Efectos del comercio en el desarrollo:** Se analizarán los efectos del comercio en el crecimiento económico, el empleo, la distribución del ingreso y la reducción de la pobreza. Se examinará cómo el comercio puede promover la transferencia de tecnología, la innovación y la mejora de la productividad. Se prestará especial atención a los desafíos que enfrentan los países en desarrollo para insertarse en las cadenas globales de valor, y cómo pueden superar estos desafíos a través de políticas de promoción de exportaciones, inversión en infraestructura y capital humano, y fortalecimiento de las instituciones.
#
# 2.  **Balanza de Pagos, Deuda Externa y Crisis Financieras:**
#
#     *   **Determinantes de la Balanza de Pagos:** Se analizarán los componentes de la balanza de pagos (cuenta corriente, cuenta de capital y cuenta financiera) y los factores que determinan sus saldos. Se examinará cómo los desequilibrios en la balanza de pagos pueden afectar la estabilidad macroeconómica y la competitividad de un país.
#
#     *   **Deuda Externa y Riesgos:** Se analizarán los diferentes tipos de deuda externa (deuda pública, deuda privada, deuda multilateral, deuda bilateral) y los riesgos asociados a cada uno. Se examinará cómo la acumulación excesiva de deuda externa puede conducir a crisis financieras y afectar el crecimiento económico. Se prestará especial atención a los mecanismos de reestructuración de deuda y a las políticas de gestión de la deuda que pueden ayudar a los países en desarrollo a evitar crisis financieras.
#
#     *   **Crisis Financieras:** Se estudiarán las causas y consecuencias de las crisis financieras en los países en desarrollo, incluyendo las crisis cambiarias, las crisis bancarias y las crisis de deuda soberana. Se analizará cómo la globalización financiera ha aumentado la vulnerabilidad de los países en desarrollo a las crisis financieras, y cómo las políticas macroprudenciales pueden ayudar a mitigar estos riesgos.
#
# 3.  **Financiamiento e Inversión Extranjera:**
#
#     *   **Inversión Extranjera Directa (IED):** Se analizará el papel de la IED en el desarrollo económico, incluyendo sus efectos en el crecimiento económico, el empleo, la transferencia de tecnología y la mejora de la productividad. Se examinarán los factores que atraen la IED a los países en desarrollo, incluyendo la estabilidad política y macroeconómica, la calidad de las instituciones, la disponibilidad de recursos naturales, y la calidad de la infraestructura. Se discutirá la importancia de las políticas que fomentan la IED responsable y sostenible, asegurando que beneficie tanto a los inversores como a los países receptores.
#
#     *   **Otras formas de financiamiento externo:** Se analizarán otras formas de financiamiento externo, incluyendo la ayuda oficial al desarrollo (AOD), los préstamos multilaterales y bilaterales, y los flujos de cartera. Se examinará cómo estas formas de financiamiento pueden complementar la IED y contribuir al desarrollo económico.
#
# 4.  **Política Fiscal y Financiera para el Desarrollo:**
#
#     *   **Política Fiscal:** Se analizará el papel de la política fiscal en la promoción del crecimiento económico sostenible e inclusivo. Se examinará cómo la política fiscal puede utilizarse para estabilizar la economía, promover la inversión en infraestructura y capital humano, y reducir la desigualdad. Se prestará especial atención a los desafíos que enfrentan los países en desarrollo para movilizar recursos fiscales internos y administrar la deuda pública de manera sostenible.
#
#     *   **Política Financiera:** Se analizará el papel de la política financiera en la promoción del desarrollo del sector financiero y la mejora del acceso al crédito. Se examinará cómo la política financiera puede utilizarse para regular el sistema financiero, promover la inclusión financiera, y prevenir las crisis financieras.
#
# **Desafíos:**
#
# 1.  **Impacto del Comercio Internacional:**
#
#     *   **Análisis:** Analizar el impacto del comercio internacional en el crecimiento económico de un país en desarrollo específico. Se debe tener en cuenta sus ventajas comparativas y sus desafíos competitivos. Esto implica seleccionar un país y analizar su estructura de exportaciones e importaciones, identificar sus principales socios comerciales, y evaluar cómo el comercio ha afectado su crecimiento económico, empleo y distribución del ingreso. Se debe prestar atención a los sectores que se han beneficiado y perjudicado por el comercio, y proponer políticas para mitigar los efectos negativos y maximizar los beneficios.
#
# 2.  **Riesgos de la Deuda Externa y Crisis Financieras:**
#
#     *   **Evaluación y Propuesta de Políticas:** Evaluar los riesgos asociados a la deuda externa y las crisis financieras en un país específico, y proponer políticas para mitigar estos riesgos. Esto implica analizar la estructura de la deuda externa del país, su sostenibilidad, y su vulnerabilidad a shocks externos. Se deben proponer políticas para reducir la deuda, mejorar la gestión de la deuda, y fortalecer la regulación del sistema financiero.
#
# 3.  **Rol de la Inversión Extranjera Directa (IED):**
#
#     *   **Investigación y Análisis:** Investigar el papel de la inversión extranjera directa en el desarrollo de un sector específico en un país en desarrollo. Esto implica seleccionar un sector y un país, y analizar cómo la IED ha afectado el crecimiento del sector, la creación de empleo, la transferencia de tecnología y la mejora de la productividad. Se deben identificar los factores que atraen la IED al sector, y proponer políticas para promover la IED responsable y sostenible.
#
# 4.  **Diseño de Políticas Fiscales y Financieras:**
#
#     *   **Planificación Estratégica:** Diseñar un plan de política fiscal y financiera para promover un crecimiento económico sostenible e inclusivo en un país en desarrollo. Esto implica establecer objetivos claros para la política fiscal y financiera, seleccionar los instrumentos de política adecuados, y evaluar los posibles efectos de estas políticas en el crecimiento económico, el empleo, la distribución del ingreso y la estabilidad macroeconómica. El plan debe tener en cuenta las características específicas del país, sus desafíos y oportunidades, y sus objetivos de desarrollo a largo plazo.
#
# Este módulo busca proporcionar una comprensión profunda de las complejas interrelaciones entre la economía global y el desarrollo económico, capacitando a los estudiantes para analizar críticamente las políticas y estrategias de desarrollo en un contexto internacional.

# %%
import json

# Muestra la estructura completa
print(json.dumps(data_json, indent=4))

# Si solo quieres ver un módulo en particular
i = 0  # Ajusta según sea necesario
print(json.dumps(data_json["modules"][i], indent=4))
# Out:
# {
#     "course_title": "Desarrollo Econ\u00f3mico",
#     "course_code": "1503714",
#     "academic_unit": "Facultad de Ciencias Econ\u00f3micas",
#     "credits": 3,
#     "validity": "2022-1 y 2022-2",
#     "professor": "Maria Isabel Restrepo E.",
#     "professor_email": "isabel.restrepo@udea.edu.co",
#     "modules": [
#         {
#             "module_num": "1",
#             "module_title": "Principios del desarrollo econ\u00f3mico",
#             "objectives": [
#                 "Distinguir las principales teor\u00edas del desarrollo econ\u00f3mico en un contexto hist\u00f3rico.",
#                 "Identificar los principales retos al desarrollo econ\u00f3mico de los pa\u00edses.",
#                 "Sustentar opiniones sobre los retos, las pol\u00edticas y las estrategias del desarrollo."
#             ],
#             "content_outline": "Introducci\u00f3n al desarrollo econ\u00f3mico, Modelos cl\u00e1sicos y neocl\u00e1sicos de crecimiento y desarrollo econ\u00f3mico, Modelos contempor\u00e1neos de desarrollo econ\u00f3mico, Determinantes fundamentales",
#             "class_notes": {
#                 "class_num": "1",
#                 "introduction": "Este m\u00f3dulo introduce los conceptos fundamentales del desarrollo econ\u00f3mico, explorando su evoluci\u00f3n hist\u00f3rica y las diferentes escuelas de pensamiento. Se analizar\u00e1n los factores que determinan el crecimiento econ\u00f3mico a largo plazo.",
#                 "theory": "Se revisar\u00e1n modelos cl\u00e1sicos como el de Adam Smith y David Ricardo, analizando sus contribuciones y limitaciones. Posteriormente, se estudiar\u00e1n modelos neocl\u00e1sicos como el de Solow-Swan, prestando especial atenci\u00f3n al papel del capital f\u00edsico y humano. Finalmente, se abordar\u00e1n modelos contempor\u00e1neos como los de crecimiento end\u00f3geno, que incorporan la innovaci\u00f3n y el progreso tecnol\u00f3gico como motores del desarrollo.  Ejemplos de determinantes fundamentales a analizar son geograf\u00eda, instituciones y cultura, examinando c\u00f3mo influyen en el desempe\u00f1o econ\u00f3mico de los pa\u00edses.",
#                 "challenges": "Investigar y presentar un breve ensayo sobre la evoluci\u00f3n de una teor\u00eda espec\u00edfica del desarrollo econ\u00f3mico (por ejemplo, la teor\u00eda de la dependencia o la teor\u00eda de la modernizaci\u00f3n).  Comparar y contrastar los supuestos y predicciones de los modelos cl\u00e1sicos y neocl\u00e1sicos de crecimiento.  Analizar un caso de estudio de un pa\u00eds que haya experimentado un r\u00e1pido crecimiento econ\u00f3mico, identificando los factores clave que contribuyeron a su \u00e9xito."
#             }
#         },
#         {
#             "module_num": "2",
#             "module_title": "La perspectiva dom\u00e9stica del desarrollo econ\u00f3mico",
#             "objectives": [
#                 "Identificar los principales retos al desarrollo econ\u00f3mico de los pa\u00edses."
#             ],
#             "content_outline": "Pobreza, desigualdad y desarrollo econ\u00f3mico, Crecimiento de la poblaci\u00f3n, Capital humano: educaci\u00f3n y salud, Urbanizaci\u00f3n y migraci\u00f3n rural \u2013 urbana, Transformaci\u00f3n agr\u00edcola y desarrollo rural, Medio ambiente y desarrollo",
#             "class_notes": {
#                 "class_num": "1",
#                 "introduction": "Este m\u00f3dulo se enfoca en los desaf\u00edos internos que enfrentan los pa\u00edses en desarrollo.  Se analizar\u00e1n temas como la pobreza, la desigualdad, el crecimiento poblacional, la inversi\u00f3n en capital humano, la urbanizaci\u00f3n y la sostenibilidad ambiental.",
#                 "theory": "Se examinar\u00e1 la relaci\u00f3n entre pobreza y desigualdad, explorando sus causas y consecuencias en el desarrollo econ\u00f3mico.  Se analizar\u00e1 el impacto del crecimiento poblacional en los recursos y el medio ambiente.  Se estudiar\u00e1 la importancia de la educaci\u00f3n y la salud como determinantes del capital humano y su contribuci\u00f3n al crecimiento.  Se analizar\u00e1n los desaf\u00edos de la urbanizaci\u00f3n y la migraci\u00f3n rural-urbana, as\u00ed como la necesidad de promover un desarrollo rural sostenible.  Finalmente, se abordar\u00e1 la relaci\u00f3n entre medio ambiente y desarrollo, explorando estrategias para lograr un crecimiento sostenible.",
#                 "challenges": "Analizar las pol\u00edticas gubernamentales destinadas a reducir la pobreza y la desigualdad en un pa\u00eds espec\u00edfico. Investigar el impacto de la inversi\u00f3n en educaci\u00f3n y salud en el crecimiento econ\u00f3mico de un pa\u00eds en desarrollo.  Evaluar las pol\u00edticas de desarrollo rural implementadas en una regi\u00f3n espec\u00edfica y sus efectos en la reducci\u00f3n de la pobreza y el crecimiento econ\u00f3mico.  Desarrollar un plan de acci\u00f3n para promover el desarrollo sostenible en una comunidad local, teniendo en cuenta los desaf\u00edos ambientales y sociales."
#             }
#         },
#         {
#             "module_num": "3",
#             "module_title": "La perspectiva internacional del desarrollo econ\u00f3mico",
#             "objectives": [
#                 "Identificar los principales retos al desarrollo econ\u00f3mico de los pa\u00edses.",
#                 "Sustentar opiniones sobre los retos, las pol\u00edticas y las estrategias del desarrollo."
#             ],
#             "content_outline": "Comercio internacional, Balanza de pagos, deuda y crisis financieras, Financiamiento e inversi\u00f3n extranjera, Pol\u00edtica fiscal y financiera para el desarrollo",
#             "class_notes": {
#                 "class_num": "1",
#                 "introduction": "Este m\u00f3dulo analiza el papel del comercio internacional, las finanzas y la inversi\u00f3n extranjera en el desarrollo econ\u00f3mico.  Se explorar\u00e1n los desaf\u00edos y oportunidades que presenta la globalizaci\u00f3n para los pa\u00edses en desarrollo.",
#                 "theory": "Se examinar\u00e1 la teor\u00eda del comercio internacional y sus efectos en el crecimiento econ\u00f3mico.  Se analizar\u00e1n los determinantes de la balanza de pagos y los riesgos asociados a la deuda externa y las crisis financieras.  Se estudiar\u00e1 el papel de la inversi\u00f3n extranjera directa y otras formas de financiamiento externo en el desarrollo.  Se analizar\u00e1n las pol\u00edticas fiscales y financieras que pueden promover un crecimiento econ\u00f3mico sostenible e inclusivo.",
#                 "challenges": "Analizar el impacto del comercio internacional en el crecimiento econ\u00f3mico de un pa\u00eds en desarrollo, teniendo en cuenta sus ventajas comparativas y sus desaf\u00edos competitivos.  Evaluar los riesgos asociados a la deuda externa y las crisis financieras en un pa\u00eds espec\u00edfico, y proponer pol\u00edticas para mitigar estos riesgos.  Investigar el papel de la inversi\u00f3n extranjera directa en el desarrollo de un sector espec\u00edfico en un pa\u00eds en desarrollo.  Dise\u00f1ar un plan de pol\u00edtica fiscal y financiera para promover un crecimiento econ\u00f3mico sostenible e inclusivo en un pa\u00eds en desarrollo."
#             }
#         }
#     ]
# }
# {
#     "module_num": "1",
#     "module_title": "Principios del desarrollo econ\u00f3mico",
#     "objectives": [
#         "Distinguir las principales teor\u00edas del desarrollo econ\u00f3mico en un contexto hist\u00f3rico.",
#         "Identificar los principales retos al desarrollo econ\u00f3mico de los pa\u00edses.",
#         "Sustentar opiniones sobre los retos, las pol\u00edticas y las estrategias del desarrollo."
#     ],
#     "content_outline": "Introducci\u00f3n al desarrollo econ\u00f3mico, Modelos cl\u00e1sicos y neocl\u00e1sicos de crecimiento y desarrollo econ\u00f3mico, Modelos contempor\u00e1neos de desarrollo econ\u00f3mico, Determinantes fundamentales",
#     "class_notes": {
#         "class_num": "1",
#         "introduction": "Este m\u00f3dulo introduce los conceptos fundamentales del desarrollo econ\u00f3mico, explorando su evoluci\u00f3n hist\u00f3rica y las diferentes escuelas de pensamiento. Se analizar\u00e1n los factores que determinan el crecimiento econ\u00f3mico a largo plazo.",
#         "theory": "Se revisar\u00e1n modelos cl\u00e1sicos como el de Adam Smith y David Ricardo, analizando sus contribuciones y limitaciones. Posteriormente, se estudiar\u00e1n modelos neocl\u00e1sicos como el de Solow-Swan, prestando especial atenci\u00f3n al papel del capital f\u00edsico y humano. Finalmente, se abordar\u00e1n modelos contempor\u00e1neos como los de crecimiento end\u00f3geno, que incorporan la innovaci\u00f3n y el progreso tecnol\u00f3gico como motores del desarrollo.  Ejemplos de determinantes fundamentales a analizar son geograf\u00eda, instituciones y cultura, examinando c\u00f3mo influyen en el desempe\u00f1o econ\u00f3mico de los pa\u00edses.",
#         "challenges": "Investigar y presentar un breve ensayo sobre la evoluci\u00f3n de una teor\u00eda espec\u00edfica del desarrollo econ\u00f3mico (por ejemplo, la teor\u00eda de la dependencia o la teor\u00eda de la modernizaci\u00f3n).  Comparar y contrastar los supuestos y predicciones de los modelos cl\u00e1sicos y neocl\u00e1sicos de crecimiento.  Analizar un caso de estudio de un pa\u00eds que haya experimentado un r\u00e1pido crecimiento econ\u00f3mico, identificando los factores clave que contribuyeron a su \u00e9xito."
#     }
# }

# %%
import json
import markdown
import pypandoc
import google.generativeai as genai

def crear_material_clase(model, modulo_info, modulo_num, clase_num, total_clases, semanas_curso, clases_semana, previous_classes_summaries=""):
    """
    Genera el material para una clase específica dentro de un módulo

    Args:
        model: Modelo de Gemini a utilizar
        modulo_info: Información del módulo actual
        modulo_num: Número del módulo
        clase_num: Número de la clase dentro del módulo
        total_clases: Total de clases para este módulo
        semanas_curso: Duración total del curso en semanas
        clases_semana: Número de clases por semana
        previous_classes_summaries: Resumen de clases anteriores para mantener coherencia
    """

    prompt = f"""Eres un desarrollador experto de contenido educativo con amplia experiencia en la creación de materiales de cursos universitarios.
    Posees un profundo conocimiento en principios pedagógicos, diseño curricular y redacción académica.
    Tu tarea es ayudar a desarrollar materiales educativos integrales a partir de un plan de estudios (syllabus), asegurando altos estándares académicos.

    ### Contexto del Curso
    - Este curso tiene una duración total de {semanas_curso} semanas
    - Se imparten {clases_semana} clases por semana
    - El módulo actual ({modulo_num}) debe dividirse en {total_clases} clases distintas

    ### Contexto y Objetivos
    - **Analizar y comprender el syllabus**:
      - Extraer los componentes esenciales (objetivos, competencias, temáticas, metodologías, evaluaciones, etc.).
      - Identificar puntos clave para la generación de contenido pedagógico.
    - **Generar materiales educativos**:
      - Analizar detalladamente cada módulo, definiendo objetivos, contenidos, actividades y evaluaciones.
      - Crear notas de clase comprensivas que expliquen en profundidad cada tema, con ejemplos, explicaciones teóricas y retos prácticos.
      - Mantener un alto rigor académico y coherencia con clases previas.

    ### Plan de estudios - Módulo {modulo_num}
    {json.dumps(modulo_info, indent=2)}

    ### Clases anteriores de este módulo (resumen)
    {previous_classes_summaries}

    ### Instrucciones
    - Genera **únicamente** el material detallado de la **clase {clase_num} del módulo {modulo_num}**.
    - Esta es la clase {clase_num} de {total_clases} para este módulo.
    - Divide el contenido del módulo de manera lógica entre las {total_clases} clases.
    - Asegúrate de que esta clase tenga continuidad con las clases anteriores del módulo.
    - Incluye en el material:
      1. Título de la clase
      2. Objetivos específicos de la clase
      3. Contenido teórico detallado
      4. Ejemplos o casos de estudio
      5. Actividades prácticas o ejercicios
      6. Materiales complementarios recomendados

    **Revisa antes de entregar la respuesta. No incluyas el historial en la respuesta, solo el nuevo contenido para esta clase específica.**
    """

    # Generar contenido con el modelo
    material = model.generate_content(prompt)

    # Generar resumen de la clase para mantener coherencia
    resumen_prompt = f"Resume brevemente los principales puntos tratados en la siguiente clase (máximo 200 palabras):\n{material.text}"
    resumen = model.generate_content(resumen_prompt)

    # Convertir a HTML
    html = markdown.markdown(material.text)

    # Convertir a PDF
    output_name = f"material_modulo_{modulo_num}_clase_{clase_num}.pdf"
    extra_args = ['--pdf-engine=xelatex', '-V', 'mainfont=Latin Modern Roman']
    pypandoc.convert_text(html, 'pdf', format='html', outputfile=output_name, extra_args=extra_args)

    return material, resumen.text

def crear_materiales_modulo(model, modulo_info, modulo_idx, semanas_curso, clases_semana):
    """
    Genera los materiales para todas las clases de un módulo

    Args:
        model: Modelo de Gemini a utilizar
        modulo_info: Información del módulo actual
        modulo_idx: Índice del módulo en la lista
        semanas_curso: Duración total del curso en semanas
        clases_semana: Número de clases por semana
    """
    # Calcular el número de clases para este módulo
    # Por defecto asignamos 2 clases por módulo, pero se puede ajustar según la lógica deseada
    total_modulos = len(data_json["modules"])
    total_clases_curso = semanas_curso * clases_semana

    # Distribuir clases de manera proporcional entre módulos
    clases_por_modulo = max(1, round(total_clases_curso / total_modulos))

    # Asegurar que los módulos más importantes tengan al menos 2 clases si es posible
    if modulo_idx < (total_clases_curso % total_modulos):
        clases_por_modulo += 1

    print(f"Generando {clases_por_modulo} clases para el módulo {modulo_idx+1}")

    # Para mantener coherencia entre clases
    previous_classes_summaries = ""

    # Generar cada clase del módulo
    for clase_num in range(1, clases_por_modulo + 1):
        print(f"Generando clase {clase_num} de {clases_por_modulo} del módulo {modulo_idx+1}...")

        material, resumen = crear_material_clase(
            model,
            modulo_info,
            modulo_idx + 1,  # Módulo comienza en 1, no en 0
            clase_num,
            clases_por_modulo,
            semanas_curso,
            clases_semana,
            previous_classes_summaries
        )

        # Agregar resumen de esta clase para las siguientes
        previous_classes_summaries += f"\n\nResumen de la clase {clase_num}:\n{resumen}"

    return previous_classes_summaries

def crear_todos_materiales(model, data_json, semanas_curso=16, clases_semana=2):
    """
    Genera los materiales para todos los módulos del curso

    Args:
        model: Modelo de Gemini a utilizar
        data_json: Datos estructurados del curso
        semanas_curso: Duración total del curso en semanas (por defecto 16)
        clases_semana: Número de clases por semana (por defecto 2)
    """
    all_summaries = ""

    for i, modulo in enumerate(data_json["modules"]):
        modulo_summaries = crear_materiales_modulo(
            model,
            modulo,
            i,
            semanas_curso,
            clases_semana
        )
        all_summaries += f"\n\n--- RESUMEN MÓDULO {i+1} ---\n{modulo_summaries}"

    # Opcionalmente, genera un documento con todos los resúmenes
    with open("resumen_curso_completo.txt", "w", encoding="utf-8") as f:
        f.write(all_summaries)

    return all_summaries

# %%
# Reemplaza tu actual llamada a crear_materiales con esto:
semanas_curso = 16  # Puedes cambiar este valor o solicitar al usuario que lo ingrese
clases_semana = 2   # Puedes cambiar este valor o solicitar al usuario que lo ingrese

history = crear_todos_materiales(model, data_json, semanas_curso, clases_semana)
# Out:
# Generando 12 clases para el módulo 1
# Generando clase 1 de 12 del módulo 1...
# Generando clase 2 de 12 del módulo 1...
# Generando clase 3 de 12 del módulo 1...
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no δ (U+03B4) (U+03B4) in font [lmmono10-regular]:!
#
# WARNING:pypandoc:Missing character: There is no δ (U+03B4) (U+03B4) in font [lmmono10-regular]:!
# Generando clase 4 de 12 del módulo 1...
# Generando clase 5 de 12 del módulo 1...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-89d4b32a8b19> in <cell line: 0>()
#       3 clases_semana = 2   # Puedes cambiar este valor o solicitar al usuario que lo ingrese
#       4
# ----> 5 history = crear_todos_materiales(model, data_json, semanas_curso, clases_semana)
#
# <ipython-input-32-32c611826e50> in crear_todos_materiales(model, data_json, semanas_curso, clases_semana)
#     137
#     138     for i, modulo in enumerate(data_json["modules"]):
# --> 139         modulo_summaries = crear_materiales_modulo(
#     140             model,
#     141             modulo,
#
# <ipython-input-32-32c611826e50> in crear_materiales_modulo(model, modulo_info, modulo_idx, semanas_curso, clases_semana)
#     108         print(f"Generando clase {clase_num} de {clases_por_modulo} del módulo {modulo_idx+1}...")
#     109
# --> 110         material, resumen = crear_material_clase(
#     111             model,
#     112             modulo_info,
#
# <ipython-input-32-32c611826e50> in crear_material_clase(model, modulo_info, modulo_num, clase_num, total_clases, semanas_curso, clases_semana, previous_classes_summaries)
#      60
#      61     # Generar contenido con el modelo
# ---> 62     material = model.generate_content(prompt)
#      63
#      64     # Generar resumen de la clase para mantener coherencia
#
# /usr/local/lib/python3.11/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.11/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     129             kwargs["compression"] = compression
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#     133
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     291                 self._initial, self._maximum, multiplier=self._multiplier
#     292             )
# --> 293             return retry_target(
#     294                 target,
#     295                 self._predicate,
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142     for sleep in sleep_generator:
#     143         try:
# --> 144             result = target()
#     145             if inspect.isawaitable(result):
#     146                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      74     def error_remapped_callable(*args, **kwargs):
#      75         try:
# ---> 76             return callable_(*args, **kwargs)
#      77         except grpc.RpcError as exc:
#      78             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.11/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1146
#    1147             # Send the request
# -> 1148             response = GenerativeServiceRestTransport._GenerateContent._get_response(
#    1149                 self._host,
#    1150                 metadata,
#
# /usr/local/lib/python3.11/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in _get_response(host, metadata, query_params, session, timeout, transcoded_request, body)
#    1046             headers = dict(metadata)
#    1047             headers["Content-Type"] = "application/json"
# -> 1048             response = getattr(session, method)(
#    1049                 "{host}{uri}".format(host=host, uri=uri),
#    1050                 timeout=timeout,
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     635         """
#     636
# --> 637         return self.request("POST", url, data=data, json=json, **kwargs)
#     638
#     639     def put(self, url, data=None, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     539
#     540         with TimeoutGuard(remaining_time) as guard:
# --> 541             response = super(AuthorizedSession, self).request(
#     542                 method,
#     543                 url,
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in getresponse(self)
#     514
#     515         # Get the response from http.client.HTTPConnection
# --> 516         httplib_response = super().getresponse()
#     517
#     518         try:
#
# /usr/lib/python3.11/http/client.py in getresponse(self)
#    1393         try:
#    1394             try:
# -> 1395                 response.begin()
#    1396             except ConnectionError:
#    1397                 self.close()
#
# /usr/lib/python3.11/http/client.py in begin(self)
#     323         # read until we get a non-100 response
#     324         while True:
# --> 325             version, status, reason = self._read_status()
#     326             if status != CONTINUE:
#     327                 break
#
# /usr/lib/python3.11/http/client.py in _read_status(self)
#     284
#     285     def _read_status(self):
# --> 286         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287         if len(line) > _MAXLINE:
#     288             raise LineTooLong("status line")
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import json
import markdown
import pypandoc
import google.generativeai as genai

def crear_material_clase(model, modulo_info, modulo_num, clase_num, total_clases, semanas_curso, clases_semana, previous_classes_summaries=""):
    """
    Genera el material para una clase específica dentro de un módulo

    Args:
        model: Modelo de Gemini a utilizar
        modulo_info: Información del módulo actual
        modulo_num: Número del módulo
        clase_num: Número de la clase dentro del módulo
        total_clases: Total de clases para este módulo
        semanas_curso: Duración total del curso en semanas
        clases_semana: Número de clases por semana
        previous_classes_summaries: Resumen de clases anteriores para mantener coherencia
    """

    prompt = f"""Eres un desarrollador experto de contenido educativo con amplia experiencia en la creación de materiales de cursos universitarios.
    Posees un profundo conocimiento en principios pedagógicos, diseño curricular y redacción académica.
    Tu tarea es ayudar a desarrollar materiales educativos integrales a partir de un plan de estudios (syllabus), asegurando altos estándares académicos.

    ### Contexto del Curso
    - Este curso tiene una duración total de {semanas_curso} semanas
    - Se imparten {clases_semana} clases por semana
    - El módulo actual ({modulo_num}) debe dividirse en {total_clases} clases distintas

    ### Contexto y Objetivos
    - **Analizar y comprender el syllabus**:
      - Extraer los componentes esenciales (objetivos, competencias, temáticas, metodologías, evaluaciones, etc.).
      - Identificar puntos clave para la generación de contenido pedagógico.
    - **Generar materiales educativos**:
      - Analizar detalladamente cada módulo, definiendo objetivos, contenidos, actividades y evaluaciones.
      - Crear notas de clase comprensivas que expliquen en profundidad cada tema, con ejemplos, explicaciones teóricas y retos prácticos.
      - Mantener un alto rigor académico y coherencia con clases previas.

    ### Plan de estudios - Módulo {modulo_num}
    {json.dumps(modulo_info, indent=2)}

    ### Clases anteriores de este módulo (resumen)
    {previous_classes_summaries}

    ### Instrucciones
    - Genera **únicamente** el material detallado de la **clase {clase_num} del módulo {modulo_num}**.
    - Esta es la clase {clase_num} de {total_clases} para este módulo.
    - Divide el contenido del módulo de manera lógica entre las {total_clases} clases.
    - Asegúrate de que esta clase tenga continuidad con las clases anteriores del módulo.
    - Inicia con un encabezado markdown de nivel 1 (# Clase {clase_num}: [Título de la clase])
    - Incluye en el material:
      1. Objetivos específicos de la clase
      2. Contenido teórico detallado
      3. Ejemplos o casos de estudio
      4. Actividades prácticas o ejercicios
      5. Materiales complementarios recomendados

    **Revisa antes de entregar la respuesta. No incluyas el historial en la respuesta, solo el nuevo contenido para esta clase específica.**
    """

    # Generar contenido con el modelo
    material = model.generate_content(prompt)

    # Generar resumen de la clase para mantener coherencia
    resumen_prompt = f"Resume brevemente los principales puntos tratados en la siguiente clase (máximo 200 palabras):\n{material.text}"
    resumen = model.generate_content(resumen_prompt)

    return material.text, resumen.text

def crear_materiales_modulo(model, modulo_info, modulo_idx, semanas_curso, clases_semana):
    """
    Genera los materiales para todas las clases de un módulo y los combina en un solo PDF

    Args:
        model: Modelo de Gemini a utilizar
        modulo_info: Información del módulo actual
        modulo_idx: Índice del módulo en la lista
        semanas_curso: Duración total del curso en semanas
        clases_semana: Número de clases por semana
    """
    # Calcular el número de clases para este módulo
    total_modulos = len(data_json["modules"])
    total_clases_curso = semanas_curso * clases_semana

    # Distribuir clases de manera proporcional entre módulos
    clases_por_modulo = max(1, round(total_clases_curso / total_modulos))

    # Asegurar que los módulos más importantes tengan al menos 2 clases si es posible
    if modulo_idx < (total_clases_curso % total_modulos):
        clases_por_modulo += 1

    print(f"Generando {clases_por_modulo} clases para el módulo {modulo_idx+1}")

    # Para mantener coherencia entre clases
    previous_classes_summaries = ""

    # Contenido combinado de todas las clases
    contenido_completo = f"# Módulo {modulo_idx+1}: {modulo_info.get('module_title', 'Sin título')}\n\n"

    # Agregar información general del módulo
    contenido_completo += "## Información General del Módulo\n\n"
    if 'objectives' in modulo_info:
        contenido_completo += "### Objetivos del Módulo\n\n"
        for objetivo in modulo_info['objectives']:
            contenido_completo += f"- {objetivo}\n"
        contenido_completo += "\n"

    if 'content_outline' in modulo_info:
        contenido_completo += "### Esquema de Contenido\n\n"
        contenido_completo += f"{modulo_info['content_outline']}\n\n"

    contenido_completo += "---\n\n"

    # Generar cada clase del módulo
    for clase_num in range(1, clases_por_modulo + 1):
        print(f"Generando clase {clase_num} de {clases_por_modulo} del módulo {modulo_idx+1}...")

        material_clase, resumen = crear_material_clase(
            model,
            modulo_info,
            modulo_idx + 1,  # Módulo comienza en 1, no en 0
            clase_num,
            clases_por_modulo,
            semanas_curso,
            clases_semana,
            previous_classes_summaries
        )

        # Agregar material de esta clase al contenido completo
        contenido_completo += f"{material_clase}\n\n"
        contenido_completo += "---\n\n"

        # Agregar resumen de esta clase para las siguientes
        previous_classes_summaries += f"\n\nResumen de la clase {clase_num}:\n{resumen}"

    # Convertir a HTML
    html = markdown.markdown(contenido_completo)

    # Convertir a PDF (un solo PDF para todo el módulo)
    output_name = f"material_modulo_{modulo_idx+1}.pdf"
    extra_args = [
        '--pdf-engine=xelatex',
        '-V', 'mainfont=Latin Modern Roman',
        '-V', 'geometry:margin=1in',
        '-V', 'linkcolor=blue',
        '-V', 'toc'  # Agregar tabla de contenidos
    ]
    pypandoc.convert_text(html, 'pdf', format='html', outputfile=output_name, extra_args=extra_args)

    print(f"PDF generado para el módulo {modulo_idx+1}: {output_name}")

    return previous_classes_summaries, contenido_completo

def crear_todos_materiales(model, data_json, semanas_curso=16, clases_semana=2):
    """
    Genera los materiales para todos los módulos del curso

    Args:
        model: Modelo de Gemini a utilizar
        data_json: Datos estructurados del curso
        semanas_curso: Duración total del curso en semanas (por defecto 16)
        clases_semana: Número de clases por semana (por defecto 2)
    """
    all_summaries = ""
    todos_contenidos = []

    for i, modulo in enumerate(data_json["modules"]):
        modulo_summaries, contenido_modulo = crear_materiales_modulo(
            model,
            modulo,
            i,
            semanas_curso,
            clases_semana
        )
        all_summaries += f"\n\n--- RESUMEN MÓDULO {i+1} ---\n{modulo_summaries}"
        todos_contenidos.append(contenido_modulo)

    # Opcionalmente, genera un documento con todos los resúmenes
    with open("resumen_curso_completo.txt", "w", encoding="utf-8") as f:
        f.write(all_summaries)

    # Opcionalmente, genera un PDF con todo el contenido del curso
    contenido_curso_completo = "\n\n".join(todos_contenidos)
    html_curso = markdown.markdown(contenido_curso_completo)

    extra_args = [
        '--pdf-engine=xelatex',
        '-V', 'mainfont=Latin Modern Roman',
        '-V', 'geometry:margin=1in',
        '-V', 'linkcolor=blue',
        '-V', 'toc'  # Agregar tabla de contenidos
    ]
    pypandoc.convert_text(html_curso, 'pdf', format='html', outputfile="curso_completo.pdf", extra_args=extra_args)

    print("Generación de materiales completada. Se han creado:")
    print(f"- {len(data_json['modules'])} PDFs de módulos individuales")
    print("- 1 PDF con el curso completo: curso_completo.pdf")
    print("- 1 archivo de resumen: resumen_curso_completo.txt")

    return all_summaries

# Ejemplo de uso:
# crear_todos_materiales(model, data_json, semanas_curso=16, clases_semana=2)

# %%
# Define estos parámetros según lo que necesites o pídelos al usuario
semanas_curso = 16  # Duración total del curso en semanas
clases_semana = 2   # Clases por semana

# Llama a la función principal para generar todos los materiales
history = crear_todos_materiales(model, data_json, semanas_curso, clases_semana)
# Out:
# Generando 12 clases para el módulo 1
# Generando clase 1 de 12 del módulo 1...
