# %% [markdown]
# Ejemplo invocación Gemini
# En este notebook se muestra cómo trabajar con la API de Google Gemini.
#
# Universidad Nacional de Colombia
#
# Departamento de Ciencias de la Computación y de la Decisión
#
# Profesor Juan David Ospina
#
# Introducción a Redes Neuronales y Algoritmos Bioinspirados
#
# Semestre 2024-02
#
# Fecha: 26 de febrero de 2025

# %%
# %%capture
# !apt-get update
# !apt-get install pandoc # para usar markdown
# !apt-get install texlive-xetex # Toma un buen tiempo la instalación
# !pip install markdown2 # para usar markdown
# !pip install pypandoc # para usar markdown

# %%
# !pip install fitz
# Out:
# Collecting fitz
#   Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl.metadata (816 bytes)
# Collecting configobj (from fitz)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting configparser (from fitz)
#   Downloading configparser-7.1.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: httplib2 in /usr/local/lib/python3.11/dist-packages (from fitz) (0.22.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (from fitz) (5.3.2)
# Collecting nipype (from fitz)
#   Downloading nipype-1.9.2-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fitz) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from fitz) (2.2.2)
# Collecting pyxnat (from fitz)
#   Downloading pyxnat-1.6.3-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from fitz) (1.13.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2->fitz) (3.2.1)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel->fitz) (6.5.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from nibabel->fitz) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel->fitz) (4.12.2)
# Requirement already satisfied: click>=6.6.0 in /usr/local/lib/python3.11/dist-packages (from nipype->fitz) (8.1.8)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.11/dist-packages (from nipype->fitz) (3.4.2)
# Collecting prov>=1.5.2 (from nipype->fitz)
#   Downloading prov-2.0.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pydot>=1.2.3 in /usr/local/lib/python3.11/dist-packages (from nipype->fitz) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.2 in /usr/local/lib/python3.11/dist-packages (from nipype->fitz) (2.8.2)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting simplejson>=3.8.0 (from nipype->fitz)
#   Downloading simplejson-3.20.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting traits>=6.2 (from nipype->fitz)
#   Downloading traits-7.0.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: filelock>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from nipype->fitz) (3.17.0)
# Collecting acres (from nipype->fitz)
#   Downloading acres-0.3.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting etelemetry>=0.3.1 (from nipype->fitz)
#   Downloading etelemetry-0.3.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting looseversion!=1.2 (from nipype->fitz)
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting puremagic (from nipype->fitz)
#   Downloading puremagic-1.28-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->fitz) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->fitz) (2025.1)
# Requirement already satisfied: lxml>=4.3 in /usr/local/lib/python3.11/dist-packages (from pyxnat->fitz) (5.3.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from pyxnat->fitz) (2.32.3)
# Requirement already satisfied: pathlib>=1.0 in /usr/local/lib/python3.11/dist-packages (from pyxnat->fitz) (1.0.1)
# Collecting ci-info>=0.2 (from etelemetry>=0.3.1->nipype->fitz)
#   Downloading ci_info-0.3.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-6.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.2->nipype->fitz) (1.17.0)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=5.0.0->nipype->fitz)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->pyxnat->fitz) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->pyxnat->fitz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->pyxnat->fitz) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->pyxnat->fitz) (2025.1.31)
# Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl (20 kB)
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Downloading configparser-7.1.0-py3-none-any.whl (17 kB)
# Downloading nipype-1.9.2-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 20.1 MB/s eta 0:00:00
# Downloading pyxnat-1.6.3-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 kB 7.3 MB/s eta 0:00:00
# Downloading etelemetry-0.3.1-py3-none-any.whl (6.4 kB)
# Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Downloading prov-2.0.1-py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 17.5 MB/s eta 0:00:00
# Downloading rdflib-6.3.2-py3-none-any.whl (528 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.1/528.1 kB 29.8 MB/s eta 0:00:00
# Downloading simplejson-3.20.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 9.8 MB/s eta 0:00:00
# Downloading traits-7.0.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 40.3 MB/s eta 0:00:00
# Downloading acres-0.3.0-py3-none-any.whl (10 kB)
# Downloading puremagic-1.28-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.4 MB/s eta 0:00:00
# Downloading ci_info-0.3.0-py3-none-any.whl (7.8 kB)
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: puremagic, looseversion, traits, simplejson, isodate, configparser, configobj, ci-info, acres, rdflib, pyxnat, etelemetry, prov, nipype, fitz
# Successfully installed acres-0.3.0 ci-info-0.3.0 configobj-5.0.9 configparser-7.1.0 etelemetry-0.3.1 fitz-0.0.1.dev2 isodate-0.6.1 looseversion-1.3.0 nipype-1.9.2 prov-2.0.1 puremagic-1.28 pyxnat-1.6.3 rdflib-6.3.2 simplejson-3.20.1 traits-7.0.2

# %%
# !pip install --upgrade pymupdf
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.25.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.25.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 48.3 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.25.3

# %%
import os
from google.colab import userdata
from markdown2 import markdown
import pypandoc

#os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

import google.generativeai as genai

# %%
import fitz  # PyMuPDF para leer PDFs
import google.generativeai as genai

# Configura la API de Gemini (sustituye con tu clave)
genai.configure(api_key="AIzaSyAooWfS3xzumCHk4xw4lMjl2yGdcoj3sog")
model = genai.GenerativeModel('gemini-2.0-flash-001')

initial_prompt = """
Eres un desarrollador experto de contenido educativo con amplia experiencia en la creación de materiales de cursos universitarios. Posees un profundo conocimiento en principios pedagógicos, diseño curricular y redacción académica. Tu tarea es ayudar a desarrollar un agente inteligente basado en modelos de lenguaje (LLM) que, a partir de un plan de estudios (syllabus), genere materiales educativos integrales que cumplan con altos estándares académicos.

Contexto y Objetivos
El agente debe:

Analizar y Comprender el Syllabus:

Extraer los componentes esenciales (objetivos, competencias, temáticas, metodologías, evaluaciones, etc.).
Identificar puntos clave para la generación de contenido pedagógico.
Generar Materiales Educativos:

Elaborar módulos detallados para cada tema o área, definiendo objetivos, contenidos, actividades y evaluaciones.
Crear notas de clase comprensivas que expliquen en profundidad cada módulo, incluyendo ejemplos, explicaciones teóricas y prácticos retos para el estudiante.
Mantener un alto rigor académico, asegurando la confiabilidad de la información y la integración de buenas prácticas pedagógicas.
Formato de Salida Específico:

Toda la salida generada debe estructurarse en formato JSON.
La estructura JSON debe incluir secciones claras para módulos y notas de clase.
Ejemplo de formato JSON:

{
  "course_title": "Título del Curso",
  "modules": [
    {
      "module_title": "Título del Módulo 1",
      "objectives": ["Objetivo 1", "Objetivo 2"],
      "module_num": "1",
      "content_outline": "Resumen de contenidos",
      "class_notes": {
        "class_num": "1",
        "introduction": "Introducción detallada del tema",
        "theory": "Desarrollo teórico con explicaciones y ejemplos",
        "challenges": "Retos y actividades prácticas para el estudiante"
      }
    },
    {
      "module_title": "Título del Módulo 2",
      "objectives": ["Objetivo A", "Objetivo B"],
      "content_outline": "Resumen de contenidos",
      "class_notes": {
        "introduction": "Introducción al tema",
        "theory": "Explicaciones teóricas y casos de estudio",
        "challenges": "Ejercicios y retos para aplicar lo aprendido"
      }
    }
  ]
}


SYLLABUS:
"""

# Función para extraer texto de un PDF
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = "\n".join([page.get_text() for page in doc])  # Extrae el texto de todas las páginas
    return text


# Cargar el PDF y extraer el texto
pdf_path = "/content/1503714_Desarrollo_Económico - firmado.pdf"  # Cambia por tu archivo
document_text = extract_text_from_pdf(pdf_path)

# %%
prompt = f"{initial_prompt}\n{document_text}"



response = model.generate_content(prompt)

# %%
# Convertir el texto en un PDF

# Resultado del promt
text = response.text

# Archivo intermedio html
html = markdown(text)

# Convierte el archivo html en PDF
extra_args = ['--pdf-engine=xelatex',
              '-V', 'mainfont=Latin Modern Roman'
             ]
pypandoc.convert_text(html, 'pdf', format='html', outputfile='materiales_curso.pdf', extra_args=extra_args)
# Revisar el resultado en la carpeta de archivos de Colab.
# Out:
# ''

# %%
import json

respuesta = response.text

# Find the start and end of the JSON object
start = respuesta.find('{')
end = respuesta.rfind('}') + 1  # +1 to include the closing brace

# Extract the JSON string
json_string = respuesta[start:end]

# Try to parse the JSON
try:
    data_json = json.loads(json_string)
    print(data_json)  # Or do something else with the data
except json.JSONDecodeError as e:
    print(f"Error decoding JSON: {e}")
    print(f"Problematic JSON string: {json_string}")
# Out:
# {'course_title': 'Desarrollo Económico', 'course_code': '1503714', 'credits': 3, 'faculty': 'Facultad de Ciencias Económicas', 'term': '2022-1 y 2022-2', 'instructor': 'Maria Isabel Restrepo E.', 'instructor_email': 'isabel.restrepo@udea.edu.co', 'course_description': 'Este curso proporciona una descripción general de los problemas de la economía del desarrollo y de las contribuciones que el análisis económico puede hacer para explicar por qué algunas naciones son pobres y otras ricas, y las circunstancias económicas y restricciones a las que se enfrenta el mundo en desarrollo. Al final del curso los estudiantes podrán demostrar su comprensión sobre los conceptos básicos, las teorías y discursos de la economía del desarrollo, así como de los problemas y las políticas. Asimismo, podrán discutir y evaluar diferentes enfoques de manera crítica.', 'general_objective': 'Analizar los conceptos básicos, las teorías y discursos de la economía del desarrollo, así como algunos de los problemas a los que se enfrentan los países en desarrollo y las estrategias de política implementadas', 'specific_objectives': ['Distinguir las principales teorías del desarrollo económico en un contexto histórico.', 'Identificar los principales retos al desarrollo económico de los países.', 'Sustentar opiniones sobre los retos, las políticas y las estrategias del desarrollo.'], 'modules': [{'module_num': '1', 'module_title': 'Principios del desarrollo económico', 'objectives': ['Comprender la introducción al desarrollo económico.', 'Analizar modelos clásicos y neoclásicos de crecimiento y desarrollo económico.', 'Evaluar modelos contemporáneos de desarrollo económico.', 'Identificar los determinantes fundamentales del desarrollo económico.'], 'content_outline': 'Introducción, Modelos clásicos y neoclásicos, Modelos contemporáneos, Determinantes fundamentales', 'class_notes': {'class_num': '1', 'introduction': 'El módulo introduce el campo del desarrollo económico, contrastando las economías desarrolladas con las economías en desarrollo.  Se explican los indicadores clave de desarrollo (PIB per cápita, esperanza de vida, tasas de alfabetización) y se discute por qué el desarrollo económico es un problema multidimensional que va más allá del mero crecimiento económico. Se analizan las diferentes escuelas de pensamiento sobre el desarrollo y sus implicaciones para la política.', 'theory': 'Este módulo cubre los modelos de crecimiento económico, incluyendo el modelo de Harrod-Domar, el modelo de Solow, y las teorías de crecimiento endógeno. Se examinan las variables clave que impulsan el crecimiento (inversión, acumulación de capital humano, innovación tecnológica). Se analizan los supuestos y limitaciones de cada modelo. Se discute el papel de la productividad y la eficiencia en el crecimiento económico. Ejemplos: El modelo de Solow explica cómo la acumulación de capital y el progreso tecnológico influyen en el crecimiento a largo plazo. Las teorías de crecimiento endógeno resaltan la importancia de la I+D y el capital humano.', 'challenges': ['Investigar y presentar un resumen de un modelo contemporáneo de desarrollo económico no cubierto en clase (por ejemplo, el modelo de Diamond).', 'Analizar críticamente un artículo de investigación que utilice uno de los modelos de crecimiento para explicar el desempeño económico de un país en desarrollo.', 'Debatir sobre la relevancia de los modelos clásicos de crecimiento para las economías en desarrollo actuales.']}}, {'module_num': '2', 'module_title': 'La perspectiva doméstica del desarrollo económico', 'objectives': ['Analizar la relación entre pobreza, desigualdad y desarrollo económico.', 'Evaluar el impacto del crecimiento de la población en el desarrollo.', 'Comprender la importancia del capital humano (educación y salud) para el desarrollo.', 'Analizar los procesos de urbanización y migración rural-urbana en el contexto del desarrollo.', 'Evaluar la transformación agrícola y el desarrollo rural.', 'Comprender ...

# %%
import markdown
import pypandoc

def crear_material_clase_i(model, i, data_json):
    # Extraer solo la información del módulo actual
    modulo_info = data_json["modules"][i]

    prompt = """Eres un desarrollador experto de contenido educativo con amplia experiencia en la creación de materiales de cursos universitarios.
    Posees un profundo conocimiento en principios pedagógicos, diseño curricular y redacción académica.
    Tu tarea es ayudar a desarrollar materiales educativos integrales a partir de un plan de estudios (syllabus), asegurando altos estándares académicos.

    ### Contexto y Objetivos
    - **Analizar y comprender el syllabus**:
      - Extraer los componentes esenciales (objetivos, competencias, temáticas, metodologías, evaluaciones, etc.).
      - Identificar puntos clave para la generación de contenido pedagógico.
    - **Generar materiales educativos**:
      - Analizar detalladamente cada módulo, definiendo objetivos, contenidos, actividades y evaluaciones.
      - Crear notas de clase comprensivas que expliquen en profundidad cada módulo, con ejemplos, explicaciones teóricas y retos prácticos.
      - Mantener un alto rigor académico y coherencia con módulos previos.

    ### Plan de estudios - Módulo {i}
    {modulo_info}

    ### Instrucciones
    - Genera **únicamente** el material detallado del **módulo {i}**.
    - **No copies ni reformules información de módulos anteriores.**
    - Si un tema se repite en distintos módulos, **explica las diferencias y profundiza en los aspectos específicos de este módulo**.
    - Asegúrate de seguir el esquema de clases indicado en el syllabus.
    - Verifica el orden y la coherencia de los temas con las demás clases.

    **Revisa antes de entregar la respuesta. No incluyas el historial en la respuesta, solo el nuevo contenido.**
    """.format(i=i, modulo_info=modulo_info)

    # Generar contenido con el modelo
    material = model.generate_content(prompt)

    # Imprimir la salida para verificar si es repetida
    print(f"Material generado para el módulo {i}:\n", material.text)

    # Generar resumen del material
    resumen = model.generate_content("Resume el siguiente texto sin perder información clave:\n" + material.text)

    # Convertir a HTML
    html = markdown.markdown(material.text)

    # Convertir a PDF
    output_name = "material_modulo_{}.pdf".format(i)
    extra_args = ['--pdf-engine=xelatex', '-V', 'mainfont=Latin Modern Roman']
    pypandoc.convert_text(html, 'pdf', format='html', outputfile=output_name, extra_args=extra_args)

    return material, resumen

# %%
import json

def crear_materiales(model, data_json):
    history = ""  # Ya no es necesario usarlo en la generación

    for i in range(len(data_json["modules"])):
        _, resumen = crear_material_clase_i(model, i, data_json)  # Pasamos data_json como dict

        # Si aún quieres acumular el resumen, puedes hacerlo sin que afecte la generación de contenido
        if resumen and resumen.text.strip():
            history += "\n" + resumen.text.strip()

    return history

# %%
history = ""
history = crear_materiales(model,data_json)
# Out:
# Material generado para el módulo 0:
#  ## Módulo 1: Principios del Desarrollo Económico
#
# **Objetivos del Módulo:**
#
# *   Comprender la introducción al desarrollo económico.
# *   Analizar modelos clásicos y neoclásicos de crecimiento y desarrollo económico.
# *   Evaluar modelos contemporáneos de desarrollo económico.
# *   Identificar los determinantes fundamentales del desarrollo económico.
#
# **Esquema del Contenido:**
#
# *   Introducción
# *   Modelos clásicos y neoclásicos
# *   Modelos contemporáneos
# *   Determinantes fundamentales
#
# ---
#
# **Clase 1: Introducción al Desarrollo Económico**
#
# **Objetivos de la Clase:**
#
# *   Definir el desarrollo económico y diferenciarlo del crecimiento económico.
# *   Identificar las características de las economías desarrolladas y en desarrollo.
# *   Comprender los principales indicadores de desarrollo económico y sus limitaciones.
# *   Analizar la naturaleza multidimensional del desarrollo económico.
# *   Explorar las diferentes escuelas de pensamiento sobre el desarrollo económico y sus implicaciones políticas.
#
# **Notas de Clase:**
#
# **1.1. ¿Qué es el Desarrollo Económico?**
#
# El desarrollo económico es un proceso multidimensional que implica mejoras sostenidas en el nivel de vida, la reducción de la pobreza, la disminución de la desigualdad y la mejora de las capacidades humanas y la libertad.  **Es más que simplemente el crecimiento económico**, que se refiere al aumento del Producto Interno Bruto (PIB). El desarrollo económico abarca cambios estructurales en la economía, la sociedad y las instituciones.
#
# **Diferencia clave entre Crecimiento y Desarrollo:** Mientras que el crecimiento económico puede ocurrir sin mejoras significativas en la distribución del ingreso o en la calidad de vida, el desarrollo económico implica un progreso integral. Por ejemplo, un país puede experimentar un alto crecimiento del PIB debido a la explotación de recursos naturales, pero si los beneficios se concentran en una pequeña élite y no se traducen en mejoras en la salud, la educación o la infraestructura para la mayoría de la población, no se puede considerar que haya experimentado un desarrollo económico genuino.
#
# **1.2. Economías Desarrolladas vs. Economías en Desarrollo:**
#
# Las **economías desarrolladas** (también conocidas como economías industrializadas o de altos ingresos) se caracterizan por:
#
# *   Altos niveles de PIB per cápita.
# *   Alta esperanza de vida.
# *   Altas tasas de alfabetización y escolarización.
# *   Infraestructura avanzada.
# *   Sistemas de salud y educación sólidos.
# *   Economías diversificadas con un sector de servicios predominante.
# *   Instituciones políticas y económicas estables y transparentes.
#
# Las **economías en desarrollo** (también conocidas como economías de bajos y medianos ingresos) se caracterizan por:
#
# *   Bajos niveles de PIB per cápita.
# *   Baja esperanza de vida.
# *   Bajas tasas de alfabetización y escolarización.
# *   Infraestructura deficiente.
# *   Sistemas de salud y educación débiles.
# *   Dependencia de la agricultura y la exportación de materias primas.
# *   Instituciones políticas y económicas débiles y/o corruptas.
# *   Altos niveles de pobreza y desigualdad.
#
# **1.3. Indicadores Clave de Desarrollo Económico:**
#
# Es crucial comprender los indicadores que nos ayudan a medir y evaluar el desarrollo.
#
# *   **PIB per cápita:**  Representa el valor de los bienes y servicios producidos en un país dividido por su población. Es una medida común del nivel de vida promedio, aunque no refleja la distribución del ingreso.  **Limitación:** No considera la distribución del ingreso ni las actividades no monetarias (trabajo doméstico, agricultura de subsistencia).
# *   **Índice de Desarrollo Humano (IDH):**  Es un indicador compuesto que combina la esperanza de vida, la educación (años promedio de escolarización y años esperados de escolarización) y el ingreso (PIB per cápita).  Proporciona una visión más holística del desarrollo que el PIB per cápita. **Limitación:** Puede ocultar desigualdades dentro de los países y no considera factores como la sostenibilidad ambiental.
# *   **Esperanza de vida al nacer:**  Indica el número promedio de años que se espera que viva una persona al nacer, basado en las tasas de mortalidad actuales.  Refleja el estado de salud y la calidad de vida de una población. **Limitación:** Es un promedio y no refleja las disparidades en la salud dentro de la población.
# *   **Tasas de alfabetización y escolarización:**  Miden la proporción de la población que puede leer y escribir, y la proporción que asiste a la escuela, respectivamente.  Indican el nivel de capital humano de un país. **Limitación:** No miden la calidad de la educación ni las habilidades adquiridas.
# *   **Índice de Gini:**  Mide la desigualdad en la distribución del ingreso.  Un valor de 0 representa la igualdad perfecta, mientras que un valor de 1 representa la desigualdad perfecta.  Permite comprender la distribución de la riqueza. **Limitación:** No captura completamente la desigualdad en la riqueza o el acceso a oportunidades.
#
# **1.4. La Naturaleza Multidimensional del Desarrollo Económico:**
#
# El desarrollo económico no se limita al crecimiento del PIB. Involucra dimensiones sociales, políticas, culturales y ambientales.
#
# *   **Dimensión Social:**  Incluye la mejora de la salud, la educación, la igualdad de género, la reducción de la pobreza y el acceso a servicios básicos.
# *   **Dimensión Política:**  Implica la promoción de la buena gobernanza, el estado de derecho, la participación ciudadana y la protección de los derechos humanos.
# *   **Dimensión Cultural:**  Considera la preservación de la identidad cultural, el fomento de la creatividad y la innovación, y la promoción del diálogo intercultural.
# *   **Dimensión Ambiental:**  Implica la gestión sostenible de los recursos naturales, la protección del medio ambiente y la mitigación del cambio climático.
#
# **1.5. Escuelas de Pensamiento sobre el Desarrollo Económico:**
#
# Existen diversas perspectivas teóricas sobre cómo lograr el desarrollo económico. Algunas de las principales escuelas de pensamiento incluyen:
#
# *   **Escuela Clásica:** Enfatiza el papel del libre mercado, la acumulación de capital y la especialización en el crecimiento económico.  Adam Smith y David Ricardo son figuras clave. **Implicaciones Políticas:**  Defensa de la liberalización comercial, la desregulación y la privatización.
# *   **Escuela Marxista:**  Considera que el desarrollo económico está determinado por las relaciones de clase y la explotación del trabajo.  Karl Marx es la figura central. **Implicaciones Políticas:**  Aboga por la redistribución de la riqueza, la planificación estatal y la revolución social.
# *   **Escuela Estructuralista:**  Argumenta que las estructuras económicas y políticas internacionales perpetúan la desigualdad entre países desarrollados y en desarrollo. Raúl Prebisch y Hans Singer son figuras influyentes. **Implicaciones Políticas:**  Propone políticas de industrialización por sustitución de importaciones, la protección de las industrias nacionales y la promoción de la cooperación Sur-Sur.
# *   **Escuela Neoliberal:**  Promueve la liberalización económica, la desregulación, la privatización y la apertura al comercio internacional como motores del crecimiento y el desarrollo.  Milton Friedman y Friedrich Hayek son figuras destacadas. **Implicaciones Políticas:**  Aboga por la reducción del tamaño del Estado, la disciplina fiscal y la apertura a la inversión extranjera.
# *   **Escuela del Desarrollo Humano:** Enfatiza la importancia de expandir las capacidades humanas (salud, educación, libertad) como el objetivo principal del desarrollo. Amartya Sen es un exponente clave. **Implicaciones Políticas:**  Prioriza la inversión en salud y educación, la promoción de la igualdad de género y la protección de los derechos humanos.
#
# **Retos para la Clase 1:**
#
# 1.  Investigar y presentar un breve análisis comparativo de dos países, uno desarrollado y otro en desarrollo, utilizando los indicadores de desarrollo económico discutidos en clase.
# 2.  Identificar y discutir un ejemplo de cómo una política económica específica puede tener diferentes impactos en diferentes grupos de personas dentro de un país en desarrollo.
# 3.  Debatir sobre la relevancia y las limitaciones de las diferentes escuelas de pensamiento sobre el desarrollo económico para abordar los desafíos actuales que enfrentan las economías en desarrollo.
# ---
# **Clase 2: Modelos Clásicos y Neoclásicos de Crecimiento y Desarrollo Económico**
#
# **Objetivos de la Clase:**
#
# *   Comprender los fundamentos del modelo de Harrod-Domar y sus limitaciones.
# *   Analizar el modelo de Solow-Swan, incluyendo el papel del progreso tecnológico.
# *   Evaluar críticamente los supuestos y las implicaciones de política de los modelos clásicos y neoclásicos.
# *   Comparar y contrastar los modelos de Harrod-Domar y Solow.
# *   Identificar las variables clave que impulsan el crecimiento económico en estos modelos.
#
# **Notas de Clase:**
#
# **2.1. El Modelo de Harrod-Domar:**
#
# El modelo de Harrod-Domar es uno de los primeros modelos de crecimiento económico. Se centra en la importancia de la inversión para el crecimiento económico.  Básicamente, el modelo establece que la tasa de crecimiento económico es directamente proporcional a la tasa de ahorro e inversamente proporcional a la relación capital-producto.
#
# *   **Supuestos clave:**
#     *   La tasa de ahorro (s) es constante.
#     *   La relación capital-producto (k) es constante (es decir, se necesita una cantidad fija de capital para producir una unidad de producto).
#     *   No hay depreciación del capital.
#     *   La economía está en pleno empleo.
# *   **Ecuación fundamental:** g = s/k, donde:
#     *   g es la tasa de crecimiento económico.
#     *   s es la tasa de ahorro.
#     *   k es la relación capital-producto.
# *   **Implicaciones:** Para aumentar la tasa de crecimiento económico, un país debe aumentar su tasa de ahorro o disminuir su relación capital-producto (es decir, aumentar la eficiencia en el uso del capital).
# *   **Limitaciones:**
#     *   Supone que la tasa de ahorro y la relación capital-producto son constantes, lo cual es poco realista.
#     *   No considera el papel del progreso tecnológico.
#     *   Ignora la posibilidad de desempleo.
#     *   No explica cómo se determina la tasa de ahorro.
#
# **2.2. El Modelo de Solow-Swan:**
#
# El modelo de Solow-Swan (o modelo de Solow) es un modelo neoclásico de crecimiento económico que supera algunas de las limitaciones del modelo de Harrod-Domar. Introduce el progreso tecnológico y la depreciación del capital.
#
# *   **Supuestos clave:**
#     *   La tasa de ahorro (s) es constante.
#     *   La población crece a una tasa constante (n).
#     *   El capital se deprecia a una tasa constante (δ).
#     *   Existe progreso tecnológico exógeno (A) que aumenta la productividad del trabajo.
#     *   La función de producción agregada presenta rendimientos decrecientes del capital.
# *   **Ecuación fundamental:** Δk = sf(k) - (δ + n)k, donde:
#     *   Δk es el cambio en el capital per cápita.
#     *   s es la tasa de ahorro.
#     *   f(k) es la función de producción per cápita.
#     *   δ es la tasa de depreciación.
#     *   n es la tasa de crecimiento de la población.
# *   **Estado estacionario:** El modelo predice que la economía converge a un estado estacionario en el que el capital per cápita y el producto per cápita dejan de crecer (a menos que haya progreso tecnológico). En el estado estacionario, la inversión iguala la depreciación más el crecimiento de la población.
# *   **Progreso Tecnológico:** El progreso tecnológico exógeno (A) desplaza la función de producción hacia arriba, permitiendo un crecimiento sostenido del producto per cápita en el largo plazo.
# *   **Implicaciones:**
#     *   El ahorro y la inversión son importantes para el crecimiento a corto plazo, pero no pueden sostener el crecimiento a largo plazo.
#     *   El progreso tecnológico es el principal motor del crecimiento a largo plazo.
#     *   Los países con niveles de capital iniciales más bajos tenderán a crecer más rápido (convergencia).
# *   **Limitaciones:**
#     *   El progreso tecnológico se considera exógeno (es decir, no se explica dentro del modelo).
#     *   No considera el papel de las instituciones, la política o la geografía en el crecimiento económico.
#     *   Supone que todos los países tienen acceso a la misma tecnología.
#
# **2.3. Comparación entre el Modelo de Harrod-Domar y el Modelo de Solow:**
#
# | Característica            | Modelo de Harrod-Domar                                 | Modelo de Solow                                              |
# | -------------------------- | ------------------------------------------------------ | ------------------------------------------------------------ |
# | Énfasis                  | Inversión y ahorro                                    | Inversión, ahorro y progreso tecnológico                          |
# | Rendimientos del capital   | Constantes                                             | Decrecientes                                                   |
# | Estado estacionario        | No predice convergencia a un estado estacionario estable | Predice convergencia a un estado estacionario (con o sin progreso tecnológico) |
# | Progreso tecnológico       | No considera el progreso tecnológico                   | Considera el progreso tecnológico exógeno                      |
# | Estabilidad               | Inestable (la tasa de crecimiento debe ser exactamente igual a s/k para evitar el desempleo o la sobreinversión) | Estable (la economía converge al estado estacionario)         |
#
# **2.4. Variables Clave que Impulsan el Crecimiento:**
#
# En los modelos clásicos y neoclásicos, las principales variables que impulsan el crecimiento económico son:
#
# *   **Inversión:** Aumenta el stock de capital y la capacidad productiva de la economía.
# *   **Ahorro:** Proporciona los recursos necesarios para financiar la inversión.
# *   **Progreso Tecnológico:** Aumenta la productividad del trabajo y el capital, permitiendo producir más con los mismos recursos.
# *   **Crecimiento de la Población:** Afecta el capital per cápita y el producto per cápita. En el modelo de Solow, un mayor crecimiento de la población reduce el capital per cápita en el estado estacionario.
# *   **Depreciación del Capital:** Reduce el stock de capital y la capacidad productiva de la economía.
#
# **Retos para la Clase 2:**
#
# 1.  Utilizar el modelo de Harrod-Domar para calcular la tasa de crecimiento económico requerida para alcanzar un objetivo de crecimiento del PIB, dados la tasa de ahorro y la relación capital-producto de un país.
# 2.  Utilizar el modelo de Solow para analizar el impacto de un aumento en la tasa de ahorro o en la tasa de progreso tecnológico sobre el capital per cápita y el producto per cápita en el estado estacionario.
# 3.  Debatir sobre las implicaciones de política de los modelos de Harrod-Domar y Solow para promover el crecimiento económico en los países en desarrollo.
#
# ---
#
# **Clase 3: Modelos Contemporáneos de Desarrollo Económico**
#
# **Objetivos de la Clase:**
#
# *   Analizar las teorías del crecimiento endógeno y su énfasis en el capital humano, la I+D y las instituciones.
# *   Comprender el papel de las externalidades, los rendimientos crecientes y la innovación en el crecimiento económico.
# *   Evaluar críticamente los modelos contemporáneos y su relevancia para las economías en desarrollo.
# *   Identificar las políticas que pueden promover el crecimiento endógeno.
#
# **Notas de Clase:**
#
# **3.1. Teorías del Crecimiento Endógeno:**
#
# Las teorías del crecimiento endógeno surgieron como una crítica al modelo de Solow, que considera el progreso tecnológico como exógeno.  Estas teorías intentan explicar el progreso tecnológico dentro del modelo, es decir, endógenamente.
#
# *   **Características Clave:**
#     *   El crecimiento económico es impulsado por factores internos a la economía, como la inversión en capital humano, la investigación y el desarrollo (I+D) y las instituciones.
#     *   El progreso tecnológico es el resultado de decisiones y acciones económicas, no un "manna del cielo" como en el modelo de Solow.
#     *   Las externalidades, los rendimientos crecientes y la innovación juegan un papel crucial en el crecimiento económico.
#
# *   **Modelos Representativos:**
#     *   **Modelo AK:** Este modelo simplificado asume una función de producción lineal en el capital (Y = AK), eliminando los rendimientos decrecientes del capital.  En este modelo, la tasa de crecimiento es endógena y depende de la tasa de ahorro y la productividad del capital (A). Este modelo es útil para ilustrar cómo la inversión en capital (incluyendo el capital humano) puede generar un crecimiento sostenido.
#     *   **Modelo de Capital Humano (Lucas):**  Este modelo destaca la importancia de la inversión en capital humano (educación, capacitación) para el crecimiento económico.  El capital humano aumenta la productividad del trabajo y fomenta la innovación.  La acumulación de capital humano genera externalidades positivas, beneficiando a toda la economía.
#     *   **Modelo de I+D (Romer):**  Este modelo enfatiza el papel de la investigación y el desarrollo (I+D) en la generación de nuevas ideas y tecnologías.  La I+D genera externalidades positivas, ya que las nuevas ideas pueden ser utilizadas por otros sin costo alguno.  El gobierno puede promover la I+D mediante subsidios y la protección de los derechos de propiedad intelectual.
#
# **3.2. Externalidades, Rendimientos Crecientes e Innovación:**
#
# Estos conceptos son fundamentales para comprender las teorías del crecimiento endógeno:
#
# *   **Externalidades:** Son efectos secundarios de la producción o el consumo que afectan a terceros que no están involucrados en la transacción.  Las externalidades positivas (como la difusión de conocimientos tecnológicos) pueden generar rendimientos crecientes a escala y promover el crecimiento económico.
# *   **Rendimientos Crecientes:** Se producen cuando un aumento en los factores de producción genera un aumento proporcionalmente mayor en la producción.  Los rendimientos crecientes pueden surgir de la especialización, la división del trabajo y las externalidades positivas.
# *   **Innovación:** Es la introducción de nuevos productos, procesos o modelos de negocio.  La innovación es un motor clave del crecimiento económico, ya que aumenta la productividad, reduce los costos y crea nuevos mercados.
#
# **3.3. Relevancia para las Economías en Desarrollo:**
#
# Las teorías del crecimiento endógeno ofrecen importantes lecciones para las economías en desarrollo:
#
# *   **Inversión en Capital Humano:**  La educación y la capacitación son fundamentales para aumentar la productividad y la capacidad de innovación de la fuerza laboral.
# *   **Promoción de la I+D:**  Los países en desarrollo deben invertir en investigación y desarrollo para adaptar y mejorar las tecnologías existentes, así como para generar nuevas tecnologías que se adapten a sus necesidades específicas.
# *   **Fortalecimiento de las Instituciones:**  Las instituciones sólidas (estado de derecho, derechos de propiedad, buena gobernanza) son esenciales para crear un entorno favorable a la inversión, la innovación y el crecimiento económico.
# *   **Atracción de Inversión Extranjera Directa (IED):** La IED puede traer consigo nuevas tecnologías, conocimientos y habilidades, que pueden contribuir al crecimiento económico.
# *   **Fomento de la Innovación Local:**  Los países en desarrollo deben apoyar a las empresas locales para que innoven y desarrollen nuevas soluciones a sus problemas específicos.
#
# **3.4. Políticas para Promover el Crecimiento Endógeno:**
#
# *   **Políticas Educativas:**  Inversión en educación de calidad en todos los niveles, desde la educación primaria hasta la educación superior.
# *   **Políticas de I+D:**  Subsidios a la investigación, incentivos fiscales para la innovación, protección de los derechos de propiedad intelectual.
# *   **Políticas Institucionales:**  Fortalecimiento del estado de derecho, lucha contra la corrupción, mejora de la gobernanza.
# *   **Políticas de Inversión:**  Promoción de la inversión extranjera directa, creación de un clima favorable a la inversión nacional.
# *   **Políticas de Competencia:**  Fomento de la competencia en los mercados para estimular la innovación y la eficiencia.
#
# **Retos para la Clase 3:**
#
# 1.  Investigar y presentar un caso de estudio de un país en desarrollo que haya logrado un crecimiento económico significativo gracias a la inversión en capital humano, la I+D o el fortalecimiento de las instituciones.
# 2.  Analizar críticamente las políticas económicas de un país en desarrollo a la luz de las teorías del crecimiento endógeno.
# 3.  Debatir sobre los desafíos que enfrentan los países en desarrollo para promover el crecimiento endógeno.
#
# ---
#
# **Clase 4: Determinantes Fundamentales del Desarrollo Económico**
#
# **Objetivos de la Clase:**
#
# *   Identificar y analizar el papel de la geografía, las instituciones, la cultura y la política en el desarrollo económico.
# *   Comprender cómo estos factores interactúan para influir en el desempeño económico de los países.
# *   Evaluar críticamente las diferentes perspectivas sobre los determinantes del desarrollo económico.
# *   Identificar políticas que pueden abordar los obstáculos al desarrollo relacionados con estos factores.
#
# **Notas de Clase:**
#
# **4.1. Geografía:**
#
# La geografía puede influir en el desarrollo económico de varias maneras:
#
# *   **Clima:** El clima puede afectar la productividad agrícola, la incidencia de enfermedades y la disponibilidad de recursos naturales.  Las regiones tropicales, por ejemplo, a menudo enfrentan desafíos relacionados con la productividad agrícola y la prevalencia de enfermedades como la malaria.
# *   **Recursos Naturales:** La abundancia de recursos naturales (petróleo, minerales, etc.) puede ser una bendición o una maldición.  Si bien los recursos naturales pueden generar ingresos significativos, también pueden dar lugar a la "enfermedad holandesa" (la apreciación del tipo de cambio que perjudica a otros sectores de la economía) y a la corrupción.
# *   **Ubicación:** La ubicación geográfica puede afectar el acceso a los mercados internacionales y los costos de transporte.  Los países sin salida al mar a menudo enfrentan mayores costos de transporte y dificultades para participar en el comercio internacional.
# *   **Topografía:** La topografía puede afectar la infraestructura y la conectividad.  Las regiones montañosas o con terrenos difíciles pueden ser más costosas de desarrollar y conectar con otras regiones.
#
# **4.2. Instituciones:**
#
# Las instituciones son las reglas del juego en una sociedad.  Incluyen las leyes, las normas sociales, las organizaciones y las estructuras de gobernanza que dan forma a las interacciones económicas y políticas.
#
# *   **Tipos de Instituciones:**
#     *   **Instituciones Políticas:**  Constituciones, sistemas electorales, partidos políticos.
#     *   **Instituciones Económicas:**  Derechos de propiedad, contratos, regulación de los mercados.
#     *   **Instituciones Sociales:**  Normas culturales, sistemas de educación, sistemas de salud.
# *   **Importancia de las Instituciones:**
#     *   **Protección de los Derechos de Propiedad:**  Los derechos de propiedad seguros y bien definidos son esenciales para fomentar la inversión, la innovación y el crecimiento económico.
#     *   **Estado de Derecho:**  Un sistema legal justo y transparente que se aplica de manera uniforme a todos los ciudadanos es fundamental para crear un entorno predecible y seguro para los negocios.
#     *   **Buena Gobernanza:**  La buena gobernanza implica la transparencia, la rendición de cuentas, la participación ciudadana y la lucha contra la corrupción.
# *   **El Argumento de Acemoglu, Johnson y Robinson:**  Estos autores argumentan que las instituciones extractivas (que benefician a una pequeña élite a expensas del resto de la población) conducen al estancamiento económico, mientras que las instituciones inclusivas (que protegen los derechos de propiedad, promueven la competencia y brindan igualdad de oportunidades) fomentan el crecimiento económico.
#
# **4.3. Cultura:**
#
# La cultura se refiere a los valores, las creencias, las actitudes y las normas de una sociedad.
#
# *   **Impacto de la Cultura:**
#     *   **Atracción al Riesgo:**  Algunas culturas son más propensas a asumir riesgos y a emprender nuevas actividades económicas que otras.
#     *   **Ahorro:**  Algunas culturas fomentan el ahorro, lo que puede conducir a una mayor inversión y crecimiento económico.
#     *   **Ética Laboral:**  Una fuerte ética laboral puede aumentar la productividad y la eficiencia.
#     *   **Confianza:**  La confianza es esencial para el funcionamiento eficiente de los mercados y las instituciones.
#     *   **Espíritu Empresarial:**  Algunas culturas fomentan el espíritu empresarial y la innovación.
# *   **Críticas al Argumento Cultural:**  Algunos críticos argumentan que el argumento cultural es determinista y que ignora la capacidad de las sociedades para cambiar y adaptarse.
#
# **4.4. Política:**
#
# Las políticas gubernamentales pueden tener un impacto significativo en el desarrollo económico.
#
# *   **Tipos de Políticas:**
#     *   **Políticas Macroeconómicas:**  Políticas fiscales y monetarias que afectan la inflación, el crecimiento y el empleo.
#     *   **Políticas Microeconómicas:**  Políticas que afectan a sectores específicos de la economía, como la agricultura, la industria y los servicios.
#     *   **Políticas Sociales:**  Políticas que afectan la salud, la educación y el bienestar social.
# *   **Ejemplos de Políticas:**
#     *   **Políticas de Libre Mercado:**  Desregulación, privatización, liberalización comercial.
#     *   **Políticas de Intervención Estatal:**  Inversión en infraestructura, subsidios a la industria, protección del medio ambiente.
#     *   **Políticas de Redistribución:**  Impuestos progresivos, programas de asistencia social.
#
# **4.5. Interacción entre los Determinantes:**
#
# Es importante reconocer que la geografía, las instituciones, la cultura y la política no actúan de forma aislada.  Interactúan entre sí de maneras complejas para influir en el desarrollo económico.
#
# *   **Ejemplos de Interacción:**
#     *   La geografía desfavorable puede llevar a la creación de instituciones extractivas que perpetúan la pobreza.
#     *   La cultura puede influir en la elección de políticas económicas.
#     *   Las políticas gubernamentales pueden afectar la cultura y las instituciones.
#
# **Retos para la Clase 4:**
#
# 1.  Investigar y presentar un caso de estudio de un país que haya superado los obstáculos geográficos o institucionales para lograr el desarrollo económico.
# 2.  Analizar críticamente las políticas económicas de un país a la luz de los determinantes fundamentales del desarrollo económico.
# 3.  Debatir sobre la importancia relativa de la geografía, las instituciones, la cultura y la política para el desarrollo económico.
# [WARNING] Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
#
# WARNING:pypandoc:Missing character: There is no δ (U+03B4) (U+03B4) in font Latin Modern Roman 10 Regular
# Material generado para el módulo 1:
#  ## Módulo 2: La perspectiva doméstica del desarrollo económico
#
# **Objetivos del Módulo:**
#
# *   Analizar la relación entre pobreza, desigualdad y desarrollo económico.
# *   Evaluar el impacto del crecimiento de la población en el desarrollo.
# *   Comprender la importancia del capital humano (educación y salud) para el desarrollo.
# *   Analizar los procesos de urbanización y migración rural-urbana en el contexto del desarrollo.
# *   Evaluar la transformación agrícola y el desarrollo rural.
# *   Comprender la relación entre medio ambiente y desarrollo.
#
# **Contenido del Módulo:**
#
# *   Pobreza, desigualdad
# *   Crecimiento de la población
# *   Capital humano
# *   Urbanización y migración
# *   Transformación agrícola
# *   Medio ambiente
#
# ---
#
# **Clase 1: Introducción a la Perspectiva Doméstica del Desarrollo Económico**
#
# **Introducción:**
#
# Este módulo se enfoca en los factores internos que moldean el desarrollo económico de una nación. A diferencia de los enfoques que priorizan el comercio internacional o la ayuda externa, nos centraremos en la dinámica interna que impulsa o frena el progreso. Exploraremos cómo factores como la pobreza, la desigualdad, el crecimiento demográfico, el capital humano, la urbanización, la transformación agrícola y la gestión ambiental interactúan para determinar la trayectoria de desarrollo de un país. Analizaremos políticas que buscan abordar estos desafíos y promover un crecimiento económico inclusivo y sostenible.
#
# **Teoría:**
#
# 1.  **Pobreza y Desigualdad:**
#
#     *   **Medición de la pobreza:** Analizaremos diferentes medidas de pobreza, incluyendo la pobreza absoluta (basada en un umbral de ingresos mínimo) y la pobreza relativa (definida en relación con la distribución del ingreso en una sociedad). También exploraremos el concepto de pobreza multidimensional, que considera factores no monetarios como la salud, la educación y el acceso a servicios básicos.
#     *   **Medición de la desigualdad:** Profundizaremos en la Curva de Lorenz, que representa gráficamente la distribución del ingreso o la riqueza en una población, y el Coeficiente de Gini, que resume la desigualdad en un solo número entre 0 (igualdad perfecta) y 1 (desigualdad perfecta).  También consideraremos otros índices de desigualdad como el índice de Theil.
#     *   **Impacto de la desigualdad en el crecimiento:**  Exploraremos cómo la alta desigualdad puede obstaculizar el crecimiento económico al reducir la inversión en capital humano, generar inestabilidad política y social, y limitar la demanda interna. Analizaremos los mecanismos a través de los cuales la desigualdad afecta el crecimiento, como la menor movilidad social, la erosión de la cohesión social y la concentración del poder político y económico.
# 2.  **Crecimiento de la Población:**
#
#     *   **Modelos Demográficos:**  Estudiaremos los modelos de transición demográfica, que describen los cambios en las tasas de natalidad y mortalidad a medida que los países se desarrollan. Analizaremos cómo estos cambios afectan la estructura de edad de la población y las oportunidades y desafíos que plantea para el desarrollo económico.
#     *   **Impacto en el Desarrollo:**  Examinaremos el impacto del crecimiento de la población en la disponibilidad de recursos naturales (agua, tierra, energía), la presión sobre los servicios públicos (educación, salud, infraestructura) y la creación de empleo.  Discutiremos cómo el crecimiento de la población puede generar desafíos ambientales, como la deforestación, la contaminación y el cambio climático.
# 3.  **Capital Humano:**
#
#     *   **Teoría del Capital Humano:**  Analizaremos la teoría del capital humano, que considera la educación y la salud como inversiones que aumentan la productividad de la mano de obra y contribuyen al crecimiento económico.  Exploraremos cómo la inversión en capital humano puede generar externalidades positivas, como la innovación, la mejora de la gobernanza y la reducción de la criminalidad.
#     *   **Salud y Educación:**  Estudiaremos los vínculos entre la salud, la educación y el desarrollo económico.  Analizaremos cómo la mejora de la salud y la educación puede aumentar la esperanza de vida, reducir la mortalidad infantil, mejorar la productividad laboral y aumentar la capacidad de innovación.
# 4.  **Urbanización y Migración Rural-Urbana:**
#
#     *   **Modelos de Migración:** Profundizaremos en el modelo de Harris-Todaro, que explica la migración rural-urbana como una respuesta a las diferencias en los salarios esperados entre las zonas rurales y urbanas, teniendo en cuenta la probabilidad de encontrar empleo en las ciudades.  Analizaremos las implicaciones de este modelo para el mercado laboral urbano, incluyendo el desempleo y la informalidad.
#     *   **Implicaciones para el Desarrollo:**  Examinaremos las implicaciones de la urbanización para el desarrollo económico, incluyendo las oportunidades y desafíos que plantea para la creación de empleo, la provisión de servicios públicos, la gestión ambiental y la gobernanza. Discutiremos cómo la urbanización puede generar economías de escala, facilitar la innovación y mejorar la calidad de vida, pero también puede exacerbar la desigualdad, la congestión y la contaminación.
# 5.  **Transformación Agrícola:**
#
#     *   **Teoría del Desarrollo Agrícola:**  Analizaremos la teoría del desarrollo agrícola, que destaca la importancia de la productividad agrícola para el crecimiento económico y la industrialización.  Exploraremos cómo el aumento de la productividad agrícola puede liberar mano de obra para otros sectores de la economía, generar excedentes para la inversión y aumentar la demanda de bienes y servicios industriales.
#     *   **Relación con la Industrialización:**  Estudiaremos la relación entre el desarrollo agrícola y la industrialización, analizando cómo la modernización de la agricultura puede impulsar el crecimiento industrial y viceversa.  Discutiremos cómo las políticas agrícolas pueden promover la innovación, la inversión y la diversificación en el sector agrícola, y cómo las políticas industriales pueden fomentar la demanda de productos agrícolas y la creación de empleo en las zonas rurales.
# 6.  **Medio Ambiente:**
#
#     *   **Externalidades Ambientales:**  Analizaremos el concepto de externalidades ambientales, que se refieren a los costos o beneficios que una actividad económica impone a terceros que no participan en la transacción.  Exploraremos cómo las externalidades ambientales negativas, como la contaminación del aire y del agua, pueden afectar la salud humana, la productividad agrícola y la disponibilidad de recursos naturales.
#     *   **Desarrollo Sostenible:**  Estudiaremos el concepto de desarrollo sostenible, que busca satisfacer las necesidades del presente sin comprometer la capacidad de las generaciones futuras para satisfacer sus propias necesidades.  Analizaremos cómo las políticas ambientales pueden promover el crecimiento económico sostenible, protegiendo los recursos naturales, reduciendo la contaminación y mitigando el cambio climático.
#
# **Ejemplos:**
#
# *   **Pobreza y Desigualdad:** En América Latina, la alta desigualdad histórica ha limitado el impacto del crecimiento económico en la reducción de la pobreza.
# *   **Crecimiento de la Población:** En África subsahariana, el rápido crecimiento de la población ejerce presión sobre los recursos naturales y los servicios públicos, lo que dificulta el logro de los Objetivos de Desarrollo Sostenible.
# *   **Capital Humano:** Los países que han invertido fuertemente en educación y salud, como Corea del Sur y Singapur, han experimentado un rápido crecimiento económico y mejoras significativas en los niveles de vida.
# *   **Urbanización y Migración:** En China, la migración rural-urbana masiva ha impulsado el crecimiento económico, pero también ha generado desafíos sociales y ambientales en las ciudades.
# *   **Transformación Agrícola:** La Revolución Verde en Asia, que introdujo variedades de cultivos de alto rendimiento y prácticas agrícolas modernas, aumentó significativamente la producción de alimentos y redujo la pobreza rural.
# *   **Medio Ambiente:** La deforestación en la Amazonía brasileña está amenazando la biodiversidad, contribuyendo al cambio climático y afectando la disponibilidad de agua dulce.
#
# **Retos Prácticos:**
#
# 1.  **Estudio de Caso sobre Desigualdad y Crecimiento:** Realizar un estudio de caso sobre un país en desarrollo específico y analizar cómo la desigualdad (medida a través del Coeficiente de Gini y otros indicadores) afecta su crecimiento económico. Considerar la distribución del ingreso, la concentración de la riqueza y el acceso a oportunidades como factores clave.
# 2.  **Análisis de Políticas Públicas para Mejorar Educación y Salud:** Investigar y presentar un análisis comparativo de las políticas públicas implementadas en dos países en desarrollo diferentes para mejorar la educación y la salud. Evaluar la efectividad de estas políticas en términos de indicadores como la tasa de alfabetización, la esperanza de vida y la mortalidad infantil.
# 3.  **Propuesta de Política para Desarrollo Agrícola Sostenible:** Desarrollar una propuesta de política detallada para promover el desarrollo agrícola sostenible en una región específica de un país en desarrollo.  La propuesta debe abordar aspectos como la gestión del agua, la conservación del suelo, la diversificación de cultivos, el acceso a mercados y la adaptación al cambio climático. Incluir indicadores medibles para evaluar el éxito de la política propuesta.
#
# Material generado para el módulo 2:
#  ## Módulo 3: La perspectiva internacional del desarrollo económico
#
# **Objetivos:**
#
# *   Analizar el papel del comercio internacional en el desarrollo económico.
# *   Comprender la relación entre la balanza de pagos, la deuda y las crisis financieras.
# *   Evaluar el impacto del financiamiento y la inversión extranjera en el desarrollo.
# *   Analizar la política fiscal y financiera para el desarrollo.
#
# **Contenido:**
#
# *   Comercio internacional.
# *   Balanza de pagos, deuda y crisis financieras.
# *   Financiamiento e inversión extranjera.
# *   Política fiscal y financiera.
#
# ### Clase 1
#
# **Introducción:**
#
# Este módulo se enfoca en las dimensiones externas que influyen en el desarrollo económico. A diferencia de los módulos anteriores que pudieron centrarse en factores internos como la acumulación de capital humano o la innovación tecnológica, aquí analizaremos cómo la interacción con la economía global impacta el crecimiento y la prosperidad de las naciones en desarrollo. Exploraremos el papel crucial del comercio internacional como un motor para el crecimiento y la diversificación económica, así como las políticas necesarias para fomentar el comercio y la integración regional. Profundizaremos en las causas y las repercusiones de las crisis de balanza de pagos y la deuda externa, examinando estrategias para gestionar la deuda y prevenir futuras crisis financieras. También evaluaremos la importancia de la Inversión Extranjera Directa (IED) y otras formas de financiamiento externo para el desarrollo económico, y analizaremos las políticas diseñadas para atraer y gestionar la IED de manera efectiva. Finalmente, analizaremos la importancia de la política fiscal y financiera en el contexto del desarrollo, centrándonos en políticas para movilizar recursos internos, gestionar el gasto público y promover la estabilidad macroeconómica en un entorno globalizado.
#
# **Teoría:**
#
# *   **Teorías del Comercio Internacional y Desarrollo:** Profundizaremos en las teorías clásicas y neoclásicas del comercio internacional, como la **ventaja comparativa** (David Ricardo) y el modelo **Heckscher-Ohlin**.  Si bien ya se pudo haber mencionado la ventaja comparativa anteriormente, aquí la analizaremos en detalle, incluyendo sus limitaciones en el contexto de los países en desarrollo.  Por ejemplo, se discutirá cómo las imperfecciones del mercado, la especialización en productos básicos y la falta de diversificación pueden impedir que los países en desarrollo se beneficien plenamente de la ventaja comparativa estática.  También exploraremos extensiones modernas de estas teorías, como los modelos de "nuevas teorías del comercio" (Krugman) que incorporan economías de escala, diferenciación de productos y competencia imperfecta, y cómo estos modelos pueden ser relevantes para comprender el comercio entre países en desarrollo y desarrollados.  Finalmente, se analizarán las implicaciones del proteccionismo y el libre comercio para el desarrollo.
#
# *   **Modelos de Crisis de Balanza de Pagos y Deuda Externa:** Se analizarán los modelos de primera, segunda y tercera generación de crisis de balanza de pagos. Se hará hincapié en las vulnerabilidades estructurales de las economías en desarrollo que las hacen más susceptibles a las crisis, como la dependencia de las exportaciones de productos básicos, la acumulación de deuda en moneda extranjera y la debilidad de las instituciones financieras. A diferencia de análisis previos, este módulo se centrará en los mecanismos de contagio internacional y el papel de las expectativas y la especulación en la propagación de las crisis.  Además, se estudiarán las consecuencias sociales y económicas de las crisis de deuda, incluyendo la pérdida de acceso al financiamiento externo, la contracción económica, el aumento de la pobreza y el deterioro de los indicadores sociales.
#
# *   **Teorías de la Inversión Extranjera Directa (IED):** Se explorarán las diferentes teorías que explican los determinantes y los efectos de la IED en los países en desarrollo.  Se analizarán las teorías de la localización de la IED (Dunning), que consideran factores como los costos laborales, la disponibilidad de recursos naturales, la infraestructura, el tamaño del mercado y el entorno institucional.  Además, se examinarán los efectos de la IED en el crecimiento económico, la transferencia de tecnología, la creación de empleo y la competitividad. Se considerarán los posibles efectos negativos de la IED, como la "crowding out" de la inversión nacional, la repatriación de beneficios y la degradación ambiental. Se analizarán las políticas para atraer IED de calidad y maximizar sus beneficios para el desarrollo.
#
# *   **Política Fiscal y Financiera para el Desarrollo:**  Se discutirán los principios de la política fiscal y financiera en el contexto del desarrollo económico. Se analizarán las diferentes fuentes de ingresos fiscales (impuestos, tasas, contribuciones) y su progresividad. Se analizarán los componentes del gasto público (educación, salud, infraestructura, seguridad social) y su impacto en el crecimiento y la equidad. Se discutirá la importancia de la gestión de la deuda pública y la sostenibilidad fiscal. Se analizarán las políticas para fortalecer el sistema financiero y promover la inclusión financiera.  Se hará especial hincapié en el papel de la política fiscal y financiera en la estabilización macroeconómica y la gestión de las crisis.
#
# **Ejemplos:**
#
# *   **Integración Comercial y Crecimiento:**  Analizar casos de países (e.g., Corea del Sur, Taiwán) que han experimentado un rápido crecimiento económico a través de la integración exitosa en el comercio mundial, enfocándose en sus estrategias de diversificación de exportaciones, promoción de la inversión extranjera y desarrollo de capacidades tecnológicas. Se contrastarán con casos de países (e.g., algunos países africanos) que han permanecido rezagados en el comercio mundial debido a la especialización en productos básicos, la falta de diversificación y la presencia de barreras comerciales.
#
# *   **Gestión de la Deuda y Prevención de Crisis:**  Estudiar ejemplos de países (e.g., Chile) que han implementado políticas prudentes de gestión de la deuda y han logrado evitar crisis financieras, resaltando la importancia de la transparencia, la rendición de cuentas y la gestión activa del riesgo. Se contrastarán con casos de países (e.g., Argentina) que han experimentado crisis de deuda recurrentes debido a la mala gestión macroeconómica, la acumulación de deuda en moneda extranjera y la falta de credibilidad.
#
# *   **Inversión en Infraestructura y Competitividad:** Demostrar cómo las inversiones estratégicas en infraestructura (e.g., transporte, energía, telecomunicaciones) y educación pueden mejorar la competitividad de un país y atraer la IED, utilizando ejemplos de países que han logrado transformar sus economías a través de la inversión en capital físico y humano (e.g., Singapur).
#
# **Retos:**
#
# *   **Estudio de Caso: Impacto del Comercio Internacional:**  Realizar un estudio de caso detallado sobre un país en desarrollo específico y analizar cómo el comercio internacional ha afectado su crecimiento económico, considerando tanto los beneficios como los desafíos. El estudio debe incluir un análisis de las políticas comerciales implementadas por el país, su estructura de exportaciones e importaciones, y su participación en acuerdos comerciales regionales e internacionales.
#
# *   **Análisis de Políticas para la Gestión de la Deuda:** Investigar y presentar un análisis comparativo de las políticas públicas implementadas en diferentes países en desarrollo para gestionar la deuda externa y prevenir las crisis financieras, identificando las mejores prácticas y las lecciones aprendidas.
#
# *   **Propuesta de Política para Atraer IED:** Desarrollar una propuesta de política concreta y específica para atraer la Inversión Extranjera Directa a una región específica de un país en desarrollo, considerando las características y las necesidades de la región, así como las ventajas comparativas del país. La propuesta debe incluir un análisis de los incentivos fiscales, la simplificación de los trámites burocráticos, la promoción de la inversión y la mejora del clima de negocios.

# %%
import json

# Muestra la estructura completa
print(json.dumps(data_json, indent=4))

# Si solo quieres ver un módulo en particular
i = 0  # Ajusta según sea necesario
print(json.dumps(data_json["modules"][i], indent=4))
# Out:
# {
#     "course_title": "Desarrollo Econ\u00f3mico",
#     "course_code": "1503714",
#     "credits": 3,
#     "faculty": "Facultad de Ciencias Econ\u00f3micas",
#     "term": "2022-1 y 2022-2",
#     "instructor": "Maria Isabel Restrepo E.",
#     "instructor_email": "isabel.restrepo@udea.edu.co",
#     "course_description": "Este curso proporciona una descripci\u00f3n general de los problemas de la econom\u00eda del desarrollo y de las contribuciones que el an\u00e1lisis econ\u00f3mico puede hacer para explicar por qu\u00e9 algunas naciones son pobres y otras ricas, y las circunstancias econ\u00f3micas y restricciones a las que se enfrenta el mundo en desarrollo. Al final del curso los estudiantes podr\u00e1n demostrar su comprensi\u00f3n sobre los conceptos b\u00e1sicos, las teor\u00edas y discursos de la econom\u00eda del desarrollo, as\u00ed como de los problemas y las pol\u00edticas. Asimismo, podr\u00e1n discutir y evaluar diferentes enfoques de manera cr\u00edtica.",
#     "general_objective": "Analizar los conceptos b\u00e1sicos, las teor\u00edas y discursos de la econom\u00eda del desarrollo, as\u00ed como algunos de los problemas a los que se enfrentan los pa\u00edses en desarrollo y las estrategias de pol\u00edtica implementadas",
#     "specific_objectives": [
#         "Distinguir las principales teor\u00edas del desarrollo econ\u00f3mico en un contexto hist\u00f3rico.",
#         "Identificar los principales retos al desarrollo econ\u00f3mico de los pa\u00edses.",
#         "Sustentar opiniones sobre los retos, las pol\u00edticas y las estrategias del desarrollo."
#     ],
#     "modules": [
#         {
#             "module_num": "1",
#             "module_title": "Principios del desarrollo econ\u00f3mico",
#             "objectives": [
#                 "Comprender la introducci\u00f3n al desarrollo econ\u00f3mico.",
#                 "Analizar modelos cl\u00e1sicos y neocl\u00e1sicos de crecimiento y desarrollo econ\u00f3mico.",
#                 "Evaluar modelos contempor\u00e1neos de desarrollo econ\u00f3mico.",
#                 "Identificar los determinantes fundamentales del desarrollo econ\u00f3mico."
#             ],
#             "content_outline": "Introducci\u00f3n, Modelos cl\u00e1sicos y neocl\u00e1sicos, Modelos contempor\u00e1neos, Determinantes fundamentales",
#             "class_notes": {
#                 "class_num": "1",
#                 "introduction": "El m\u00f3dulo introduce el campo del desarrollo econ\u00f3mico, contrastando las econom\u00edas desarrolladas con las econom\u00edas en desarrollo.  Se explican los indicadores clave de desarrollo (PIB per c\u00e1pita, esperanza de vida, tasas de alfabetizaci\u00f3n) y se discute por qu\u00e9 el desarrollo econ\u00f3mico es un problema multidimensional que va m\u00e1s all\u00e1 del mero crecimiento econ\u00f3mico. Se analizan las diferentes escuelas de pensamiento sobre el desarrollo y sus implicaciones para la pol\u00edtica.",
#                 "theory": "Este m\u00f3dulo cubre los modelos de crecimiento econ\u00f3mico, incluyendo el modelo de Harrod-Domar, el modelo de Solow, y las teor\u00edas de crecimiento end\u00f3geno. Se examinan las variables clave que impulsan el crecimiento (inversi\u00f3n, acumulaci\u00f3n de capital humano, innovaci\u00f3n tecnol\u00f3gica). Se analizan los supuestos y limitaciones de cada modelo. Se discute el papel de la productividad y la eficiencia en el crecimiento econ\u00f3mico. Ejemplos: El modelo de Solow explica c\u00f3mo la acumulaci\u00f3n de capital y el progreso tecnol\u00f3gico influyen en el crecimiento a largo plazo. Las teor\u00edas de crecimiento end\u00f3geno resaltan la importancia de la I+D y el capital humano.",
#                 "challenges": [
#                     "Investigar y presentar un resumen de un modelo contempor\u00e1neo de desarrollo econ\u00f3mico no cubierto en clase (por ejemplo, el modelo de Diamond).",
#                     "Analizar cr\u00edticamente un art\u00edculo de investigaci\u00f3n que utilice uno de los modelos de crecimiento para explicar el desempe\u00f1o econ\u00f3mico de un pa\u00eds en desarrollo.",
#                     "Debatir sobre la relevancia de los modelos cl\u00e1sicos de crecimiento para las econom\u00edas en desarrollo actuales."
#                 ]
#             }
#         },
#         {
#             "module_num": "2",
#             "module_title": "La perspectiva dom\u00e9stica del desarrollo econ\u00f3mico",
#             "objectives": [
#                 "Analizar la relaci\u00f3n entre pobreza, desigualdad y desarrollo econ\u00f3mico.",
#                 "Evaluar el impacto del crecimiento de la poblaci\u00f3n en el desarrollo.",
#                 "Comprender la importancia del capital humano (educaci\u00f3n y salud) para el desarrollo.",
#                 "Analizar los procesos de urbanizaci\u00f3n y migraci\u00f3n rural-urbana en el contexto del desarrollo.",
#                 "Evaluar la transformaci\u00f3n agr\u00edcola y el desarrollo rural.",
#                 "Comprender la relaci\u00f3n entre medio ambiente y desarrollo."
#             ],
#             "content_outline": "Pobreza, desigualdad, Crecimiento de la poblaci\u00f3n, Capital humano, Urbanizaci\u00f3n y migraci\u00f3n, Transformaci\u00f3n agr\u00edcola, Medio ambiente",
#             "class_notes": {
#                 "class_num": "1",
#                 "introduction": "Este m\u00f3dulo examina los factores internos que influyen en el desarrollo econ\u00f3mico de un pa\u00eds. Se analiza la relaci\u00f3n entre la pobreza, la desigualdad y el crecimiento econ\u00f3mico, y se examinan las pol\u00edticas para reducir la pobreza y la desigualdad. Se discute el impacto del crecimiento de la poblaci\u00f3n en el desarrollo econ\u00f3mico, incluyendo los efectos sobre la disponibilidad de recursos, la educaci\u00f3n y el empleo. Se analiza la importancia del capital humano (educaci\u00f3n y salud) para el desarrollo econ\u00f3mico, y se examinan las pol\u00edticas para mejorar la educaci\u00f3n y la salud. Se discuten los procesos de urbanizaci\u00f3n y migraci\u00f3n rural-urbana, y se examinan sus implicaciones para el desarrollo econ\u00f3mico. Se analiza la transformaci\u00f3n agr\u00edcola y el desarrollo rural, y se examinan las pol\u00edticas para promover el desarrollo agr\u00edcola y rural. Se discute la relaci\u00f3n entre el medio ambiente y el desarrollo econ\u00f3mico, y se examinan las pol\u00edticas para proteger el medio ambiente y promover el desarrollo sostenible.",
#                 "theory": "Se exploran las teor\u00edas de la desigualdad (curva de Lorenz, coeficiente de Gini) y su impacto en el crecimiento. Se analizan los modelos demogr\u00e1ficos y su relaci\u00f3n con el desarrollo econ\u00f3mico. Se discute la teor\u00eda del capital humano y su impacto en la productividad y el crecimiento. Se explican los modelos de migraci\u00f3n rural-urbana (Harris-Todaro) y sus implicaciones para el mercado laboral. Se analiza la teor\u00eda del desarrollo agr\u00edcola y su relaci\u00f3n con la industrializaci\u00f3n. Se discuten las externalidades ambientales y su impacto en el desarrollo sostenible. Ejemplos: El crecimiento de la poblaci\u00f3n puede generar presiones sobre los recursos naturales y los servicios p\u00fablicos, lo que a su vez puede afectar negativamente el desarrollo econ\u00f3mico. La inversi\u00f3n en educaci\u00f3n y salud puede aumentar la productividad de la mano de obra y mejorar los niveles de vida.",
#                 "challenges": [
#                     "Realizar un estudio de caso sobre un pa\u00eds en desarrollo y analizar c\u00f3mo la desigualdad afecta su crecimiento econ\u00f3mico.",
#                     "Investigar y presentar un an\u00e1lisis de las pol\u00edticas p\u00fablicas implementadas en un pa\u00eds en desarrollo para mejorar la educaci\u00f3n y la salud.",
#                     "Desarrollar una propuesta de pol\u00edtica para promover el desarrollo agr\u00edcola sostenible en una regi\u00f3n espec\u00edfica de un pa\u00eds en desarrollo."
#                 ]
#             }
#         },
#         {
#             "module_num": "3",
#             "module_title": "La perspectiva internacional del desarrollo econ\u00f3mico",
#             "objectives": [
#                 "Analizar el papel del comercio internacional en el desarrollo econ\u00f3mico.",
#                 "Comprender la relaci\u00f3n entre la balanza de pagos, la deuda y las crisis financieras.",
#                 "Evaluar el impacto del financiamiento y la inversi\u00f3n extranjera en el desarrollo.",
#                 "Analizar la pol\u00edtica fiscal y financiera para el desarrollo."
#             ],
#             "content_outline": "Comercio internacional, Balanza de pagos, deuda y crisis financieras, Financiamiento e inversi\u00f3n extranjera, Pol\u00edtica fiscal y financiera",
#             "class_notes": {
#                 "class_num": "1",
#                 "introduction": "Este m\u00f3dulo analiza las dimensiones externas del desarrollo econ\u00f3mico. Se examina el papel del comercio internacional como motor del crecimiento y la diversificaci\u00f3n econ\u00f3mica, y se discuten las pol\u00edticas para promover el comercio y la integraci\u00f3n regional. Se analizan las causas y consecuencias de las crisis de balanza de pagos y la deuda externa, y se examinan las pol\u00edticas para gestionar la deuda y prevenir las crisis financieras. Se discute el papel de la inversi\u00f3n extranjera directa (IED) y otras formas de financiamiento externo para el desarrollo econ\u00f3mico, y se examinan las pol\u00edticas para atraer y gestionar la IED. Se analiza la importancia de la pol\u00edtica fiscal y financiera para el desarrollo econ\u00f3mico, y se examinan las pol\u00edticas para movilizar recursos internos, gestionar el gasto p\u00fablico y promover la estabilidad macroecon\u00f3mica.",
#                 "theory": "Se exploran las teor\u00edas del comercio internacional (ventaja comparativa, Heckscher-Ohlin) y su impacto en el desarrollo. Se analizan los modelos de crisis de balanza de pagos y los efectos de la deuda externa. Se discuten las teor\u00edas de la inversi\u00f3n extranjera directa y sus efectos en el crecimiento. Se explican los principios de la pol\u00edtica fiscal y financiera para el desarrollo. Ejemplos: Los pa\u00edses que se han integrado con \u00e9xito en el comercio mundial han experimentado un crecimiento econ\u00f3mico m\u00e1s r\u00e1pido. La gesti\u00f3n prudente de la deuda externa es fundamental para evitar las crisis financieras. La inversi\u00f3n en infraestructura y educaci\u00f3n puede mejorar la competitividad de un pa\u00eds y atraer la IED.",
#                 "challenges": [
#                     "Realizar un estudio de caso sobre un pa\u00eds en desarrollo y analizar c\u00f3mo el comercio internacional ha afectado su crecimiento econ\u00f3mico.",
#                     "Investigar y presentar un an\u00e1lisis de las pol\u00edticas p\u00fablicas implementadas en un pa\u00eds en desarrollo para gestionar la deuda externa y prevenir las crisis financieras.",
#                     "Desarrollar una propuesta de pol\u00edtica para atraer la inversi\u00f3n extranjera directa a una regi\u00f3n espec\u00edfica de un pa\u00eds en desarrollo."
#                 ]
#             }
#         }
#     ],
#     "evaluation": {
#         "examen_parcial_1": {
#             "percentage": 20,
#             "week": 4
#         },
#         "examen_parcial_2": {
#             "percentage": 20,
#             "week": 8
#         },
#         "examen_parcial_3": {
#             "percentage": 20,
#             "week": 12
#         },
#         "trabajo_final": {
#             "percentage": 20,
#             "week": 13
#         },
#         "exposicion_trabajo": {
#             "percentage": 13,
#             "week": "13-14"
#         },
#         "sustentacion_planteamiento": {
#             "percentage": 7,
#             "week": 6
#         }
#     },
#     "methodology": "Clases magistrales, Participaci\u00f3n de los estudiantes en clase, Actividades de trabajo independiente de los estudiantes"
# }
# {
#     "module_num": "1",
#     "module_title": "Principios del desarrollo econ\u00f3mico",
#     "objectives": [
#         "Comprender la introducci\u00f3n al desarrollo econ\u00f3mico.",
#         "Analizar modelos cl\u00e1sicos y neocl\u00e1sicos de crecimiento y desarrollo econ\u00f3mico.",
#         "Evaluar modelos contempor\u00e1neos de desarrollo econ\u00f3mico.",
#         "Identificar los determinantes fundamentales del desarrollo econ\u00f3mico."
#     ],
#     "content_outline": "Introducci\u00f3n, Modelos cl\u00e1sicos y neocl\u00e1sicos, Modelos contempor\u00e1neos, Determinantes fundamentales",
#     "class_notes": {
#         "class_num": "1",
#         "introduction": "El m\u00f3dulo introduce el campo del desarrollo econ\u00f3mico, contrastando las econom\u00edas desarrolladas con las econom\u00edas en desarrollo.  Se explican los indicadores clave de desarrollo (PIB per c\u00e1pita, esperanza de vida, tasas de alfabetizaci\u00f3n) y se discute por qu\u00e9 el desarrollo econ\u00f3mico es un problema multidimensional que va m\u00e1s all\u00e1 del mero crecimiento econ\u00f3mico. Se analizan las diferentes escuelas de pensamiento sobre el desarrollo y sus implicaciones para la pol\u00edtica.",
#         "theory": "Este m\u00f3dulo cubre los modelos de crecimiento econ\u00f3mico, incluyendo el modelo de Harrod-Domar, el modelo de Solow, y las teor\u00edas de crecimiento end\u00f3geno. Se examinan las variables clave que impulsan el crecimiento (inversi\u00f3n, acumulaci\u00f3n de capital humano, innovaci\u00f3n tecnol\u00f3gica). Se analizan los supuestos y limitaciones de cada modelo. Se discute el papel de la productividad y la eficiencia en el crecimiento econ\u00f3mico. Ejemplos: El modelo de Solow explica c\u00f3mo la acumulaci\u00f3n de capital y el progreso tecnol\u00f3gico influyen en el crecimiento a largo plazo. Las teor\u00edas de crecimiento end\u00f3geno resaltan la importancia de la I+D y el capital humano.",
#         "challenges": [
#             "Investigar y presentar un resumen de un modelo contempor\u00e1neo de desarrollo econ\u00f3mico no cubierto en clase (por ejemplo, el modelo de Diamond).",
#             "Analizar cr\u00edticamente un art\u00edculo de investigaci\u00f3n que utilice uno de los modelos de crecimiento para explicar el desempe\u00f1o econ\u00f3mico de un pa\u00eds en desarrollo.",
#             "Debatir sobre la relevancia de los modelos cl\u00e1sicos de crecimiento para las econom\u00edas en desarrollo actuales."
#         ]
#     }
# }

# %%
import json
import markdown
import pypandoc
import google.generativeai as genai

def crear_material_clase(model, modulo_info, modulo_num, clase_num, total_clases, semanas_curso, clases_semana, previous_classes_summaries=""):
    """
    Genera el material para una clase específica dentro de un módulo

    Args:
        model: Modelo de Gemini a utilizar
        modulo_info: Información del módulo actual
        modulo_num: Número del módulo
        clase_num: Número de la clase dentro del módulo
        total_clases: Total de clases para este módulo
        semanas_curso: Duración total del curso en semanas
        clases_semana: Número de clases por semana
        previous_classes_summaries: Resumen de clases anteriores para mantener coherencia
    """

    prompt = f"""Eres un desarrollador experto de contenido educativo con amplia experiencia en la creación de materiales de cursos universitarios.
    Posees un profundo conocimiento en principios pedagógicos, diseño curricular y redacción académica.
    Tu tarea es ayudar a desarrollar materiales educativos integrales a partir de un plan de estudios (syllabus), asegurando altos estándares académicos.

    ### Contexto del Curso
    - Este curso tiene una duración total de {semanas_curso} semanas
    - Se imparten {clases_semana} clases por semana
    - El módulo actual ({modulo_num}) debe dividirse en {total_clases} clases distintas

    ### Contexto y Objetivos
    - **Analizar y comprender el syllabus**:
      - Extraer los componentes esenciales (objetivos, competencias, temáticas, metodologías, evaluaciones, etc.).
      - Identificar puntos clave para la generación de contenido pedagógico.
    - **Generar materiales educativos**:
      - Analizar detalladamente cada módulo, definiendo objetivos, contenidos, actividades y evaluaciones.
      - Crear notas de clase comprensivas que expliquen en profundidad cada tema, con ejemplos, explicaciones teóricas y retos prácticos.
      - Mantener un alto rigor académico y coherencia con clases previas.

    ### Plan de estudios - Módulo {modulo_num}
    {json.dumps(modulo_info, indent=2)}

    ### Clases anteriores de este módulo (resumen)
    {previous_classes_summaries}

    ### Instrucciones
    - Genera **únicamente** el material detallado de la **clase {clase_num} del módulo {modulo_num}**.
    - Esta es la clase {clase_num} de {total_clases} para este módulo.
    - Divide el contenido del módulo de manera lógica entre las {total_clases} clases.
    - Asegúrate de que esta clase tenga continuidad con las clases anteriores del módulo.
    - Incluye en el material:
      1. Título de la clase
      2. Objetivos específicos de la clase
      3. Contenido teórico detallado
      4. Ejemplos o casos de estudio
      5. Actividades prácticas o ejercicios
      6. Materiales complementarios recomendados

    **Revisa antes de entregar la respuesta. No incluyas el historial en la respuesta, solo el nuevo contenido para esta clase específica.**
    """

    # Generar contenido con el modelo
    material = model.generate_content(prompt)

    # Generar resumen de la clase para mantener coherencia
    resumen_prompt = f"Resume brevemente los principales puntos tratados en la siguiente clase (máximo 200 palabras):\n{material.text}"
    resumen = model.generate_content(resumen_prompt)

    # Convertir a HTML
    html = markdown.markdown(material.text)

    # Convertir a PDF
    output_name = f"material_modulo_{modulo_num}_clase_{clase_num}.pdf"
    extra_args = ['--pdf-engine=xelatex', '-V', 'mainfont=Latin Modern Roman']
    pypandoc.convert_text(html, 'pdf', format='html', outputfile=output_name, extra_args=extra_args)

    return material, resumen.text

def crear_materiales_modulo(model, modulo_info, modulo_idx, semanas_curso, clases_semana):
    """
    Genera los materiales para todas las clases de un módulo

    Args:
        model: Modelo de Gemini a utilizar
        modulo_info: Información del módulo actual
        modulo_idx: Índice del módulo en la lista
        semanas_curso: Duración total del curso en semanas
        clases_semana: Número de clases por semana
    """
    # Calcular el número de clases para este módulo
    # Por defecto asignamos 2 clases por módulo, pero se puede ajustar según la lógica deseada
    total_modulos = len(data_json["modules"])
    total_clases_curso = semanas_curso * clases_semana

    # Distribuir clases de manera proporcional entre módulos
    clases_por_modulo = max(1, round(total_clases_curso / total_modulos))

    # Asegurar que los módulos más importantes tengan al menos 2 clases si es posible
    if modulo_idx < (total_clases_curso % total_modulos):
        clases_por_modulo += 1

    print(f"Generando {clases_por_modulo} clases para el módulo {modulo_idx+1}")

    # Para mantener coherencia entre clases
    previous_classes_summaries = ""

    # Generar cada clase del módulo
    for clase_num in range(1, clases_por_modulo + 1):
        print(f"Generando clase {clase_num} de {clases_por_modulo} del módulo {modulo_idx+1}...")

        material, resumen = crear_material_clase(
            model,
            modulo_info,
            modulo_idx + 1,  # Módulo comienza en 1, no en 0
            clase_num,
            clases_por_modulo,
            semanas_curso,
            clases_semana,
            previous_classes_summaries
        )

        # Agregar resumen de esta clase para las siguientes
        previous_classes_summaries += f"\n\nResumen de la clase {clase_num}:\n{resumen}"

    return previous_classes_summaries

def crear_todos_materiales(model, data_json, semanas_curso=16, clases_semana=2):
    """
    Genera los materiales para todos los módulos del curso

    Args:
        model: Modelo de Gemini a utilizar
        data_json: Datos estructurados del curso
        semanas_curso: Duración total del curso en semanas (por defecto 16)
        clases_semana: Número de clases por semana (por defecto 2)
    """
    all_summaries = ""

    for i, modulo in enumerate(data_json["modules"]):
        modulo_summaries = crear_materiales_modulo(
            model,
            modulo,
            i,
            semanas_curso,
            clases_semana
        )
        all_summaries += f"\n\n--- RESUMEN MÓDULO {i+1} ---\n{modulo_summaries}"

    # Opcionalmente, genera un documento con todos los resúmenes
    with open("resumen_curso_completo.txt", "w", encoding="utf-8") as f:
        f.write(all_summaries)

    return all_summaries

# %%
# Reemplaza tu actual llamada a crear_materiales con esto:
semanas_curso = 16  # Puedes cambiar este valor o solicitar al usuario que lo ingrese
clases_semana = 2   # Puedes cambiar este valor o solicitar al usuario que lo ingrese

history = crear_todos_materiales(model, data_json, semanas_curso, clases_semana)
# Out:
# Generando 12 clases para el módulo 1
# Generando clase 1 de 12 del módulo 1...
# Generando clase 2 de 12 del módulo 1...
# Generando clase 3 de 12 del módulo 1...
# Generando clase 4 de 12 del módulo 1...
# [WARNING] Missing character: There is no δ (U+03B4) (U+03B4) in font [lmmono10-regular]:!
# WARNING:pypandoc:Missing character: There is no δ (U+03B4) (U+03B4) in font [lmmono10-regular]:!
# [WARNING] Missing character: There is no δ (U+03B4) (U+03B4) in font [lmmono10-regular]:!
# WARNING:pypandoc:Missing character: There is no δ (U+03B4) (U+03B4) in font [lmmono10-regular]:!
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
# [WARNING] Missing character: There is no β (U+03B2) (U+03B2) in font [lmmono10-regular]:!
# WARNING:pypandoc:Missing character: There is no β (U+03B2) (U+03B2) in font [lmmono10-regular]:!
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
# [WARNING] Missing character: There is no β (U+03B2) (U+03B2) in font [lmmono10-regular]:!
# WARNING:pypandoc:Missing character: There is no β (U+03B2) (U+03B2) in font [lmmono10-regular]:!
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no β (U+03B2) (U+03B2) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no β (U+03B2) (U+03B2) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no β (U+03B2) (U+03B2) in font Latin Modern Roman 10 Regular
# WARNING:pypandoc:Missing character: There is no β (U+03B2) (U+03B2) in font Latin Modern Roman 10 Regular
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
# [WARNING] Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
#
# WARNING:pypandoc:Missing character: There is no α (U+03B1) (U+03B1) in font [lmmono10-regular]:!
# Generando clase 5 de 12 del módulo 1...
# Generando clase 6 de 12 del módulo 1...
# Generando clase 7 de 12 del módulo 1...
# Generando clase 8 de 12 del módulo 1...
# Generando clase 9 de 12 del módulo 1...
# Generando clase 10 de 12 del módulo 1...
# Generando clase 11 de 12 del módulo 1...
# Generando clase 12 de 12 del módulo 1...
# Generando 12 clases para el módulo 2
# Generando clase 1 de 12 del módulo 2...
# Generando clase 2 de 12 del módulo 2...
# Generando clase 3 de 12 del módulo 2...
# Generando clase 4 de 12 del módulo 2...
# Generando clase 5 de 12 del módulo 2...
# Generando clase 6 de 12 del módulo 2...
# Generando clase 7 de 12 del módulo 2...
# Generando clase 8 de 12 del módulo 2...
# Generando clase 9 de 12 del módulo 2...
# Generando clase 10 de 12 del módulo 2...
# Generando clase 11 de 12 del módulo 2...
# Generando clase 12 de 12 del módulo 2...
# Generando 11 clases para el módulo 3
# Generando clase 1 de 11 del módulo 3...
# Generando clase 2 de 11 del módulo 3...
# Generando clase 3 de 11 del módulo 3...

# %%
import json
import markdown
import pypandoc
import google.generativeai as genai

def crear_material_clase(model, modulo_info, modulo_num, clase_num, total_clases, semanas_curso, clases_semana, previous_classes_summaries=""):
    """
    Genera el material para una clase específica con prompts optimizados
    """
    # Prompt base con información esencial
    prompt_base = f"""Eres un desarrollador experto de contenido educativo.

    ### Contexto del Curso
    - Duración: {semanas_curso} semanas, {clases_semana} clases por semana
    - Módulo actual ({modulo_num}) dividido en {total_clases} clases
    - Esta es la clase {clase_num} de {total_clases} para este módulo

    ### Instrucciones
    Genera el material detallado para la clase {clase_num} del módulo {modulo_num}, incluyendo:
    1. Título de la clase
    2. Objetivos específicos
    3. Contenido teórico detallado
    4. Ejemplos o casos de estudio
    5. Actividades prácticas
    6. Materiales complementarios"""

    # Extraer solo la información esencial del módulo
    modulo_info_simplificado = {
        "title": modulo_info.get("title", ""),
        "description": modulo_info.get("description", ""),
        "topics": modulo_info.get("topics", [])
    }

    # Primer paso: obtener estructura general de la clase
    primer_prompt = f"""{prompt_base}

    ### Información del módulo
    {json.dumps(modulo_info_simplificado, indent=2)}

    Primero, proporciona solo un esquema detallado con los temas principales
    que deberías cubrir en esta clase específica."""

    esquema = model.generate_content(primer_prompt)

    # Solo enviar resúmenes relevantes para mantener contexto
    resumenes_relevantes = ""
    if previous_classes_summaries:
        # Extraer solo los últimos resúmenes si hay muchos
        resumenes_split = previous_classes_summaries.split("Resumen de la clase")
        if len(resumenes_split) > 3:  # Si hay más de 3 resúmenes
            resumenes_relevantes = "Resumen de la clase".join(resumenes_split[-3:])
        else:
            resumenes_relevantes = previous_classes_summaries

    # Segundo paso: generar el contenido completo basado en el esquema
    segundo_prompt = f"""{prompt_base}

    ### Información del módulo
    {json.dumps(modulo_info_simplificado, indent=2)}

    ### Esquema aprobado
    {esquema.text}

    ### Contexto de clases anteriores
    {resumenes_relevantes}

    Desarrolla ahora el contenido completo siguiendo este esquema,
    asegurando continuidad con las clases anteriores."""

    material = model.generate_content(segundo_prompt)

    # Generar resumen de la clase para mantener coherencia (prompt corto)
    resumen_prompt = "Resume en 150 palabras los puntos clave tratados en la siguiente clase:\n" + material.text[:2000]  # Limitamos a los primeros 2000 caracteres para el resumen
    resumen = model.generate_content(resumen_prompt)

    # Convertir a HTML y PDF
    html = markdown.markdown(material.text)
    output_name = f"material_modulo_{modulo_num}_clase_{clase_num}.pdf"
    try:
        extra_args = ['--pdf-engine=xelatex', '-V', 'mainfont=Latin Modern Roman']
        pypandoc.convert_text(html, 'pdf', format='html', outputfile=output_name, extra_args=extra_args)
    except Exception as e:
        print(f"Error al generar PDF: {e}")

    return material, resumen.text

def crear_materiales_modulo(model, modulo_info, modulo_idx, semanas_curso, clases_semana):
    """
    Genera los materiales para todas las clases de un módulo
    """
    # Calcular el número de clases para este módulo
    total_modulos = len(data_json["modules"])
    total_clases_curso = semanas_curso * clases_semana

    # Distribuir clases de manera proporcional entre módulos
    clases_por_modulo = max(1, round(total_clases_curso / total_modulos))

    # Asegurar que los módulos más importantes tengan al menos 2 clases si es posible
    if modulo_idx < (total_clases_curso % total_modulos):
        clases_por_modulo += 1

    print(f"Generando {clases_por_modulo} clases para el módulo {modulo_idx+1}")

    # Para mantener coherencia entre clases
    previous_classes_summaries = ""

    # Generar cada clase del módulo
    for clase_num in range(1, clases_por_modulo + 1):
        print(f"Generando clase {clase_num} de {clases_por_modulo} del módulo {modulo_idx+1}...")

        material, resumen = crear_material_clase(
            model,
            modulo_info,
            modulo_idx + 1,
            clase_num,
            clases_por_modulo,
            semanas_curso,
            clases_semana,
            previous_classes_summaries
        )

        # Agregar resumen de esta clase para las siguientes
        previous_classes_summaries += f"\n\nResumen de la clase {clase_num}:\n{resumen}"

    return previous_classes_summaries

def crear_todos_materiales(model, data_json, semanas_curso=16, clases_semana=2):
    """
    Genera los materiales para todos los módulos del curso
    """
    all_summaries = ""

    for i, modulo in enumerate(data_json["modules"]):
        print(f"\n--- GENERANDO MÓDULO {i+1} ---")
        modulo_summaries = crear_materiales_modulo(
            model,
            modulo,
            i,
            semanas_curso,
            clases_semana
        )
        all_summaries += f"\n\n--- RESUMEN MÓDULO {i+1} ---\n{modulo_summaries}"

        # Guardar resúmenes después de cada módulo en caso de error
        with open(f"resumen_modulo_{i+1}.txt", "w", encoding="utf-8") as f:
            f.write(modulo_summaries)

    # Documento final con todos los resúmenes
    with open("resumen_curso_completo.txt", "w", encoding="utf-8") as f:
        f.write(all_summaries)

    return all_summaries

# %%
semanas_curso = 16  # Puedes cambiar este valor
clases_semana = 2   # Puedes cambiar este valor
history = crear_todos_materiales(model, data_json, semanas_curso, clases_semana)

# %%
import json
import markdown
import pypandoc
import google.generativeai as genai

def crear_material_clase(model, modulo_info, modulo_num, clase_num, total_clases, semanas_curso, clases_semana, previous_classes_summaries=""):
    """
    Genera el material para una clase específica con prompts optimizados
    """
    # Prompt base con información esencial
    prompt_base = f"""Eres un desarrollador experto de contenido educativo.

    ### Contexto del Curso
    - Duración: {semanas_curso} semanas, {clases_semana} clases por semana
    - Módulo actual ({modulo_num}) dividido en {total_clases} clases
    - Esta es la clase {clase_num} de {total_clases} para este módulo

    ### Instrucciones
    Genera el material detallado para la clase {clase_num} del módulo {modulo_num}, incluyendo:
    1. Título de la clase
    2. Objetivos específicos
    3. Contenido teórico detallado
    4. Ejemplos o casos de estudio
    5. Actividades prácticas
    6. Materiales complementarios"""

    # Extraer solo la información esencial del módulo
    modulo_info_simplificado = {
        "title": modulo_info.get("title", ""),
        "description": modulo_info.get("description", ""),
        "topics": modulo_info.get("topics", [])
    }

    # Primer paso: obtener estructura general de la clase
    primer_prompt = f"""{prompt_base}

    ### Información del módulo
    {json.dumps(modulo_info_simplificado, indent=2)}

    Primero, proporciona solo un esquema detallado con los temas principales
    que deberías cubrir en esta clase específica."""

    esquema = model.generate_content(primer_prompt)

    # Solo enviar resúmenes relevantes para mantener contexto
    resumenes_relevantes = ""
    if previous_classes_summaries:
        # Extraer solo los últimos resúmenes si hay muchos
        resumenes_split = previous_classes_summaries.split("Resumen de la clase")
        if len(resumenes_split) > 3:  # Si hay más de 3 resúmenes
            resumenes_relevantes = "Resumen de la clase".join(resumenes_split[-3:])
        else:
            resumenes_relevantes = previous_classes_summaries

    # Segundo paso: generar el contenido completo basado en el esquema
    segundo_prompt = f"""{prompt_base}

    ### Información del módulo
    {json.dumps(modulo_info_simplificado, indent=2)}

    ### Esquema aprobado
    {esquema.text}

    ### Contexto de clases anteriores
    {resumenes_relevantes}

    Desarrolla ahora el contenido completo siguiendo este esquema,
    asegurando continuidad con las clases anteriores."""

    material = model.generate_content(segundo_prompt)

    # Generar resumen de la clase para mantener coherencia (prompt corto)
    resumen_prompt = "Resume en 150 palabras los puntos clave tratados en la siguiente clase:\n" + material.text[:2000]  # Limitamos a los primeros 2000 caracteres para el resumen
    resumen = model.generate_content(resumen_prompt)

    # Convertir a HTML y PDF
    html = markdown.markdown(material.text)
    output_name = f"material_modulo_{modulo_num}_clase_{clase_num}.pdf"
    try:
        extra_args = ['--pdf-engine=xelatex', '-V', 'mainfont=Latin Modern Roman']
        pypandoc.convert_text(html, 'pdf', format='html', outputfile=output_name, extra_args=extra_args)
    except Exception as e:
        print(f"Error al generar PDF: {e}")

    return material, resumen.text

def crear_materiales_modulo(model, modulo_info, modulo_idx, semanas_curso, clases_semana):
    """
    Genera los materiales para todas las clases de un módulo
    """
    # Calcular el número de clases para este módulo
    total_modulos = len(data_json["modules"])
    total_clases_curso = semanas_curso * clases_semana

    # Distribuir clases de manera proporcional entre módulos
    clases_por_modulo = max(1, round(total_clases_curso / total_modulos))

    # Asegurar que los módulos más importantes tengan al menos 2 clases si es posible
    if modulo_idx < (total_clases_curso % total_modulos):
        clases_por_modulo += 1

    # Limitamos a máximo 6 clases por módulo como solicitado
    clases_por_modulo = min(clases_por_modulo, 6)

    print(f"Generando {clases_por_modulo} clases para el módulo {modulo_idx+1}")

    # Para mantener coherencia entre clases
    previous_classes_summaries = ""

    # Generar cada clase del módulo
    for clase_num in range(1, clases_por_modulo + 1):
        print(f"Generando clase {clase_num} de {clases_por_modulo} del módulo {modulo_idx+1}...")

        material, resumen = crear_material_clase(
            model,
            modulo_info,
            modulo_idx + 1,
            clase_num,
            clases_por_modulo,
            semanas_curso,
            clases_semana,
            previous_classes_summaries
        )

        # Agregar resumen de esta clase para las siguientes
        previous_classes_summaries += f"\n\nResumen de la clase {clase_num}:\n{resumen}"

    return previous_classes_summaries

def crear_todos_materiales(model, data_json, semanas_curso=16, clases_semana=2):
    """
    Genera los materiales para todos los módulos del curso
    """
    all_summaries = ""

    for i, modulo in enumerate(data_json["modules"]):
        print(f"\n--- GENERANDO MÓDULO {i+1} ---")
        modulo_summaries = crear_materiales_modulo(
            model,
            modulo,
            i,
            semanas_curso,
            clases_semana
        )
        all_summaries += f"\n\n--- RESUMEN MÓDULO {i+1} ---\n{modulo_summaries}"

        # Guardar resúmenes después de cada módulo en caso de error
        with open(f"resumen_modulo_{i+1}.txt", "w", encoding="utf-8") as f:
            f.write(modulo_summaries)

    # Documento final con todos los resúmenes
    with open("resumen_curso_completo.txt", "w", encoding="utf-8") as f:
        f.write(all_summaries)

    return all_summaries

# %%
semanas_curso = 16  # Duración total del curso en semanas
clases_semana = 2   # Número de clases por semana

# Ejecutar la generación del curso con el código modificado
history = crear_todos_materiales(model, data_json, semanas_curso, clases_semana)
